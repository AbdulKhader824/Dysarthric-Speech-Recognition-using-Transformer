# %%
import os
import random
from glob import glob
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
import os
import shutil
import random

# Define source and destination directories
source_dir = r"D:\Mtechs3\project\UASpeech_original_FM\UASpeech\audio\original\M10"
destination_dir = r"D:\Mtechs3\project\UASpeech_original_FM\UASpeech\audio\original\M10test"  # Change this to your desired destination

# Create destination directory if it doesn't exist
os.makedirs(destination_dir, exist_ok=True)

# List all audio files in the source directory
audio_files = [f for f in os.listdir(source_dir) if f.endswith(('.wav', '.mp3', '.flac'))]  # Add other audio formats if necessary

# Calculate the number of files to move (20%)
num_files_to_move = max(1, len(audio_files) // 5)  # At least one file if less than 5

# Select a random sample of 20% of the files
files_to_move = random.sample(audio_files, num_files_to_move)

# Move the selected files to the destination directory
for file_name in files_to_move:
    src_path = os.path.join(source_dir, file_name)
    dst_path = os.path.join(destination_dir, file_name)
    shutil.move(src_path, dst_path)  # Move the file
    print(f"Moved: {file_name}")  # Print the name of the moved file

print(f"Total files moved: {len(files_to_move)}")
# Out:
# Moved: M10_B1_UW70_M8.wav
# Moved: M10_B1_UW15_M6.wav
# Moved: M10_B3_UW91_M5.wav
# Moved: M10_B3_UW56_M8.wav
# Moved: M10_B1_C7_M5.wav
# Moved: M10_B1_D3_M8.wav
# Moved: M10_B2_CW88_M5.wav
# Moved: M10_B3_UW77_M7.wav
# Moved: M10_B2_CW56_M7.wav
# Moved: M10_B1_CW82_M2.wav
# Moved: M10_B1_UW53_M4.wav
# Moved: M10_B2_UW80_M7.wav
# Moved: M10_B1_CW10_M6.wav
# Moved: M10_B1_C8_M7.wav
# Moved: M10_B2_LO_M4.wav
# Moved: M10_B3_UW75_M7.wav
# Moved: M10_B2_UW21_M8.wav
# Moved: M10_B1_C13_M3.wav
# Moved: M10_B1_UW54_M7.wav
# Moved: M10_B3_CW67_M6.wav
# Moved: M10_B2_C2_M4.wav
# Moved: M10_B3_LR_M6.wav
# Moved: M10_B1_CW38_M5.wav
# Moved: M10_B1_UW82_M8.wav
# Moved: M10_B3_LH_M8.wav
# Moved: M10_B2_CW53_M3.wav
# Moved: M10_B2_UW7_M8.wav
# Moved: M10_B1_CW90_M3.wav
# Moved: M10_B3_LS_M6.wav
# Moved: M10_B3_D8_M4.wav
# Moved: M10_B2_LO_M8.wav
# Moved: M10_B2_D0_M7.wav
# Moved: M10_B2_CW25_M4.wav
# Moved: M10_B2_CW20_M8.wav
# Moved: M10_B2_CW98_M8.wav
# Moved: M10_B1_UW68_M2.wav
# Moved: M10_B3_CW35_M8.wav
# Moved: M10_B2_UW63_M5.wav
# Moved: M10_B3_UW76_M5.wav
# Moved: M10_B1_LI_M2.wav
# Moved: M10_B2_LG_M7.wav
# Moved: M10_B3_D9_M5.wav
# Moved: M10_B1_CW43_M4.wav
# Moved: M10_B1_CW95_M8.wav
# Moved: M10_B3_CW20_M7.wav
# Moved: M10_B2_UW45_M6.wav
# Moved: M10_B3_CW38_M4.wav
# Moved: M10_B1_UW45_M5.wav
# Moved: M10_B2_CW51_M2.wav
# Moved: M10_B2_CW44_M7.wav
# Moved: M10_B3_CW96_M3.wav
# Moved: M10_B2_CW66_M6.wav
# Moved: M10_B2_LA_M8.wav
# Moved: M10_B3_LW_M2.wav
# Moved: M10_B3_UW67_M7.wav
# Moved: M10_B1_UW49_M5.wav
# Moved: M10_B1_D4_M3.wav
# Moved: M10_B2_UW28_M5.wav
# Moved: M10_B2_LV_M6.wav
# Moved: M10_B3_CW37_M6.wav
# Moved: M10_B3_UW49_M8.wav
# Moved: M10_B3_C2_M7.wav
# Moved: M10_B2_UW41_M7.wav
# Moved: M10_B3_UW38_M8.wav
# Moved: M10_B3_UW93_M8.wav
# Moved: M10_B1_UW49_M3.wav
# Moved: M10_B3_C7_M4.wav
# Moved: M10_B3_C18_M2.wav
# Moved: M10_B2_CW21_M2.wav
# Moved: M10_B1_UW85_M4.wav
# Moved: M10_B1_CW29_M2.wav
# Moved: M10_B1_UW27_M7.wav
# Moved: M10_B2_UW12_M8.wav
# Moved: M10_B1_UW23_M7.wav
# Moved: M10_B2_UW23_M4.wav
# Moved: M10_B3_CW31_M7.wav
# Moved: M10_B3_CW56_M3.wav
# Moved: M10_B3_D9_M3.wav
# Moved: M10_B2_UW42_M3.wav
# Moved: M10_B1_CW33_M4.wav
# Moved: M10_B3_CW15_M6.wav
# Moved: M10_B3_UW10_M4.wav
# Moved: M10_B2_CW36_M3.wav
# Moved: M10_B3_C2_M5.wav
# Moved: M10_B3_UW93_M6.wav
# Moved: M10_B3_UW89_M2.wav
# Moved: M10_B3_CW68_M6.wav
# Moved: M10_B3_UW47_M3.wav
# Moved: M10_B1_D5_M3.wav
# Moved: M10_B3_CW50_M6.wav
# Moved: M10_B3_UW78_M4.wav
# Moved: M10_B3_C8_M3.wav
# Moved: M10_B3_LP_M2.wav
# Moved: M10_B2_CW78_M8.wav
# Moved: M10_B3_UW66_M3.wav
# Moved: M10_B3_CW82_M8.wav
# Moved: M10_B3_CW13_M5.wav
# Moved: M10_B3_CW71_M2.wav
# Moved: M10_B1_UW96_M2.wav
# Moved: M10_B2_UW34_M8.wav
# Moved: M10_B1_UW61_M6.wav
# Moved: M10_B2_CW57_M6.wav
# Moved: M10_B2_LM_M7.wav
# Moved: M10_B1_UW17_M3.wav
# Moved: M10_B1_D5_M7.wav
# Moved: M10_B2_CW97_M4.wav
# Moved: M10_B2_CW46_M5.wav
# Moved: M10_B1_CW100_M3.wav
# Moved: M10_B1_CW1_M8.wav
# Moved: M10_B3_CW44_M6.wav
# Moved: M10_B1_CW7_M3.wav
# Moved: M10_B3_UW42_M6.wav
# Moved: M10_B1_UW7_M7.wav
# Moved: M10_B3_CW78_M7.wav
# Moved: M10_B3_UW31_M3.wav
# Moved: M10_B2_LT_M2.wav
# Moved: M10_B1_UW18_M3.wav
# Moved: M10_B1_CW8_M6.wav
# Moved: M10_B2_UW41_M3.wav
# Moved: M10_B3_UW97_M6.wav
# Moved: M10_B2_UW94_M3.wav
# Moved: M10_B1_CW59_M4.wav
# Moved: M10_B1_UW28_M5.wav
# Moved: M10_B2_CW53_M8.wav
# Moved: M10_B1_UW11_M5.wav
# Moved: M10_B3_UW61_M5.wav
# Moved: M10_B1_UW88_M5.wav
# Moved: M10_B1_UW4_M5.wav
# Moved: M10_B1_UW72_M6.wav
# Moved: M10_B2_CW43_M7.wav
# Moved: M10_B1_UW39_M2.wav
# Moved: M10_B3_C14_M8.wav
# Moved: M10_B1_UW38_M7.wav
# Moved: M10_B2_UW6_M4.wav
# Moved: M10_B1_UW12_M8.wav
# Moved: M10_B2_C16_M6.wav
# Moved: M10_B1_LW_M5.wav
# Moved: M10_B3_UW49_M2.wav
# Moved: M10_B3_CW68_M3.wav
# Moved: M10_B2_UW61_M7.wav
# Moved: M10_B1_CW56_M5.wav
# Moved: M10_B3_UW59_M5.wav
# Moved: M10_B2_UW37_M8.wav
# Moved: M10_B2_UW61_M2.wav
# Moved: M10_B1_LY_M6.wav
# Moved: M10_B3_CW27_M6.wav
# Moved: M10_B2_CW54_M8.wav
# Moved: M10_B3_LJ_M6.wav
# Moved: M10_B1_UW27_M5.wav
# Moved: M10_B1_D7_M4.wav
# Moved: M10_B1_LY_M4.wav
# Moved: M10_B1_CW87_M4.wav
# Moved: M10_B2_D8_M3.wav
# Moved: M10_B2_CW30_M7.wav
# Moved: M10_B3_C15_M5.wav
# Moved: M10_B2_CW22_M2.wav
# Moved: M10_B3_UW28_M6.wav
# Moved: M10_B3_CW56_M5.wav
# Moved: M10_B3_UW83_M8.wav
# Moved: M10_B3_D1_M6.wav
# Moved: M10_B2_C7_M4.wav
# Moved: M10_B1_LN_M8.wav
# Moved: M10_B1_UW92_M2.wav
# Moved: M10_B3_UW14_M2.wav
# Moved: M10_B1_UW9_M5.wav
# Moved: M10_B2_CW85_M4.wav
# Moved: M10_B2_CW35_M4.wav
# Moved: M10_B2_LT_M4.wav
# Moved: M10_B2_CW71_M2.wav
# Moved: M10_B3_D0_M7.wav
# Moved: M10_B1_C12_M3.wav
# Moved: M10_B3_LP_M3.wav
# Moved: M10_B2_UW19_M2.wav
# Moved: M10_B3_UW73_M6.wav
# Moved: M10_B3_CW65_M4.wav
# Moved: M10_B1_UW38_M6.wav
# Moved: M10_B3_LS_M4.wav
# Moved: M10_B1_LA_M2.wav
# Moved: M10_B1_UW17_M2.wav
# Moved: M10_B1_UW16_M6.wav
# Moved: M10_B1_CW20_M5.wav
# Moved: M10_B2_UW35_M3.wav
# Moved: M10_B1_LM_M2.wav
# Moved: M10_B2_UW68_M3.wav
# Moved: M10_B2_C17_M4.wav
# Moved: M10_B2_LL_M7.wav
# Moved: M10_B1_CW71_M7.wav
# Moved: M10_B1_CW57_M7.wav
# Moved: M10_B3_UW99_M3.wav
# Moved: M10_B1_UW34_M7.wav
# Moved: M10_B3_LG_M2.wav
# Moved: M10_B3_UW4_M4.wav
# Moved: M10_B1_CW47_M8.wav
# Moved: M10_B2_CW66_M4.wav
# Moved: M10_B2_CW82_M5.wav
# Moved: M10_B1_UW82_M6.wav
# Moved: M10_B1_CW19_M2.wav
# Moved: M10_B3_CW99_M7.wav
# Moved: M10_B3_LK_M8.wav
# Moved: M10_B3_CW88_M3.wav
# Moved: M10_B2_C8_M4.wav
# Moved: M10_B2_D8_M5.wav
# Moved: M10_B3_UW51_M6.wav
# Moved: M10_B2_UW17_M7.wav
# Moved: M10_B2_UW37_M6.wav
# Moved: M10_B2_UW3_M3.wav
# Moved: M10_B3_UW70_M7.wav
# Moved: M10_B1_LP_M5.wav
# Moved: M10_B1_UW3_M5.wav
# Moved: M10_B2_UW9_M3.wav
# Moved: M10_B3_LQ_M8.wav
# Moved: M10_B3_UW78_M7.wav
# Moved: M10_B3_CW31_M8.wav
# Moved: M10_B2_UW86_M6.wav
# Moved: M10_B3_UW53_M6.wav
# Moved: M10_B1_C9_M2.wav
# Moved: M10_B3_CW32_M8.wav
# Moved: M10_B2_UW31_M2.wav
# Moved: M10_B2_CW48_M2.wav
# Moved: M10_B2_UW54_M7.wav
# Moved: M10_B3_CW49_M7.wav
# Moved: M10_B1_UW42_M3.wav
# Moved: M10_B3_UW73_M8.wav
# Moved: M10_B2_LR_M5.wav
# Moved: M10_B1_CW31_M6.wav
# Moved: M10_B1_UW46_M4.wav
# Moved: M10_B3_UW43_M5.wav
# Moved: M10_B1_CW14_M6.wav
# Moved: M10_B1_UW64_M8.wav
# Moved: M10_B1_UW43_M7.wav
# Moved: M10_B3_UW16_M6.wav
# Moved: M10_B1_LE_M5.wav
# Moved: M10_B1_LJ_M3.wav
# Moved: M10_B1_UW14_M7.wav
# Moved: M10_B2_LN_M8.wav
# Moved: M10_B2_CW31_M7.wav
# Moved: M10_B1_CW21_M8.wav
# Moved: M10_B1_CW12_M7.wav
# Moved: M10_B3_CW90_M3.wav
# Moved: M10_B2_UW70_M6.wav
# Moved: M10_B3_UW24_M2.wav
# Moved: M10_B3_UW92_M3.wav
# Moved: M10_B1_UW54_M8.wav
# Moved: M10_B3_C9_M7.wav
# Moved: M10_B3_CW11_M4.wav
# Moved: M10_B3_CW18_M3.wav
# Moved: M10_B3_CW6_M6.wav
# Moved: M10_B2_UW97_M2.wav
# Moved: M10_B3_CW78_M5.wav
# Moved: M10_B2_UW56_M4.wav
# Moved: M10_B2_CW64_M4.wav
# Moved: M10_B1_CW9_M4.wav
# Moved: M10_B1_UW83_M6.wav
# Moved: M10_B2_CW67_M4.wav
# Moved: M10_B2_UW82_M3.wav
# Moved: M10_B1_CW22_M3.wav
# Moved: M10_B1_LB_M4.wav
# Moved: M10_B3_CW21_M8.wav
# Moved: M10_B3_C14_M2.wav
# Moved: M10_B1_CW58_M3.wav
# Moved: M10_B3_UW28_M8.wav
# Moved: M10_B3_LA_M5.wav
# Moved: M10_B1_C10_M4.wav
# Moved: M10_B3_LC_M4.wav
# Moved: M10_B2_UW22_M4.wav
# Moved: M10_B1_UW7_M5.wav
# Moved: M10_B3_LI_M6.wav
# Moved: M10_B2_UW73_M2.wav
# Moved: M10_B3_CW6_M7.wav
# Moved: M10_B1_CW64_M6.wav
# Moved: M10_B1_UW28_M2.wav
# Moved: M10_B1_CW46_M2.wav
# Moved: M10_B2_CW95_M2.wav
# Moved: M10_B2_UW9_M5.wav
# Moved: M10_B2_D6_M5.wav
# Moved: M10_B1_LB_M5.wav
# Moved: M10_B2_CW57_M3.wav
# Moved: M10_B3_CW29_M7.wav
# Moved: M10_B2_UW89_M4.wav
# Moved: M10_B3_UW27_M4.wav
# Moved: M10_B2_UW48_M7.wav
# Moved: M10_B3_CW17_M6.wav
# Moved: M10_B3_CW43_M4.wav
# Moved: M10_B1_UW73_M4.wav
# Moved: M10_B3_LY_M3.wav
# Moved: M10_B3_CW45_M4.wav
# Moved: M10_B1_D9_M4.wav
# Moved: M10_B1_CW29_M5.wav
# Moved: M10_B2_UW93_M3.wav
# Moved: M10_B1_C2_M7.wav
# Moved: M10_B3_LH_M2.wav
# Moved: M10_B1_UW13_M8.wav
# Moved: M10_B3_C5_M8.wav
# Moved: M10_B3_C11_M4.wav
# Moved: M10_B1_LL_M8.wav
# Moved: M10_B3_UW83_M3.wav
# Moved: M10_B1_D2_M7.wav
# Moved: M10_B1_CW92_M7.wav
# Moved: M10_B2_D8_M8.wav
# Moved: M10_B2_UW88_M4.wav
# Moved: M10_B1_CW71_M6.wav
# Moved: M10_B1_CW10_M3.wav
# Moved: M10_B2_UW99_M5.wav
# Moved: M10_B3_CW40_M3.wav
# Moved: M10_B2_LJ_M5.wav
# Moved: M10_B2_C14_M5.wav
# Moved: M10_B2_LY_M8.wav
# Moved: M10_B2_UW79_M3.wav
# Moved: M10_B2_CW95_M4.wav
# Moved: M10_B1_CW16_M6.wav
# Moved: M10_B1_UW5_M2.wav
# Moved: M10_B1_LQ_M4.wav
# Moved: M10_B3_LI_M2.wav
# Moved: M10_B3_CW49_M6.wav
# Moved: M10_B1_CW30_M7.wav
# Moved: M10_B2_CW84_M8.wav
# Moved: M10_B2_UW62_M8.wav
# Moved: M10_B1_CW83_M2.wav
# Moved: M10_B2_UW90_M3.wav
# Moved: M10_B1_UW10_M4.wav
# Moved: M10_B1_UW46_M2.wav
# Moved: M10_B2_UW30_M8.wav
# Moved: M10_B3_UW53_M7.wav
# Moved: M10_B3_D0_M4.wav
# Moved: M10_B3_CW92_M3.wav
# Moved: M10_B2_C15_M6.wav
# Moved: M10_B1_CW99_M2.wav
# Moved: M10_B2_C10_M5.wav
# Moved: M10_B1_CW96_M2.wav
# Moved: M10_B1_CW14_M5.wav
# Moved: M10_B2_UW46_M3.wav
# Moved: M10_B3_UW36_M2.wav
# Moved: M10_B1_CW24_M3.wav
# Moved: M10_B3_UW64_M6.wav
# Moved: M10_B1_CW81_M4.wav
# Moved: M10_B2_UW49_M5.wav
# Moved: M10_B2_CW33_M2.wav
# Moved: M10_B2_LU_M5.wav
# Moved: M10_B1_UW46_M7.wav
# Moved: M10_B3_CW19_M5.wav
# Moved: M10_B3_UW71_M8.wav
# Moved: M10_B1_CW76_M8.wav
# Moved: M10_B2_UW35_M8.wav
# Moved: M10_B3_C12_M6.wav
# Moved: M10_B1_C12_M6.wav
# Moved: M10_B3_CW75_M2.wav
# Moved: M10_B3_CW32_M3.wav
# Moved: M10_B1_C8_M6.wav
# Moved: M10_B3_LJ_M7.wav
# Moved: M10_B2_UW30_M5.wav
# Moved: M10_B2_CW46_M3.wav
# Moved: M10_B2_LC_M7.wav
# Moved: M10_B3_CW34_M6.wav
# Moved: M10_B2_CW89_M4.wav
# Moved: M10_B3_UW47_M4.wav
# Moved: M10_B3_UW17_M8.wav
# Moved: M10_B1_LM_M4.wav
# Moved: M10_B1_CW57_M8.wav
# Moved: M10_B1_CW51_M3.wav
# Moved: M10_B3_UW48_M6.wav
# Moved: M10_B3_LK_M3.wav
# Moved: M10_B3_UW46_M8.wav
# Moved: M10_B1_CW72_M5.wav
# Moved: M10_B3_UW16_M2.wav
# Moved: M10_B3_UW49_M4.wav
# Moved: M10_B3_CW46_M5.wav
# Moved: M10_B1_D7_M7.wav
# Moved: M10_B1_UW73_M8.wav
# Moved: M10_B2_CW51_M5.wav
# Moved: M10_B3_CW8_M6.wav
# Moved: M10_B2_UW29_M2.wav
# Moved: M10_B2_CW50_M4.wav
# Moved: M10_B1_UW88_M2.wav
# Moved: M10_B1_CW14_M3.wav
# Moved: M10_B1_CW13_M7.wav
# Moved: M10_B1_CW79_M6.wav
# Moved: M10_B1_CW67_M3.wav
# Moved: M10_B1_LC_M2.wav
# Moved: M10_B3_CW67_M5.wav
# Moved: M10_B1_UW21_M5.wav
# Moved: M10_B2_UW43_M4.wav
# Moved: M10_B1_CW65_M2.wav
# Moved: M10_B2_CW84_M6.wav
# Moved: M10_B2_LI_M3.wav
# Moved: M10_B2_CW78_M2.wav
# Moved: M10_B3_C3_M2.wav
# Moved: M10_B3_C15_M8.wav
# Moved: M10_B3_CW20_M4.wav
# Moved: M10_B2_LE_M7.wav
# Moved: M10_B1_CW8_M8.wav
# Moved: M10_B3_CW78_M6.wav
# Moved: M10_B1_UW95_M7.wav
# Moved: M10_B2_CW89_M8.wav
# Moved: M10_B3_UW98_M6.wav
# Moved: M10_B2_UW16_M6.wav
# Moved: M10_B1_CW83_M4.wav
# Moved: M10_B1_CW1_M5.wav
# Moved: M10_B3_UW18_M6.wav
# Moved: M10_B1_C2_M4.wav
# Moved: M10_B3_CW26_M2.wav
# Moved: M10_B1_D5_M2.wav
# Moved: M10_B2_C4_M5.wav
# Moved: M10_B1_CW9_M3.wav
# Moved: M10_B1_UW92_M5.wav
# Moved: M10_B3_UW76_M7.wav
# Moved: M10_B1_UW14_M2.wav
# Moved: M10_B1_LB_M8.wav
# Moved: M10_B1_C5_M6.wav
# Moved: M10_B3_LR_M7.wav
# Moved: M10_B1_CW76_M6.wav
# Moved: M10_B1_UW85_M3.wav
# Moved: M10_B1_CW6_M5.wav
# Moved: M10_B3_CW92_M7.wav
# Moved: M10_B1_C2_M2.wav
# Moved: M10_B2_CW19_M7.wav
# Moved: M10_B3_CW15_M7.wav
# Moved: M10_B1_C18_M4.wav
# Moved: M10_B2_CW55_M2.wav
# Moved: M10_B2_UW65_M4.wav
# Moved: M10_B2_CW18_M2.wav
# Moved: M10_B3_CW77_M4.wav
# Moved: M10_B3_UW13_M8.wav
# Moved: M10_B1_UW12_M3.wav
# Moved: M10_B1_UW25_M5.wav
# Moved: M10_B2_CW12_M3.wav
# Moved: M10_B2_CW57_M7.wav
# Moved: M10_B1_C7_M7.wav
# Moved: M10_B2_UW77_M8.wav
# Moved: M10_B1_UW85_M8.wav
# Moved: M10_B2_UW33_M4.wav
# Moved: M10_B1_UW54_M4.wav
# Moved: M10_B3_CW39_M3.wav
# Moved: M10_B1_UW62_M7.wav
# Moved: M10_B3_C18_M3.wav
# Moved: M10_B2_UW75_M3.wav
# Moved: M10_B3_CW97_M7.wav
# Moved: M10_B1_LH_M5.wav
# Moved: M10_B2_C14_M7.wav
# Moved: M10_B2_CW91_M5.wav
# Moved: M10_B2_CW73_M2.wav
# Moved: M10_B3_C9_M3.wav
# Moved: M10_B1_CW70_M6.wav
# Moved: M10_B3_LX_M2.wav
# Moved: M10_B3_UW63_M7.wav
# Moved: M10_B3_CW67_M4.wav
# Moved: M10_B1_CW78_M5.wav
# Moved: M10_B3_UW79_M2.wav
# Moved: M10_B1_CW28_M7.wav
# Moved: M10_B1_C16_M3.wav
# Moved: M10_B3_CW93_M4.wav
# Moved: M10_B1_CW94_M3.wav
# Moved: M10_B3_CW93_M7.wav
# Moved: M10_B3_UW33_M6.wav
# Moved: M10_B1_CW87_M2.wav
# Moved: M10_B2_UW8_M3.wav
# Moved: M10_B2_D4_M4.wav
# Moved: M10_B1_UW49_M8.wav
# Moved: M10_B3_UW53_M3.wav
# Moved: M10_B2_CW83_M3.wav
# Moved: M10_B2_UW35_M2.wav
# Moved: M10_B2_CW81_M5.wav
# Moved: M10_B2_CW74_M2.wav
# Moved: M10_B2_UW39_M4.wav
# Moved: M10_B1_LJ_M2.wav
# Moved: M10_B1_CW31_M5.wav
# Moved: M10_B1_D0_M5.wav
# Moved: M10_B3_UW41_M5.wav
# Moved: M10_B1_UW17_M8.wav
# Moved: M10_B3_UW56_M2.wav
# Moved: M10_B2_C19_M2.wav
# Moved: M10_B1_UW80_M8.wav
# Moved: M10_B1_UW72_M4.wav
# Moved: M10_B2_UW82_M7.wav
# Moved: M10_B3_CW5_M4.wav
# Moved: M10_B1_CW76_M7.wav
# Moved: M10_B1_UW92_M8.wav
# Moved: M10_B3_UW57_M4.wav
# Moved: M10_B2_UW67_M6.wav
# Moved: M10_B1_C6_M7.wav
# Moved: M10_B2_CW91_M7.wav
# Moved: M10_B2_C15_M3.wav
# Moved: M10_B1_CW22_M6.wav
# Moved: M10_B1_CW20_M3.wav
# Moved: M10_B3_LW_M6.wav
# Moved: M10_B2_D5_M3.wav
# Moved: M10_B1_CW52_M3.wav
# Moved: M10_B1_CW22_M7.wav
# Moved: M10_B3_CW66_M3.wav
# Moved: M10_B3_C1_M3.wav
# Moved: M10_B3_CW13_M4.wav
# Moved: M10_B2_UW97_M6.wav
# Moved: M10_B1_UW38_M5.wav
# Moved: M10_B3_UW72_M6.wav
# Moved: M10_B2_C18_M4.wav
# Moved: M10_B1_UW4_M6.wav
# Moved: M10_B2_CW17_M6.wav
# Moved: M10_B2_UW33_M7.wav
# Moved: M10_B1_CW93_M8.wav
# Moved: M10_B3_CW91_M4.wav
# Moved: M10_B1_CW53_M3.wav
# Moved: M10_B2_UW32_M3.wav
# Moved: M10_B3_UW29_M5.wav
# Moved: M10_B2_UW11_M8.wav
# Moved: M10_B1_CW67_M8.wav
# Moved: M10_B3_UW23_M4.wav
# Moved: M10_B2_CW39_M6.wav
# Moved: M10_B2_CW29_M4.wav
# Moved: M10_B1_UW42_M2.wav
# Moved: M10_B1_CW11_M4.wav
# Moved: M10_B2_C15_M4.wav
# Moved: M10_B3_UW97_M3.wav
# Moved: M10_B3_CW82_M3.wav
# Moved: M10_B2_UW1_M7.wav
# Moved: M10_B2_UW81_M5.wav
# Moved: M10_B1_C14_M2.wav
# Moved: M10_B2_LT_M8.wav
# Moved: M10_B2_UW6_M3.wav
# Moved: M10_B3_UW93_M4.wav
# Moved: M10_B1_UW2_M8.wav
# Moved: M10_B1_UW89_M8.wav
# Moved: M10_B1_UW74_M6.wav
# Moved: M10_B1_CW22_M8.wav
# Moved: M10_B1_UW42_M4.wav
# Moved: M10_B3_UW40_M5.wav
# Moved: M10_B3_CW28_M8.wav
# Moved: M10_B1_C4_M6.wav
# Moved: M10_B1_CW9_M2.wav
# Moved: M10_B2_C19_M7.wav
# Moved: M10_B2_CW35_M7.wav
# Moved: M10_B2_UW17_M3.wav
# Moved: M10_B1_CW86_M7.wav
# Moved: M10_B3_UW85_M7.wav
# Moved: M10_B2_CW39_M5.wav
# Moved: M10_B3_D7_M7.wav
# Moved: M10_B2_C8_M3.wav
# Moved: M10_B2_LQ_M5.wav
# Moved: M10_B3_C7_M3.wav
# Moved: M10_B2_CW55_M6.wav
# Moved: M10_B1_CW20_M2.wav
# Moved: M10_B1_CW24_M8.wav
# Moved: M10_B1_LZ_M4.wav
# Moved: M10_B1_C17_M3.wav
# Moved: M10_B3_CW55_M6.wav
# Moved: M10_B1_UW72_M5.wav
# Moved: M10_B3_UW44_M3.wav
# Moved: M10_B1_UW11_M6.wav
# Moved: M10_B3_UW53_M4.wav
# Moved: M10_B1_LZ_M5.wav
# Moved: M10_B1_CW77_M2.wav
# Moved: M10_B2_LW_M8.wav
# Moved: M10_B3_CW19_M2.wav
# Moved: M10_B2_UW86_M5.wav
# Moved: M10_B1_C19_M3.wav
# Moved: M10_B3_CW87_M5.wav
# Moved: M10_B1_LK_M6.wav
# Moved: M10_B2_UW79_M2.wav
# Moved: M10_B1_UW89_M3.wav
# Moved: M10_B1_D1_M7.wav
# Moved: M10_B3_CW41_M5.wav
# Moved: M10_B1_UW85_M2.wav
# Moved: M10_B2_UW79_M7.wav
# Moved: M10_B3_CW99_M3.wav
# Moved: M10_B1_CW93_M7.wav
# Moved: M10_B1_CW82_M5.wav
# Moved: M10_B1_CW68_M4.wav
# Moved: M10_B1_UW93_M5.wav
# Moved: M10_B3_CW12_M3.wav
# Moved: M10_B3_UW52_M4.wav
# Moved: M10_B2_UW38_M6.wav
# Moved: M10_B1_LE_M3.wav
# Moved: M10_B3_CW16_M8.wav
# Moved: M10_B1_UW44_M5.wav
# Moved: M10_B2_C6_M2.wav
# Moved: M10_B1_D1_M8.wav
# Moved: M10_B1_LH_M2.wav
# Moved: M10_B2_UW78_M3.wav
# Moved: M10_B2_LN_M2.wav
# Moved: M10_B3_UW26_M4.wav
# Moved: M10_B1_UW3_M3.wav
# Moved: M10_B1_CW96_M4.wav
# Moved: M10_B2_C13_M4.wav
# Moved: M10_B3_CW51_M7.wav
# Moved: M10_B3_D9_M8.wav
# Moved: M10_B2_LQ_M2.wav
# Moved: M10_B2_UW5_M7.wav
# Moved: M10_B3_UW18_M3.wav
# Moved: M10_B2_UW12_M5.wav
# Moved: M10_B2_UW89_M5.wav
# Moved: M10_B3_UW53_M5.wav
# Moved: M10_B2_CW15_M7.wav
# Moved: M10_B3_CW78_M4.wav
# Moved: M10_B2_CW90_M2.wav
# Moved: M10_B1_CW94_M2.wav
# Moved: M10_B1_UW62_M5.wav
# Moved: M10_B2_CW5_M2.wav
# Moved: M10_B3_CW76_M6.wav
# Moved: M10_B3_UW51_M4.wav
# Moved: M10_B2_D9_M4.wav
# Moved: M10_B2_CW62_M4.wav
# Moved: M10_B2_CW85_M6.wav
# Moved: M10_B2_UW91_M7.wav
# Moved: M10_B3_CW92_M5.wav
# Moved: M10_B2_UW32_M2.wav
# Moved: M10_B3_UW19_M5.wav
# Moved: M10_B3_CW5_M5.wav
# Moved: M10_B1_CW31_M2.wav
# Moved: M10_B2_UW36_M5.wav
# Moved: M10_B3_LD_M8.wav
# Moved: M10_B2_UW92_M2.wav
# Moved: M10_B3_C9_M4.wav
# Moved: M10_B3_CW51_M6.wav
# Moved: M10_B1_CW89_M5.wav
# Moved: M10_B3_CW21_M4.wav
# Moved: M10_B3_UW89_M3.wav
# Moved: M10_B3_CW76_M5.wav
# Moved: M10_B3_UW30_M2.wav
# Moved: M10_B2_CW24_M8.wav
# Moved: M10_B1_UW70_M4.wav
# Moved: M10_B3_UW79_M5.wav
# Moved: M10_B3_LK_M6.wav
# Moved: M10_B1_UW77_M4.wav
# Moved: M10_B2_LB_M3.wav
# Moved: M10_B1_CW84_M2.wav
# Moved: M10_B1_UW31_M3.wav
# Moved: M10_B3_UW39_M7.wav
# Moved: M10_B1_UW63_M8.wav
# Moved: M10_B1_CW74_M3.wav
# Moved: M10_B3_UW14_M8.wav
# Moved: M10_B2_C2_M6.wav
# Moved: M10_B1_UW61_M8.wav
# Moved: M10_B1_LA_M7.wav
# Moved: M10_B3_UW56_M4.wav
# Moved: M10_B1_UW30_M6.wav
# Moved: M10_B2_CW54_M7.wav
# Moved: M10_B3_CW100_M6.wav
# Moved: M10_B2_CW77_M3.wav
# Moved: M10_B2_UW51_M6.wav
# Moved: M10_B3_UW64_M5.wav
# Moved: M10_B3_UW89_M4.wav
# Moved: M10_B3_UW23_M5.wav
# Moved: M10_B2_C8_M6.wav
# Moved: M10_B3_UW22_M8.wav
# Moved: M10_B3_UW65_M8.wav
# Moved: M10_B2_CW11_M5.wav
# Moved: M10_B2_CW92_M3.wav
# Moved: M10_B3_UW69_M2.wav
# Moved: M10_B1_C16_M5.wav
# Moved: M10_B3_CW85_M3.wav
# Moved: M10_B2_UW26_M4.wav
# Moved: M10_B3_LY_M8.wav
# Moved: M10_B3_LT_M7.wav
# Moved: M10_B2_CW30_M8.wav
# Moved: M10_B3_UW62_M2.wav
# Moved: M10_B3_UW85_M6.wav
# Moved: M10_B2_CW95_M5.wav
# Moved: M10_B3_LM_M4.wav
# Moved: M10_B2_CW76_M5.wav
# Moved: M10_B1_CW69_M8.wav
# Moved: M10_B1_UW12_M6.wav
# Moved: M10_B1_UW4_M3.wav
# Moved: M10_B2_UW100_M6.wav
# Moved: M10_B2_LB_M7.wav
# Moved: M10_B3_CW49_M8.wav
# Moved: M10_B1_LW_M7.wav
# Moved: M10_B2_CW41_M6.wav
# Moved: M10_B2_UW93_M7.wav
# Moved: M10_B1_UW91_M3.wav
# Moved: M10_B2_UW88_M8.wav
# Moved: M10_B3_LA_M3.wav
# Moved: M10_B2_CW50_M6.wav
# Moved: M10_B2_CW80_M3.wav
# Moved: M10_B2_UW91_M2.wav
# Moved: M10_B3_CW95_M6.wav
# Moved: M10_B2_LK_M3.wav
# Moved: M10_B3_UW100_M5.wav
# Moved: M10_B1_UW55_M2.wav
# Moved: M10_B2_CW74_M7.wav
# Moved: M10_B2_UW31_M8.wav
# Moved: M10_B1_UW16_M2.wav
# Moved: M10_B2_C18_M3.wav
# Moved: M10_B3_UW87_M5.wav
# Moved: M10_B1_UW37_M4.wav
# Moved: M10_B3_C4_M6.wav
# Moved: M10_B1_CW91_M3.wav
# Moved: M10_B3_UW18_M2.wav
# Moved: M10_B2_CW88_M3.wav
# Moved: M10_B1_CW35_M5.wav
# Moved: M10_B3_D0_M8.wav
# Moved: M10_B2_UW58_M2.wav
# Moved: M10_B3_UW22_M3.wav
# Moved: M10_B3_CW94_M7.wav
# Moved: M10_B1_CW40_M7.wav
# Moved: M10_B3_UW86_M6.wav
# Moved: M10_B3_UW70_M2.wav
# Moved: M10_B3_CW38_M5.wav
# Moved: M10_B3_LQ_M5.wav
# Moved: M10_B2_CW4_M8.wav
# Moved: M10_B3_C12_M8.wav
# Moved: M10_B2_CW86_M8.wav
# Moved: M10_B1_LX_M7.wav
# Moved: M10_B2_CW36_M5.wav
# Moved: M10_B3_UW63_M6.wav
# Moved: M10_B1_UW40_M6.wav
# Moved: M10_B3_UW97_M2.wav
# Moved: M10_B2_CW100_M7.wav
# Moved: M10_B1_UW52_M7.wav
# Moved: M10_B2_UW29_M4.wav
# Moved: M10_B1_LC_M3.wav
# Moved: M10_B1_UW29_M4.wav
# Moved: M10_B2_CW70_M3.wav
# Moved: M10_B3_CW13_M2.wav
# Moved: M10_B3_CW10_M2.wav
# Moved: M10_B1_UW63_M4.wav
# Moved: M10_B2_C13_M2.wav
# Moved: M10_B1_UW39_M8.wav
# Moved: M10_B3_CW88_M2.wav
# Moved: M10_B2_UW25_M6.wav
# Moved: M10_B2_UW40_M7.wav
# Moved: M10_B3_UW77_M8.wav
# Moved: M10_B3_CW35_M5.wav
# Moved: M10_B3_UW51_M2.wav
# Moved: M10_B1_UW13_M6.wav
# Moved: M10_B2_UW71_M7.wav
# Moved: M10_B1_CW83_M8.wav
# Moved: M10_B2_UW91_M3.wav
# Moved: M10_B3_UW43_M2.wav
# Moved: M10_B3_C6_M8.wav
# Moved: M10_B3_CW32_M4.wav
# Moved: M10_B3_UW18_M5.wav
# Moved: M10_B1_UW84_M2.wav
# Moved: M10_B2_UW54_M5.wav
# Moved: M10_B2_CW9_M2.wav
# Moved: M10_B1_C2_M8.wav
# Moved: M10_B1_CW48_M2.wav
# Moved: M10_B1_CW92_M8.wav
# Moved: M10_B1_LP_M6.wav
# Moved: M10_B2_CW16_M5.wav
# Moved: M10_B2_CW76_M8.wav
# Moved: M10_B1_CW14_M8.wav
# Moved: M10_B3_CW62_M8.wav
# Moved: M10_B2_CW20_M7.wav
# Moved: M10_B3_LH_M7.wav
# Moved: M10_B3_CW87_M8.wav
# Moved: M10_B2_C7_M6.wav
# Moved: M10_B1_UW73_M7.wav
# Moved: M10_B1_UW39_M7.wav
# Moved: M10_B2_CW89_M5.wav
# Moved: M10_B3_CW77_M2.wav
# Moved: M10_B1_C12_M4.wav
# Moved: M10_B3_CW26_M7.wav
# Moved: M10_B3_LD_M3.wav
# Moved: M10_B3_LM_M5.wav
# Moved: M10_B1_D5_M5.wav
# Moved: M10_B3_UW8_M2.wav
# Moved: M10_B1_CW45_M5.wav
# Moved: M10_B1_CW92_M6.wav
# Moved: M10_B1_CW54_M5.wav
# Moved: M10_B3_UW71_M4.wav
# Moved: M10_B2_UW18_M2.wav
# Moved: M10_B1_CW6_M7.wav
# Moved: M10_B3_UW83_M6.wav
# Moved: M10_B3_CW96_M4.wav
# Moved: M10_B3_C17_M4.wav
# Moved: M10_B2_CW82_M7.wav
# Moved: M10_B3_UW88_M8.wav
# Moved: M10_B1_CW72_M4.wav
# Moved: M10_B2_CW3_M3.wav
# Moved: M10_B1_C19_M6.wav
# Moved: M10_B1_UW5_M7.wav
# Moved: M10_B2_D7_M5.wav
# Moved: M10_B1_LD_M6.wav
# Moved: M10_B3_CW60_M4.wav
# Moved: M10_B1_UW48_M7.wav
# Moved: M10_B2_UW77_M4.wav
# Moved: M10_B2_CW2_M3.wav
# Moved: M10_B2_UW20_M4.wav
# Moved: M10_B1_UW47_M4.wav
# Moved: M10_B1_C1_M7.wav
# Moved: M10_B2_CW73_M5.wav
# Moved: M10_B2_LC_M5.wav
# Moved: M10_B2_CW14_M5.wav
# Moved: M10_B1_C13_M5.wav
# Moved: M10_B2_C9_M7.wav
# Moved: M10_B3_CW28_M2.wav
# Moved: M10_B1_UW34_M6.wav
# Moved: M10_B1_CW59_M7.wav
# Moved: M10_B2_C14_M6.wav
# Moved: M10_B2_UW9_M2.wav
# Moved: M10_B1_CW1_M4.wav
# Moved: M10_B3_UW17_M5.wav
# Moved: M10_B2_UW73_M4.wav
# Moved: M10_B3_LD_M6.wav
# Moved: M10_B2_CW49_M2.wav
# Moved: M10_B3_CW13_M8.wav
# Moved: M10_B1_C4_M2.wav
# Moved: M10_B3_UW82_M7.wav
# Moved: M10_B1_CW59_M3.wav
# Moved: M10_B3_CW23_M8.wav
# Moved: M10_B2_C19_M8.wav
# Moved: M10_B2_UW65_M3.wav
# Moved: M10_B1_UW32_M7.wav
# Moved: M10_B3_UW72_M4.wav
# Moved: M10_B1_LM_M7.wav
# Moved: M10_B2_UW6_M8.wav
# Moved: M10_B2_LK_M6.wav
# Moved: M10_B2_CW34_M8.wav
# Moved: M10_B2_CW45_M6.wav
# Moved: M10_B3_CW76_M4.wav
# Moved: M10_B1_C13_M7.wav
# Moved: M10_B1_UW45_M7.wav
# Moved: M10_B3_CW28_M7.wav
# Moved: M10_B3_UW42_M4.wav
# Moved: M10_B3_LO_M6.wav
# Moved: M10_B2_CW57_M4.wav
# Moved: M10_B2_CW72_M5.wav
# Moved: M10_B2_UW16_M2.wav
# Moved: M10_B3_CW95_M3.wav
# Moved: M10_B1_CW95_M2.wav
# Moved: M10_B1_UW72_M3.wav
# Moved: M10_B2_CW12_M2.wav
# Moved: M10_B2_UW10_M6.wav
# Moved: M10_B3_UW98_M2.wav
# Moved: M10_B1_LD_M7.wav
# Moved: M10_B2_UW56_M3.wav
# Moved: M10_B3_CW72_M5.wav
# Moved: M10_B2_CW60_M3.wav
# Moved: M10_B3_C16_M5.wav
# Moved: M10_B2_CW53_M5.wav
# Moved: M10_B3_UW1_M3.wav
# Moved: M10_B2_UW38_M7.wav
# Moved: M10_B2_UW89_M2.wav
# Moved: M10_B1_CW39_M2.wav
# Moved: M10_B2_CW67_M2.wav
# Moved: M10_B2_CW65_M2.wav
# Moved: M10_B3_D8_M3.wav
# Moved: M10_B1_UW8_M7.wav
# Moved: M10_B3_UW55_M4.wav
# Moved: M10_B1_UW2_M7.wav
# Moved: M10_B2_CW10_M7.wav
# Moved: M10_B2_UW70_M7.wav
# Moved: M10_B2_UW47_M4.wav
# Moved: M10_B3_CW36_M2.wav
# Moved: M10_B3_UW49_M5.wav
# Moved: M10_B3_CW2_M7.wav
# Moved: M10_B2_CW96_M6.wav
# Moved: M10_B1_LF_M8.wav
# Moved: M10_B2_C16_M5.wav
# Moved: M10_B2_CW49_M8.wav
# Moved: M10_B2_CW83_M7.wav
# Moved: M10_B2_CW100_M2.wav
# Moved: M10_B3_UW40_M6.wav
# Moved: M10_B3_C16_M2.wav
# Moved: M10_B1_D3_M6.wav
# Moved: M10_B1_LJ_M4.wav
# Moved: M10_B3_UW80_M8.wav
# Moved: M10_B3_C16_M6.wav
# Moved: M10_B2_UW43_M8.wav
# Moved: M10_B1_CW21_M5.wav
# Moved: M10_B1_LY_M3.wav
# Moved: M10_B3_CW27_M7.wav
# Moved: M10_B3_UW48_M4.wav
# Moved: M10_B1_LS_M6.wav
# Moved: M10_B3_CW12_M6.wav
# Moved: M10_B1_LT_M2.wav
# Moved: M10_B3_CW10_M6.wav
# Moved: M10_B1_LX_M3.wav
# Moved: M10_B2_UW22_M6.wav
# Moved: M10_B1_CW83_M7.wav
# Moved: M10_B3_UW65_M7.wav
# Moved: M10_B3_UW53_M8.wav
# Moved: M10_B1_CW69_M4.wav
# Moved: M10_B1_LW_M6.wav
# Moved: M10_B2_CW37_M5.wav
# Moved: M10_B1_CW64_M3.wav
# Moved: M10_B3_UW38_M7.wav
# Moved: M10_B1_UW76_M2.wav
# Moved: M10_B3_CW25_M7.wav
# Moved: M10_B1_D9_M2.wav
# Moved: M10_B2_LJ_M8.wav
# Moved: M10_B3_UW30_M3.wav
# Moved: M10_B1_CW26_M4.wav
# Moved: M10_B3_UW89_M6.wav
# Moved: M10_B1_LH_M6.wav
# Moved: M10_B2_CW4_M7.wav
# Moved: M10_B1_CW87_M8.wav
# Moved: M10_B2_LO_M2.wav
# Moved: M10_B1_C15_M5.wav
# Moved: M10_B3_CW80_M5.wav
# Moved: M10_B3_CW27_M8.wav
# Moved: M10_B3_UW15_M2.wav
# Moved: M10_B3_CW95_M2.wav
# Moved: M10_B1_LU_M4.wav
# Moved: M10_B1_UW99_M6.wav
# Moved: M10_B3_UW47_M5.wav
# Moved: M10_B2_UW54_M8.wav
# Moved: M10_B3_CW84_M3.wav
# Moved: M10_B1_CW28_M6.wav
# Moved: M10_B3_CW22_M6.wav
# Moved: M10_B1_CW35_M3.wav
# Moved: M10_B2_CW51_M4.wav
# Moved: M10_B2_CW22_M8.wav
# Moved: M10_B1_CW70_M5.wav
# Moved: M10_B3_CW56_M7.wav
# Moved: M10_B2_C15_M8.wav
# Moved: M10_B3_UW3_M7.wav
# Moved: M10_B1_UW99_M3.wav
# Moved: M10_B2_CW16_M7.wav
# Moved: M10_B3_CW2_M4.wav
# Moved: M10_B1_UW77_M2.wav
# Moved: M10_B1_CW77_M6.wav
# Moved: M10_B1_CW42_M8.wav
# Moved: M10_B3_LE_M5.wav
# Moved: M10_B1_CW10_M5.wav
# Moved: M10_B3_UW14_M6.wav
# Moved: M10_B3_CW39_M2.wav
# Moved: M10_B1_CW17_M4.wav
# Moved: M10_B3_UW68_M5.wav
# Moved: M10_B2_LU_M6.wav
# Moved: M10_B2_UW84_M5.wav
# Moved: M10_B2_UW60_M5.wav
# Moved: M10_B1_LI_M4.wav
# Moved: M10_B1_LA_M3.wav
# Moved: M10_B2_CW56_M5.wav
# Moved: M10_B1_CW32_M5.wav
# Moved: M10_B2_CW88_M7.wav
# Moved: M10_B1_CW99_M3.wav
# Moved: M10_B2_CW70_M2.wav
# Moved: M10_B1_UW19_M8.wav
# Moved: M10_B1_CW43_M6.wav
# Moved: M10_B2_UW10_M3.wav
# Moved: M10_B1_CW53_M2.wav
# Moved: M10_B3_CW68_M5.wav
# Moved: M10_B3_CW61_M8.wav
# Moved: M10_B3_CW34_M5.wav
# Moved: M10_B1_C17_M6.wav
# Moved: M10_B1_CW38_M6.wav
# Moved: M10_B2_CW73_M7.wav
# Moved: M10_B1_C15_M6.wav
# Moved: M10_B3_UW95_M3.wav
# Moved: M10_B3_LC_M2.wav
# Moved: M10_B1_C16_M4.wav
# Moved: M10_B2_CW59_M8.wav
# Moved: M10_B1_UW55_M5.wav
# Moved: M10_B3_UW19_M6.wav
# Moved: M10_B2_UW6_M2.wav
# Moved: M10_B3_UW32_M8.wav
# Moved: M10_B1_CW42_M2.wav
# Moved: M10_B3_UW53_M2.wav
# Moved: M10_B2_UW75_M2.wav
# Moved: M10_B3_UW80_M3.wav
# Moved: M10_B1_D9_M7.wav
# Moved: M10_B2_CW78_M7.wav
# Moved: M10_B2_UW97_M5.wav
# Moved: M10_B2_CW31_M2.wav
# Moved: M10_B3_CW70_M2.wav
# Moved: M10_B3_CW10_M5.wav
# Moved: M10_B2_UW19_M7.wav
# Moved: M10_B3_C9_M2.wav
# Moved: M10_B2_UW53_M5.wav
# Moved: M10_B2_CW79_M8.wav
# Moved: M10_B1_UW40_M2.wav
# Moved: M10_B2_CW59_M5.wav
# Moved: M10_B3_LG_M3.wav
# Moved: M10_B3_CW52_M5.wav
# Moved: M10_B2_UW51_M8.wav
# Moved: M10_B1_UW24_M8.wav
# Moved: M10_B2_UW75_M7.wav
# Moved: M10_B2_CW78_M5.wav
# Moved: M10_B1_UW31_M8.wav
# Moved: M10_B3_CW50_M7.wav
# Moved: M10_B1_CW36_M6.wav
# Moved: M10_B3_CW80_M8.wav
# Moved: M10_B3_CW79_M6.wav
# Moved: M10_B1_CW5_M8.wav
# Moved: M10_B2_LW_M6.wav
# Moved: M10_B1_CW25_M3.wav
# Moved: M10_B2_C8_M7.wav
# Moved: M10_B1_CW34_M5.wav
# Moved: M10_B1_CW41_M3.wav
# Moved: M10_B2_CW94_M7.wav
# Moved: M10_B2_UW35_M7.wav
# Moved: M10_B3_CW77_M3.wav
# Moved: M10_B2_CW72_M3.wav
# Moved: M10_B2_UW93_M6.wav
# Moved: M10_B1_UW15_M7.wav
# Moved: M10_B2_UW63_M2.wav
# Moved: M10_B3_CW17_M7.wav
# Moved: M10_B2_UW33_M2.wav
# Moved: M10_B3_UW51_M7.wav
# Moved: M10_B2_UW68_M5.wav
# Moved: M10_B1_CW21_M2.wav
# Moved: M10_B1_CW3_M2.wav
# Moved: M10_B3_CW42_M5.wav
# Moved: M10_B3_C19_M8.wav
# Moved: M10_B3_CW9_M5.wav
# Moved: M10_B2_UW85_M7.wav
# Moved: M10_B1_C6_M8.wav
# Moved: M10_B1_CW11_M7.wav
# Moved: M10_B3_C7_M5.wav
# Moved: M10_B1_CW27_M4.wav
# Moved: M10_B2_CW65_M3.wav
# Moved: M10_B1_UW77_M7.wav
# Moved: M10_B1_UW87_M4.wav
# Moved: M10_B2_UW53_M3.wav
# Moved: M10_B3_CW56_M8.wav
# Moved: M10_B2_CW96_M8.wav
# Moved: M10_B1_CW45_M3.wav
# Moved: M10_B2_UW69_M2.wav
# Moved: M10_B3_UW46_M6.wav
# Moved: M10_B1_LH_M8.wav
# Moved: M10_B1_CW15_M6.wav
# Moved: M10_B2_UW96_M5.wav
# Moved: M10_B1_LQ_M2.wav
# Moved: M10_B2_UW39_M6.wav
# Moved: M10_B2_CW34_M3.wav
# Moved: M10_B3_UW3_M8.wav
# Moved: M10_B1_CW98_M4.wav
# Moved: M10_B1_CW74_M4.wav
# Moved: M10_B3_UW45_M6.wav
# Moved: M10_B1_UW71_M2.wav
# Moved: M10_B3_UW99_M4.wav
# Moved: M10_B3_LL_M3.wav
# Moved: M10_B3_CW50_M5.wav
# Moved: M10_B1_UW98_M3.wav
# Moved: M10_B3_CW50_M2.wav
# Moved: M10_B3_CW16_M3.wav
# Moved: M10_B2_UW55_M6.wav
# Moved: M10_B2_UW22_M2.wav
# Moved: M10_B1_LS_M7.wav
# Moved: M10_B1_CW16_M5.wav
# Moved: M10_B3_CW8_M5.wav
# Moved: M10_B2_CW37_M2.wav
# Moved: M10_B1_CW49_M3.wav
# Moved: M10_B2_LR_M4.wav
# Moved: M10_B3_UW84_M2.wav
# Moved: M10_B2_CW26_M2.wav
# Moved: M10_B3_CW12_M8.wav
# Moved: M10_B1_LZ_M8.wav
# Moved: M10_B3_UW37_M7.wav
# Moved: M10_B3_CW22_M2.wav
# Moved: M10_B3_LR_M3.wav
# Moved: M10_B1_UW53_M6.wav
# Moved: M10_B1_UW89_M5.wav
# Moved: M10_B3_CW49_M5.wav
# Moved: M10_B2_CW8_M2.wav
# Moved: M10_B3_CW44_M8.wav
# Moved: M10_B1_CW7_M5.wav
# Moved: M10_B1_UW24_M3.wav
# Moved: M10_B2_CW33_M5.wav
# Moved: M10_B2_CW9_M4.wav
# Moved: M10_B3_LP_M6.wav
# Moved: M10_B3_UW69_M8.wav
# Moved: M10_B1_CW9_M5.wav
# Moved: M10_B3_C6_M6.wav
# Moved: M10_B1_UW92_M6.wav
# Moved: M10_B1_LB_M3.wav
# Moved: M10_B3_CW35_M7.wav
# Moved: M10_B2_CW1_M5.wav
# Moved: M10_B1_C15_M8.wav
# Moved: M10_B2_UW60_M7.wav
# Moved: M10_B3_UW3_M2.wav
# Moved: M10_B3_CW27_M5.wav
# Moved: M10_B3_LW_M5.wav
# Moved: M10_B2_CW76_M4.wav
# Moved: M10_B2_UW74_M2.wav
# Moved: M10_B1_CW94_M7.wav
# Moved: M10_B1_UW55_M7.wav
# Moved: M10_B1_CW16_M2.wav
# Moved: M10_B1_LM_M3.wav
# Moved: M10_B3_UW88_M5.wav
# Moved: M10_B2_UW50_M6.wav
# Total files moved: 1071

# %%
import pandas as pd
import os


# Assuming saveto is the directory where the CSV file is located
saveto = r"D:\Mtechs3\project\UASpeech_original_FM\UASpeech\audio\original\M10"
wavs = glob("{}/**/*.wav".format(saveto), recursive=True)
id_to_text = {}

# Load the CSV file into a pandas DataFrame, skipping the first row
csv_file_path = os.path.join(saveto, "dictionary_UASPEECH.csv")
df = pd.read_csv(csv_file_path, sep=',', header=None, names=['ID', 'Text'], skiprows=1)

# Create a dictionary with formatted keys and values
id_to_text = {row["Text"]: row["ID"] for _, row in df.iterrows()}

# %%
k=df.iloc[:,1]

# %%
def get_data(wavs, id_to_text, maxlen=50):
    """ returns mapping of audio paths and transcription texts """
    data = []
    for w in wavs:
        id = w.split("\\")[-1]
        for item in k:
            if item+"_" in id and len(id_to_text[item]) < maxlen:
                data.append({"audio": w, "text": id_to_text[item]})
                
    return data

# %%
class VectorizeChar:
    def __init__(self, max_len=50):
        self.vocab = (
            ["-", "#", "<", ">"]
            + [chr(i + 96) for i in range(1, 27)]
            + [" ", ".", ",", "?"]
        )
        self.max_len = max_len
        self.char_to_idx = {}
        for i, ch in enumerate(self.vocab):
            self.char_to_idx[ch] = i

    def __call__(self, text):
        text = text.lower()
        text = text[: self.max_len - 2]
        text = "<" + text + ">"
        pad_len = self.max_len - len(text)
        return [self.char_to_idx.get(ch, 1) for ch in text] + [0] * pad_len

    def get_vocabulary(self):
        return self.vocab

# %%
max_target_len = 200  # all transcripts in out data are < 200 characters
data = get_data(wavs, id_to_text, max_target_len)
vectorizer = VectorizeChar(max_target_len)

# %%
len(data)
# Out:
# 4284

# %%
def create_text_ds(data):
    texts = [_["text"] for _ in data]
    text_ds = [vectorizer(t) for t in texts]
    text_ds = tf.data.Dataset.from_tensor_slices(text_ds)
    return text_ds


def path_to_audio(path):
    # spectrogram using stft
    audio = tf.io.read_file(path)
    audio, _ = tf.audio.decode_wav(audio, 1)
    #print(audio)
    audio = tf.squeeze(audio, axis=-1)
    #print(audio)
    stfts = tf.signal.stft(audio, frame_length=200, frame_step=80, fft_length=256)
    x = tf.math.pow(tf.abs(stfts), 0.5)
    # normalisation
    means = tf.math.reduce_mean(x, 1, keepdims=True)
    stddevs = tf.math.reduce_std(x, 1, keepdims=True)
    x = (x - means) / stddevs
    audio_len = tf.shape(x)[0]
    # padding to 10 seconds
    pad_len = 2754
    paddings = tf.constant([[0, pad_len], [0, 0]])
    x = tf.pad(x, paddings, "CONSTANT")[:pad_len, :]
    return x


def create_audio_ds(data):
    flist = [_["audio"] for _ in data]
    audio_ds = tf.data.Dataset.from_tensor_slices(flist)
    audio_ds = audio_ds.map(
        path_to_audio, num_parallel_calls=tf.data.AUTOTUNE
    )
    return audio_ds


def create_tf_dataset(data, bs=4):
    audio_ds = create_audio_ds(data)
    text_ds = create_text_ds(data)
    ds = tf.data.Dataset.zip((audio_ds, text_ds))
    ds = ds.map(lambda x, y: {"source": x, "target": y})
    ds = ds.batch(bs)
    ds = ds.prefetch(tf.data.AUTOTUNE)
    return ds


split = int(len(data) * 0.99)
train_data = data[:split]
test_data = data[split:]
ds = create_tf_dataset(train_data, bs=64)
val_ds = create_tf_dataset(test_data, bs=4)

# %%
ds
# Out:
# <PrefetchDataset shapes: {source: (None, None, 129), target: (None, 200)}, types: {source: tf.float32, target: tf.int32}>

# %%
class TokenEmbedding(layers.Layer):
    def __init__(self, num_vocab=1000, maxlen=100, num_hid=64):
        super().__init__()
        self.emb = tf.keras.layers.Embedding(num_vocab, num_hid)
        self.pos_emb = layers.Embedding(input_dim=maxlen, output_dim=num_hid)

    def call(self, x):
        maxlen = tf.shape(x)[-1]
        x = self.emb(x)
        positions = tf.range(start=0, limit=maxlen, delta=1)
        positions = self.pos_emb(positions)
        return x + positions


class SpeechFeatureEmbedding(layers.Layer):
    def __init__(self, num_hid=64, maxlen=100):
        super().__init__()
        self.conv1 = tf.keras.layers.Conv1D(
            num_hid, 11, strides=2, padding="same", activation="relu"
        )
        self.conv2 = tf.keras.layers.Conv1D(
            num_hid, 11, strides=2, padding="same", activation="relu"
        )
        self.conv3 = tf.keras.layers.Conv1D(
            num_hid, 11, strides=2, padding="same", activation="relu"
        )
        self.pos_emb = layers.Embedding(input_dim=maxlen, output_dim=num_hid)

    def call(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        return self.conv3(x)

# %%
class TransformerEncoder(layers.Layer):
    def __init__(self, embed_dim, num_heads, feed_forward_dim, rate=0.1):
        super().__init__()
        self.att = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.ffn = keras.Sequential(
            [
                layers.Dense(feed_forward_dim, activation="relu"),
                layers.Dense(embed_dim),
            ]
        )
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = layers.Dropout(rate)
        self.dropout2 = layers.Dropout(rate)

    def call(self, inputs, training):
        attn_output = self.att(inputs, inputs)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output)

# %%
class TransformerDecoder(layers.Layer):
    def __init__(self, embed_dim, num_heads, feed_forward_dim, dropout_rate=0.1):
        super().__init__()
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm3 = layers.LayerNormalization(epsilon=1e-6)
        self.self_att = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim
        )
        self.enc_att = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.self_dropout = layers.Dropout(0.5)
        self.enc_dropout = layers.Dropout(0.1)
        self.ffn_dropout = layers.Dropout(0.1)
        self.ffn = keras.Sequential(
            [
                layers.Dense(feed_forward_dim, activation="relu"),
                layers.Dense(embed_dim),
            ]
        )

    def causal_attention_mask(self, batch_size, n_dest, n_src, dtype):
        """Masks the upper half of the dot product matrix in self attention.

        This prevents flow of information from future tokens to current token.
        1's in the lower triangle, counting from the lower right corner.
        """
        i = tf.range(n_dest)[:, None]
        j = tf.range(n_src)
        m = i >= j - n_src + n_dest
        mask = tf.cast(m, dtype)
        mask = tf.reshape(mask, [1, n_dest, n_src])
        mult = tf.concat(
            [tf.expand_dims(batch_size, -1), tf.constant([1, 1], dtype=tf.int32)], 0
        )
        return tf.tile(mask, mult)

    def call(self, enc_out, target):
        input_shape = tf.shape(target)
        batch_size = input_shape[0]
        seq_len = input_shape[1]
        causal_mask = self.causal_attention_mask(batch_size, seq_len, seq_len, tf.bool)
        target_att = self.self_att(target, target, attention_mask=causal_mask)
        target_norm = self.layernorm1(target + self.self_dropout(target_att))
        enc_out = self.enc_att(target_norm, enc_out)
        enc_out_norm = self.layernorm2(self.enc_dropout(enc_out) + target_norm)
        ffn_out = self.ffn(enc_out_norm)
        ffn_out_norm = self.layernorm3(enc_out_norm + self.ffn_dropout(ffn_out))
        return ffn_out_norm

# %%
#with accuracy
class Transformer(keras.Model):
    def __init__(
        self,
        num_hid=64,
        num_head=2,
        num_feed_forward=128,
        source_maxlen=100,
        target_maxlen=100,
        num_layers_enc=4,
        num_layers_dec=1,
        num_classes=10,
    ):
        super().__init__()
        self.loss_metric = keras.metrics.Mean(name="loss")
        self.accuracy_metric = keras.metrics.CategoricalAccuracy(name="accuracy")
        self.num_layers_enc = num_layers_enc
        self.num_layers_dec = num_layers_dec
        self.target_maxlen = target_maxlen
        self.num_classes = num_classes

        self.enc_input = SpeechFeatureEmbedding(num_hid=num_hid, maxlen=source_maxlen)
        self.dec_input = TokenEmbedding(
            num_vocab=num_classes, maxlen=target_maxlen, num_hid=num_hid
        )

        self.encoder = keras.Sequential(
            [self.enc_input]
            + [
                TransformerEncoder(num_hid, num_head, num_feed_forward)
                for _ in range(num_layers_enc)
            ]
        )

        for i in range(num_layers_dec):
            setattr(
                self,
                f"dec_layer_{i}",
                TransformerDecoder(num_hid, num_head, num_feed_forward),
            )

        self.classifier = layers.Dense(num_classes)

    def decode(self, enc_out, target):
        y = self.dec_input(target)
        for i in range(self.num_layers_dec):
            y = getattr(self, f"dec_layer_{i}")(enc_out, y)
        return y

    def call(self, inputs):
        source = inputs[0]
        target = inputs[1]
        x = self.encoder(source)
        y = self.decode(x, target)
        return self.classifier(y)

    @property
    def metrics(self):
        return [self.loss_metric, self.accuracy_metric]

    def train_step(self, batch):
        source = batch["source"]
        target = batch["target"]
        dec_input = target[:, :-1]
        dec_target = target[:, 1:]
        with tf.GradientTape() as tape:
            preds = self([source, dec_input])
            one_hot = tf.one_hot(dec_target, depth=self.num_classes)
            mask = tf.math.logical_not(tf.math.equal(dec_target, 0))
            loss = self.compiled_loss(one_hot, preds, sample_weight=mask)
        trainable_vars = self.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))
        self.loss_metric.update_state(loss)
        self.accuracy_metric.update_state(one_hot, preds, sample_weight=mask)
        return {"loss": self.loss_metric.result(), "accuracy": self.accuracy_metric.result()}

    def test_step(self, batch):
        source = batch["source"]
        target = batch["target"]
        dec_input = target[:, :-1]
        dec_target = target[:, 1:]
        preds = self([source, dec_input])
        one_hot = tf.one_hot(dec_target, depth=self.num_classes)
        mask = tf.math.logical_not(tf.math.equal(dec_target, 0))
        loss = self.compiled_loss(one_hot, preds, sample_weight=mask)
        self.loss_metric.update_state(loss)
        self.accuracy_metric.update_state(one_hot, preds, sample_weight=mask)
        return {"loss": self.loss_metric.result(), "accuracy": self.accuracy_metric.result()}

    def generate(self, source, target_start_token_idx):
        """Performs inference over one batch of inputs using greedy decoding."""
        bs = tf.shape(source)[0]
        enc = self.encoder(source)
        dec_input = tf.ones((bs, 1), dtype=tf.int32) * target_start_token_idx
        dec_logits = []
        for i in range(self.target_maxlen - 1):
            dec_out = self.decode(enc, dec_input)
            logits = self.classifier(dec_out)
            logits = tf.argmax(logits, axis=-1, output_type=tf.int32)
            last_logit = tf.expand_dims(logits[:, -1], axis=-1)
            dec_logits.append(last_logit)
            dec_input = tf.concat([dec_input, last_logit], axis=-1)
        return dec_input

# %%
class DisplayOutputs(keras.callbacks.Callback):
    def __init__(
        self, batch, idx_to_token, target_start_token_idx=27, target_end_token_idx=28
    ):
        """Displays a batch of outputs after every epoch

        Args:
            batch: A test batch containing the keys "source" and "target"
            idx_to_token: A List containing the vocabulary tokens corresponding to their indices
            target_start_token_idx: A start token index in the target vocabulary
            target_end_token_idx: An end token index in the target vocabulary
        """
        self.batch = batch
        self.target_start_token_idx = target_start_token_idx
        self.target_end_token_idx = target_end_token_idx
        self.idx_to_char = idx_to_token

    def on_epoch_end(self, epoch, logs=None):
        if epoch % 4 != 0:
            return
        source = self.batch["source"]
        target = self.batch["target"].numpy()
        bs = tf.shape(source)[0]
        preds = self.model.generate(source, self.target_start_token_idx)
        preds = preds.numpy()
        for i in range(bs):
            target_text = "".join([self.idx_to_char[_] for _ in target[i, :]])
            prediction = ""
            for idx in preds[i, :]:
                ##print(idx)
                prediction += self.idx_to_char[idx]
                if idx == self.target_end_token_idx:
                    break
            print(f"target:     {target_text.replace('-','')}")
            print(f"prediction: {prediction}\n")

# %%
class CustomSchedule(keras.optimizers.schedules.LearningRateSchedule):
    def __init__(
        self,
        init_lr=0.00001,
        lr_after_warmup=0.001,
        final_lr=0.00001,
        warmup_epochs=15,
        decay_epochs=85,
        steps_per_epoch=203,
    ):
        super().__init__()
        self.init_lr = init_lr
        self.lr_after_warmup = lr_after_warmup
        self.final_lr = final_lr
        self.warmup_epochs = warmup_epochs
        self.decay_epochs = decay_epochs
        self.steps_per_epoch = steps_per_epoch

    def calculate_lr(self, epoch):
        """ linear warm up - linear decay """
        warmup_lr = (
            self.init_lr
            + ((self.lr_after_warmup - self.init_lr) / (self.warmup_epochs - 1)) * epoch
        )
        decay_lr = tf.math.maximum(
            self.final_lr,
            self.lr_after_warmup
            - (epoch - self.warmup_epochs)
            * (self.lr_after_warmup - self.final_lr)
            / (self.decay_epochs),
        )
        return tf.math.minimum(warmup_lr, decay_lr)

    def __call__(self, step):
        epoch = step // self.steps_per_epoch
        return self.calculate_lr(epoch)

# %%
batch = next(iter(val_ds))

# The vocabulary to convert predicted indices into characters
idx_to_char = vectorizer.get_vocabulary()
display_cb = DisplayOutputs(
    batch, idx_to_char, target_start_token_idx=2, target_end_token_idx=3
)  # set the arguments as per vocabulary index for '<' and '>'

model = Transformer(
    num_hid=200,
    num_head=2,
    num_feed_forward=400,
    target_maxlen=max_target_len,
    num_layers_enc=4,
    num_layers_dec=1,
    num_classes=34,
)
loss_fn = tf.keras.losses.CategoricalCrossentropy(
    from_logits=True, label_smoothing=0.1,
)

learning_rate = CustomSchedule(
    init_lr=0.00001,
    lr_after_warmup=0.001,
    final_lr=0.00001,
    warmup_epochs=15,
    decay_epochs=85,
    steps_per_epoch=len(ds),
)
optimizer = keras.optimizers.Adam(learning_rate)
model.compile(optimizer=optimizer, loss=loss_fn)

# %%
rmodel = Transformer(
    num_hid=200,
    num_head=2,
    num_feed_forward=400,
    target_maxlen=max_target_len,
    num_layers_enc=4,
    num_layers_dec=1,
    num_classes=34,
)

# Build the model by calling it with some input data (you can use a dummy batch)
dummy_batch = (tf.ones((1,1, 129)), tf.ones((1, 200)))
_ = rmodel(dummy_batch)

# Compile the model
rmodel.compile(optimizer=optimizer, loss=loss_fn, metrics=["accuracy"])


#history = model.fit(ds, validation_data=val_ds, callbacks=[display_cb], epochs=203)

# %%
rmodel.load_weights(r"C:\Users\abdul\project_presentation\Models\transformer\control2latesttransformer.h5")

# %%
history = rmodel.fit(ds, validation_data=val_ds, callbacks=[display_cb], epochs=50)
# Out:
# Epoch 1/50
# 67/67 [==============================] - 29s 354ms/step - loss: 0.0598 - accuracy: 0.6604 - val_loss: 0.0566 - val_accuracy: 0.6400
# target:     <glasses>
# prediction: <wall>
#
# target:     <glasses>
# prediction: <clal>
#
# target:     <slide>
# prediction: <said>
#
# target:     <slide>
# prediction: <bothen>
#
# Epoch 2/50
# 67/67 [==============================] - 23s 347ms/step - loss: 0.0513 - accuracy: 0.7240 - val_loss: 0.0463 - val_accuracy: 0.7320
# Epoch 3/50
# 67/67 [==============================] - 25s 367ms/step - loss: 0.0423 - accuracy: 0.7988 - val_loss: 0.0402 - val_accuracy: 0.7920
# Epoch 4/50
# 67/67 [==============================] - 27s 397ms/step - loss: 0.0358 - accuracy: 0.8594 - val_loss: 0.0355 - val_accuracy: 0.8160
# Epoch 5/50
# 67/67 [==============================] - 28s 419ms/step - loss: 0.0313 - accuracy: 0.9035 - val_loss: 0.0345 - val_accuracy: 0.8360
# target:     <glasses>
# prediction: <look>
#
# target:     <glasses>
# prediction: <like>
#
# target:     <slide>
# prediction: <stimes>
#
# target:     <slide>
# prediction: <slide>
#
# Epoch 6/50
# 67/67 [==============================] - 28s 417ms/step - loss: 0.0282 - accuracy: 0.9367 - val_loss: 0.0333 - val_accuracy: 0.8440
# Epoch 7/50
# 67/67 [==============================] - 29s 430ms/step - loss: 0.0261 - accuracy: 0.9566 - val_loss: 0.0326 - val_accuracy: 0.8600
# Epoch 8/50
# 67/67 [==============================] - 29s 430ms/step - loss: 0.0246 - accuracy: 0.9720 - val_loss: 0.0337 - val_accuracy: 0.8560
# Epoch 9/50
# 67/67 [==============================] - 29s 431ms/step - loss: 0.0236 - accuracy: 0.9819 - val_loss: 0.0341 - val_accuracy: 0.8520
# target:     <glasses>
# prediction: <glasses>
#
# target:     <glasses>
# prediction: <plauge>
#
# target:     <slide>
# prediction: <slide>
#
# target:     <slide>
# prediction: <slide>
#
# Epoch 10/50
# 67/67 [==============================] - 28s 418ms/step - loss: 0.0232 - accuracy: 0.9856 - val_loss: 0.0346 - val_accuracy: 0.8600
# Epoch 11/50
# 67/67 [==============================] - 29s 425ms/step - loss: 0.0227 - accuracy: 0.9899 - val_loss: 0.0344 - val_accuracy: 0.8480
# Epoch 12/50
# 67/67 [==============================] - 28s 421ms/step - loss: 0.0225 - accuracy: 0.9920 - val_loss: 0.0349 - val_accuracy: 0.8520
# Epoch 13/50
# 67/67 [==============================] - 28s 413ms/step - loss: 0.0228 - accuracy: 0.9880 - val_loss: 0.0348 - val_accuracy: 0.8360
# target:     <glasses>
# prediction: <glasses>
#
# target:     <glasses>
# prediction: <glasses>
#
# target:     <slide>
# prediction: <swithing>
#
# target:     <slide>
# prediction: <slide>
#
# Epoch 14/50
# 67/67 [==============================] - 28s 418ms/step - loss: 0.0232 - accuracy: 0.9848 - val_loss: 0.0335 - val_accuracy: 0.8520
# Epoch 15/50
# 67/67 [==============================] - 29s 426ms/step - loss: 0.0240 - accuracy: 0.9763 - val_loss: 0.0345 - val_accuracy: 0.8760
# Epoch 16/50
# 67/67 [==============================] - 28s 418ms/step - loss: 0.0250 - accuracy: 0.9650 - val_loss: 0.0387 - val_accuracy: 0.8120
# Epoch 17/50
# 67/67 [==============================] - 28s 420ms/step - loss: 0.0250 - accuracy: 0.9658 - val_loss: 0.0375 - val_accuracy: 0.8280
# target:     <glasses>
# prediction: <glasses>
#
# target:     <glasses>
# prediction: <glasses>
#
# target:     <slide>
# prediction: <sy>
#
# target:     <slide>
# prediction: <slides>
#
# Epoch 18/50
# 67/67 [==============================] - 28s 424ms/step - loss: 0.0254 - accuracy: 0.9636 - val_loss: 0.0330 - val_accuracy: 0.8680
# Epoch 19/50
# 67/67 [==============================] - 29s 425ms/step - loss: 0.0240 - accuracy: 0.9777 - val_loss: 0.0373 - val_accuracy: 0.8080
# Epoch 20/50
# 67/67 [==============================] - 29s 428ms/step - loss: 0.0246 - accuracy: 0.9712 - val_loss: 0.0412 - val_accuracy: 0.7800
# Epoch 21/50
# 67/67 [==============================] - 29s 426ms/step - loss: 0.0233 - accuracy: 0.9842 - val_loss: 0.0351 - val_accuracy: 0.8360
# target:     <glasses>
# prediction: <glasses>
#
# target:     <glasses>
# prediction: <glasses>
#
# target:     <slide>
# prediction: <sympathize>
#
# target:     <slide>
# prediction: <sympathize>
#
# Epoch 22/50
# 67/67 [==============================] - 29s 425ms/step - loss: 0.0225 - accuracy: 0.9935 - val_loss: 0.0349 - val_accuracy: 0.8400
# Epoch 23/50
# 67/67 [==============================] - 28s 422ms/step - loss: 0.0220 - accuracy: 0.9972 - val_loss: 0.0333 - val_accuracy: 0.8600
# Epoch 24/50
# 67/67 [==============================] - 29s 430ms/step - loss: 0.0218 - accuracy: 0.9985 - val_loss: 0.0337 - val_accuracy: 0.8440
# Epoch 25/50
# 67/67 [==============================] - 29s 429ms/step - loss: 0.0216 - accuracy: 0.9998 - val_loss: 0.0326 - val_accuracy: 0.8520
# target:     <glasses>
# prediction: <glasses>
#
# target:     <glasses>
# prediction: <glasses>
#
# target:     <slide>
# prediction: <sympathize>
#
# target:     <slide>
# prediction: <slide>
#
# Epoch 26/50
# 67/67 [==============================] - 28s 419ms/step - loss: 0.0216 - accuracy: 0.9999 - val_loss: 0.0331 - val_accuracy: 0.8520
# Epoch 27/50
# 67/67 [==============================] - 29s 426ms/step - loss: 0.0216 - accuracy: 1.0000 - val_loss: 0.0333 - val_accuracy: 0.8480
# Epoch 28/50
# 67/67 [==============================] - 29s 426ms/step - loss: 0.0216 - accuracy: 1.0000 - val_loss: 0.0335 - val_accuracy: 0.8520
# Epoch 29/50
# 67/67 [==============================] - 29s 426ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.0336 - val_accuracy: 0.8520
# target:     <glasses>
# prediction: <glasses>
#
# target:     <glasses>
# prediction: <glasses>
#
# target:     <slide>
# prediction: <sympathize>
#
# target:     <slide>
# prediction: <slide>
#
# Epoch 30/50
# 67/67 [==============================] - 29s 425ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.0337 - val_accuracy: 0.8520
# Epoch 31/50
# 67/67 [==============================] - 29s 427ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.0338 - val_accuracy: 0.8520
# Epoch 32/50
# 67/67 [==============================] - 29s 427ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.0339 - val_accuracy: 0.8520
# Epoch 33/50
# 67/67 [==============================] - 29s 426ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.0339 - val_accuracy: 0.8520
# target:     <glasses>
# prediction: <glasses>
#
# target:     <glasses>
# prediction: <glasses>
#
# target:     <slide>
# prediction: <sy>
#
# target:     <slide>
# prediction: <slide>
#
# Epoch 34/50
# 67/67 [==============================] - 28s 421ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.0340 - val_accuracy: 0.8520
# Epoch 35/50
# 67/67 [==============================] - 29s 426ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.0341 - val_accuracy: 0.8520
# Epoch 36/50
# 67/67 [==============================] - 29s 427ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.0341 - val_accuracy: 0.8520
# Epoch 37/50
# 67/67 [==============================] - 29s 427ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.0341 - val_accuracy: 0.8520
# target:     <glasses>
# prediction: <glasses>
#
# target:     <glasses>
# prediction: <glasses>
#
# target:     <slide>
# prediction: <sy>
#
# target:     <slide>
# prediction: <slide>
#
# Epoch 38/50
# 67/67 [==============================] - 28s 423ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.0342 - val_accuracy: 0.8520
# Epoch 39/50
# 67/67 [==============================] - 29s 427ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.0342 - val_accuracy: 0.8520
# Epoch 40/50
# 67/67 [==============================] - 29s 428ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.0342 - val_accuracy: 0.8480
# Epoch 41/50
# 67/67 [==============================] - 29s 427ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.0342 - val_accuracy: 0.8480
# target:     <glasses>
# prediction: <glasses>
#
# target:     <glasses>
# prediction: <glasses>
#
# target:     <slide>
# prediction: <sy>
#
# target:     <slide>
# prediction: <slide>
#
# Epoch 42/50
# 67/67 [==============================] - 28s 422ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.0343 - val_accuracy: 0.8480
# Epoch 43/50
# 67/67 [==============================] - 29s 426ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.0343 - val_accuracy: 0.8480
# Epoch 44/50
# 67/67 [==============================] - 29s 427ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.0344 - val_accuracy: 0.8480
# Epoch 45/50
# 67/67 [==============================] - 29s 429ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.0344 - val_accuracy: 0.8480
# target:     <glasses>
# prediction: <glasses>
#
# target:     <glasses>
# prediction: <glasses>
#
# target:     <slide>
# prediction: <sy>
#
# target:     <slide>
# prediction: <slide>
#
# Epoch 46/50
# 67/67 [==============================] - 28s 421ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.0345 - val_accuracy: 0.8480
# Epoch 47/50
# 67/67 [==============================] - 29s 430ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.0345 - val_accuracy: 0.8480
# Epoch 48/50
# 67/67 [==============================] - 29s 432ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.0345 - val_accuracy: 0.8480
# Epoch 49/50
# 67/67 [==============================] - 29s 430ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.0346 - val_accuracy: 0.8480
# target:     <glasses>
# prediction: <glasses>
#
# target:     <glasses>
# prediction: <glasses>
#
# target:     <slide>
# prediction: <sy>
#
# target:     <slide>
# prediction: <slide>
#
# Epoch 50/50
# 67/67 [==============================] - 28s 424ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.0346 - val_accuracy: 0.8440
