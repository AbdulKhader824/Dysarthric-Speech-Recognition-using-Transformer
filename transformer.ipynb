# %%
import os
import random
from glob import glob
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
import pandas as pd
import os


# Assuming saveto is the directory where the CSV file is located
saveto = r"D:\Mtechs3\project\UASpeech_original_FM\UASpeech\audio\original\F04"
wavs = glob("{}/**/*.wav".format(saveto), recursive=True)
id_to_text = {}

# Load the CSV file into a pandas DataFrame, skipping the first row
csv_file_path = os.path.join(saveto, "dictionary_UASPEECH.csv")
df = pd.read_csv(csv_file_path, sep=',', header=None, names=['ID', 'Text'], skiprows=1)

# Create a dictionary with formatted keys and values
id_to_text = {row["Text"]: row["ID"] for _, row in df.iterrows()}

# %%
k=df.iloc[:,1]

# %%
def get_data(wavs, id_to_text, maxlen=50):
    """ returns mapping of audio paths and transcription texts """
    data = []
    for w in wavs:
        id = w.split("\\")[-1]
        for item in k:
            if item+"_" in id and len(id_to_text[item]) < maxlen:
                data.append({"audio": w, "text": id_to_text[item]})
                #print("hi")
    return data

# %%
saveto = r"C:\Users\abdul\project_presentation\datasets\LJSpeech"
wavs = glob("{}/**/*.wav".format(saveto), recursive=True)

id_to_text = {}
with open(os.path.join(saveto, "metadata.csv"), encoding="utf-8") as f:
    for line in f:
        id = line.strip().split("|")[0]
        text = line.strip().split("|")[2]
        id_to_text[id] = text

# %%
id_to_text
# Out:
# {'LJ001-0001': 'Printing, in the only sense with which we are at present concerned, differs from most if not from all the arts and crafts represented in the Exhibition',
#  'LJ001-0002': 'in being comparatively modern.',
#  'LJ001-0003': 'For although the Chinese took impressions from wood blocks engraved in relief for centuries before the woodcutters of the Netherlands, by a similar process',
#  'LJ001-0004': 'produced the block books, which were the immediate predecessors of the true printed book,',
#  'LJ001-0005': 'the invention of movable metal letters in the middle of the fifteenth century may justly be considered as the invention of the art of printing.',
#  'LJ001-0006': 'And it is worth mention in passing that, as an example of fine typography,',
#  'LJ001-0007': 'the earliest book printed with movable types, the Gutenberg, or "forty-two line Bible" of about fourteen fifty-five,',
#  'LJ001-0008': 'has never been surpassed.',
#  'LJ001-0009': 'Printing, then, for our purpose, may be considered as the art of making books by means of movable types.',
#  'LJ001-0010': 'Now, as all books not primarily intended as picture-books consist principally of types composed to form letterpress,',
#  'LJ001-0011': 'it is of the first importance that the letter used should be fine in form;',
#  'LJ001-0012': 'especially as no more time is occupied, or cost incurred, in casting, setting, or printing beautiful letters',
#  'LJ001-0013': 'than in the same operations with ugly ones.',
#  'LJ001-0014': 'And it was a matter of course that in the Middle Ages, when the craftsmen took care that beautiful form should always be a part of their productions whatever they were,',
#  'LJ001-0015': 'the forms of printed letters should be beautiful, and that their arrangement on the page should be reasonable and a help to the shapeliness of the letters themselves.',
#  'LJ001-0016': 'The Middle Ages brought calligraphy to perfection, and it was natural therefore',
#  'LJ001-0017': 'that the forms of printed letters should follow more or less closely those of the written character, and they followed them very closely.',
#  'LJ001-0018': 'The first books were printed in black letter, i.e. the letter which was a Gothic development of the ancient Roman character,',
#  'LJ001-0019': 'and which developed more completely and satisfactorily on the side of the "lower-case" than the capital letters;',
#  'LJ001-0020': 'the "lower-case" being in fact invented in the early Middle Ages.',
#  'LJ001-0021': 'The earliest book printed with movable type, the aforesaid Gutenberg Bible, is printed in letters which are an exact imitation',
#  'LJ001-0022': 'of the more formal ecclesiastical writing which obtained at that time; this has since been called "missal type,"',
#  'LJ001-0023': 'and was in fact the kind of letter used in the many splendid missals, psalters, etc., produced by printing in the fifteenth century.',
#  'LJ001-0024': 'But the first Bible actually dated (which also was printed at Maintz by Peter Schoeffer in the year fourteen sixty-two)',
#  'LJ001-0025': 'imitates a much freer hand, simpler, rounder, and less spiky, and therefore far pleasanter and easier to read.',
#  'LJ001-0026': 'On the whole the type of this book may be considered the ne-plus-ultra of Gothic type,',
#  'LJ001-0027': 'especially as regards the lower-case letters; and type very similar was used during the next fifteen or twenty years not only by Schoeffer,',
#  'LJ001-0028': 'but by printers in Strasburg, Basle, Paris, Lubeck, and other cities.',
#  'LJ001-0029': 'But though on the whole, except in Italy, Gothic letter was most often used',
#  'LJ001-0030': 'a very few years saw the birth of Roman character not only in Italy, but in Germany and France.',
#  'LJ001-0031': 'In fourteen sixty-five Sweynheim and Pannartz began printing in the monastery of Subiaco near Rome,',
#  'LJ001-0032': 'and used an exceedingly beautiful type, which is indeed to look at a transition between Gothic and Roman,',
#  'LJ001-0033': 'but which must certainly have come from the study of the twelfth or even the eleventh century MSS.',
#  'LJ001-0034': 'They printed very few books in this type, three only; but in their very first books in Rome, beginning with the year fourteen sixty-eight,',
#  'LJ001-0035': 'they discarded this for a more completely Roman and far less beautiful letter.',
#  'LJ001-0036': 'But about the same year Mentelin at Strasburg began to print in a type which is distinctly Roman;',
#  'LJ001-0037': 'and the next year Gunther Zeiner at Augsburg followed suit;',
#  'LJ001-0038': 'while in fourteen seventy at Paris Udalric Gering and his associates turned out the first books printed in France, also in Roman character.',
#  'LJ001-0039': 'The Roman type of all these printers is similar in character,',
#  'LJ001-0040': 'and is very simple and legible, and unaffectedly designed for use; but it is by no means without beauty.',
#  'LJ001-0041': 'It must be said that it is in no way like the transition type of Subiaco,',
#  'LJ001-0042': 'and though more Roman than that, yet scarcely more like the complete Roman type of the earliest printers of Rome.',
#  'LJ001-0043': 'A further development of the Roman letter took place at Venice.',
#  'LJ001-0044': 'John of Spires and his brother Vindelin, followed by Nicholas Jenson, began to print in that city,',
#  'LJ001-0045': 'fourteen sixty-nine, fourteen seventy;',
#  'LJ001-0046': 'their type is on the lines of the German and French rather than of the Roman printers.',
#  'LJ001-0047': 'Of Jenson it must be said that he carried the development of Roman type as far as it can go:',
#  'LJ001-0048': 'his letter is admirably clear and regular, but at least as beautiful as any other Roman type.',
#  'LJ001-0049': 'After his death in the "fourteen eighties," or at least by fourteen ninety, printing in Venice had declined very much;',
#  'LJ001-0050': 'and though the famous family of Aldus restored its technical excellence, rejecting battered letters,',
#  'LJ001-0051': 'and paying great attention to the "press work" or actual process of printing,',
#  'LJ001-0052': "yet their type is artistically on a much lower level than Jenson's, and in fact",
#  'LJ001-0053': 'they must be considered to have ended the age of fine printing in Italy.',
#  'LJ001-0054': 'Jenson, however, had many contemporaries who used beautiful type,',
#  'LJ001-0055': 'some of which -- as, e.g., that of Jacobus Rubeus or Jacques le Rouge -- is scarcely distinguishable from his.',
#  'LJ001-0056': 'It was these great Venetian printers, together with their brethren of Rome, Milan,',
#  'LJ001-0057': "Parma, and one or two other cities, who produced the splendid editions of the Classics, which are one of the great glories of the printer's art,",
#  'LJ001-0058': 'and are worthy representatives of the eager enthusiasm for the revived learning of that epoch. By far,',
#  'LJ001-0059': 'the greater part of these Italian printers, it should be mentioned, were Germans or Frenchmen, working under the influence of Italian opinion and aims.',
#  'LJ001-0060': 'It must be understood that through the whole of the fifteenth and the first quarter of the sixteenth centuries',
#  'LJ001-0061': 'the Roman letter was used side by side with the Gothic.',
#  'LJ001-0062': 'Even in Italy most of the theological and law books were printed in Gothic letter,',
#  'LJ001-0063': 'which was generally more formally Gothic than the printing of the German workmen,',
#  'LJ001-0064': 'many of whose types, indeed, like that of the Subiaco works, are of a transitional character.',
#  'LJ001-0065': 'This was notably the case with the early works printed at Ulm, and in a somewhat lesser degree at Augsburg.',
#  'LJ001-0066': "In fact Gunther Zeiner's first type (afterwards used by Schussler) is remarkably like the type of the before-mentioned Subiaco books.",
#  'LJ001-0067': 'In the Low Countries and Cologne, which were very fertile of printed books, Gothic was the favorite.',
#  'LJ001-0068': 'The characteristic Dutch type, as represented by the excellent printer Gerard Leew, is very pronounced and uncompromising Gothic.',
#  'LJ001-0069': "This type was introduced into England by Wynkyn de Worde, Caxton's successor,",
#  'LJ001-0070': 'and was used there with very little variation all through the sixteenth and seventeenth centuries, and indeed into the eighteenth.',
#  'LJ001-0071': "Most of Caxton's own types are of an earlier character, though they also much resemble Flemish or Cologne letter.",
#  'LJ001-0072': 'After the end of the fifteenth century the degradation of printing, especially in Germany and Italy,',
#  'LJ001-0073': 'went on apace; and by the end of the sixteenth century there was no really beautiful printing done:',
#  'LJ001-0074': 'the best, mostly French or Low-Country, was neat and clear, but without any distinction;',
#  'LJ001-0075': 'the worst, which perhaps was the English, was a terrible falling-off from the work of the earlier presses;',
#  'LJ001-0076': 'and things got worse and worse through the whole of the seventeenth century, so that in the eighteenth printing was very miserably performed.',
#  'LJ001-0077': 'In England about this time, an attempt was made (notably by Caslon, who started business in London as a type-founder in seventeen twenty)',
#  'LJ001-0078': 'to improve the letter in form.',
#  'LJ001-0079': "Caslon's type is clear and neat, and fairly well designed;",
#  'LJ001-0080': 'he seems to have taken the letter of the Elzevirs of the seventeenth century for his model:',
#  'LJ001-0081': 'type cast from his matrices is still in everyday use.',
#  'LJ001-0082': 'In spite, however, of his praiseworthy efforts, printing had still one last degradation to undergo.',
#  'LJ001-0083': 'The seventeenth century founts were bad rather negatively than positively.',
#  'LJ001-0084': 'But for the beauty of the earlier work they might have seemed tolerable.',
#  'LJ001-0085': 'It was reserved for the founders of the later eighteenth century to produce letters which are positively ugly, and which, it may be added,',
#  'LJ001-0086': 'are dazzling and unpleasant to the eye owing to the clumsy thickening and vulgar thinning of the lines:',
#  'LJ001-0087': 'for the seventeenth-century letters are at least pure and simple in line. The Italian, Bodoni, and the Frenchman, Didot,',
#  'LJ001-0088': 'were the leaders in this luckless change, though our own Baskerville, who was at work some years before them, went much on the same lines;',
#  'LJ001-0089': 'but his letters, though uninteresting and poor, are not nearly so gross and vulgar as those of either the Italian or the Frenchman.',
#  'LJ001-0090': 'With this change the art of printing touched bottom,',
#  'LJ001-0091': 'so far as fine printing is concerned, though paper did not get to its worst till about eighteen forty.',
#  'LJ001-0092': "The Chiswick press in eighteen forty-four revived Caslon's founts, printing for Messrs. Longman the Diary of Lady Willoughby.",
#  'LJ001-0093': 'This experiment was so far successful that about eighteen fifty Messrs. Miller and Richard of Edinburgh',
#  'LJ001-0094': 'were induced to cut punches for a series of "old style" letters.',
#  'LJ001-0095': 'These and similar founts, cast by the above firm and others,',
#  'LJ001-0096': 'have now come into general use and are obviously a great improvement on the ordinary "modern style" in use in England, which is in fact the Bodoni type',
#  'LJ001-0097': 'a little reduced in ugliness. The design of the letters of this modern "old style" leaves a good deal to be desired,',
#  'LJ001-0098': 'and the whole effect is a little too gray, owing to the thinness of the letters.',
#  'LJ001-0099': 'It must be remembered, however, that most modern printing is done by machinery on soft paper, and not by the hand press,',
#  'LJ001-0100': 'and these somewhat wiry letters are suitable for the machine process, which would not do justice to letters of more generous design.',
#  'LJ001-0101': 'It is discouraging to note that the improvement of the last fifty years is almost wholly confined to Great Britain.',
#  'LJ001-0102': 'Here and there a book is printed in France or Germany with some pretension to good taste,',
#  'LJ001-0103': 'but the general revival of the old forms has made no way in those countries.',
#  'LJ001-0104': 'Italy is contentedly stagnant.',
#  'LJ001-0105': 'America has produced a good many showy books, the typography, paper, and illustrations of which are, however, all wrong,',
#  'LJ001-0106': 'oddity rather than rational beauty and meaning being apparently the thing sought for both in the letters and the illustrations.',
#  'LJ001-0107': 'To say a few words on the principles of design in typography:',
#  'LJ001-0108': 'it is obvious that legibility is the first thing to be aimed at in the forms of the letters;',
#  'LJ001-0109': 'this is best furthered by the avoidance of irrational swellings and spiky projections, and by the using of careful purity of line.',
#  'LJ001-0110': 'Even the Caslon type when enlarged shows great shortcomings in this respect:',
#  'LJ001-0111': 'the ends of many of the letters such as the t and e are hooked up in a vulgar and meaningless way,',
#  'LJ001-0112': "instead of ending in the sharp and clear stroke of Jenson's letters;",
#  'LJ001-0113': 'there is a grossness in the upper finishings of letters like the c, the a, and so on,',
#  'LJ001-0114': 'an ugly pear-shaped swelling defacing the form of the letter:',
#  'LJ001-0115': 'in short, it happens to this craft, as to others, that the utilitarian practice, though it professes to avoid ornament,',
#  'LJ001-0116': 'still clings to a foolish, because misunderstood conventionality, deduced from what was once ornament, and is by no means useful;',
#  'LJ001-0117': 'which title can only be claimed by artistic practice, whether the art in it be conscious or unconscious.',
#  'LJ001-0118': 'In no characters is the contrast between the ugly and vulgar illegibility of the modern type',
#  'LJ001-0119': 'and the elegance and legibility of the ancient more striking than in the Arabic numerals.',
#  'LJ001-0120': 'In the old print each figure has its definite individuality, and one cannot be mistaken for the other;',
#  'LJ001-0121': 'in reading the modern figures the eyes must be strained before the reader can have any reasonable assurance',
#  'LJ001-0122': 'that he has a five, an eight, or a three before him, unless the press work is of the best:',
#  'LJ001-0123': "this is awkward if you have to read Bradshaw's Guide in a hurry.",
#  'LJ001-0124': 'One of the differences between the fine type and the utilitarian must probably be put down to a misapprehension of a commercial necessity:',
#  'LJ001-0125': 'this is the narrowing of the modern letters.',
#  'LJ001-0126': "Most of Jenson's letters are designed within a square,",
#  'LJ001-0127': 'the modern letters are narrowed by a third or thereabout; but while this gain of space very much hampers the possibility of beauty of design,',
#  'LJ001-0128': 'it is not a real gain, for the modern printer throws the gain away by putting inordinately wide spaces between his lines, which, probably,',
#  'LJ001-0129': 'the lateral compression of his letters renders necessary.',
#  'LJ001-0130': 'Commercialism again compels the use of type too small in size to be comfortable reading:',
#  'LJ001-0131': 'the size known as "Long primer" ought to be the smallest size used in a book meant to be read.',
#  'LJ001-0132': 'Here, again, if the practice of "leading" were retrenched larger type could be used without enhancing the price of a book.',
#  'LJ001-0133': 'One very important matter in "setting up" for fine printing is the "spacing," that is, the lateral distance of words from one another.',
#  'LJ001-0134': 'In good printing the spaces between the words should be as near as possible equal',
#  'LJ001-0135': 'it is impossible that they should be quite equal except in lines of poetry',
#  'LJ001-0136': 'modern printers understand this, but it is only practiced in the very best establishments.',
#  'LJ001-0137': 'But another point which they should attend to they almost always disregard;',
#  'LJ001-0138': 'this is the tendency to the formation of ugly meandering white lines or "rivers" in the page',
#  'LJ001-0139': 'a blemish which can be nearly, though not wholly, avoided by care and forethought',
#  'LJ001-0140': 'the desirable thing being "the breaking of the line" as in bonding masonry or brickwork',
#  'LJ001-0141': 'The general solidity of a page is much to be sought for',
#  'LJ001-0142': 'modern printers generally overdo the "whites" in the spacing, a defect probably forced on them by the characterless quality of the letters.',
#  'LJ001-0143': 'For where these are boldly and carefully designed, and each letter is thoroughly individual in form,',
#  'LJ001-0144': 'the words may be set much closer together, without loss of clearness.',
#  'LJ001-0145': 'No definite rules, however, except the avoidance of "rivers" and excess of white, can be given for the spacing,',
#  'LJ001-0146': 'which requires the constant exercise of judgment and taste on the part of the printer.',
#  'LJ001-0147': 'The position of the page on the paper should be considered if the book is to have a satisfactory look.',
#  'LJ001-0148': 'Here once more the almost invariable modern practice is in opposition to a natural sense of proportion.',
#  'LJ001-0149': 'From the time when books first took their present shape till the end of the sixteenth century, or indeed later,',
#  'LJ001-0150': 'the page so lay on the paper that there was more space allowed to the bottom and fore margin than to the top and back of the paper,',
#  'LJ001-0151': 'the unit of the book being looked on as the two pages forming an opening.',
#  'LJ001-0152': 'The modern printer, in the teeth of the evidence given by his own eyes, considers the single page as the unit, and prints the page in the middle of his paper',
#  'LJ001-0153': 'only nominally so, however, in many cases, since when he uses a headline he counts that in,',
#  'LJ001-0154': 'the result as measured by the eye being that the lower margin is less than the top one, and that the whole opening has an upside-down look vertically',
#  'LJ001-0155': 'and that laterally the page looks as if it were being driven off the paper.',
#  'LJ001-0156': 'The paper on which the printing is to be done is a necessary part of our subject:',
#  'LJ001-0157': 'of this it may be said that though there is some good paper made now,',
#  'LJ001-0158': 'it is never used except for very expensive books, although it would not materially increase the cost in all but the very cheapest.',
#  'LJ001-0159': 'The paper that is used for ordinary books is exceedingly bad even in this country, but is beaten in the race for vileness',
#  'LJ001-0160': 'by that made in America, which is the worst conceivable.',
#  'LJ001-0161': 'There seems to be no reason why ordinary paper should not be better made,',
#  'LJ001-0162': 'even allowing the necessity for a very low price; but any improvement must be based on showing openly that the cheap article is cheap,',
#  'LJ001-0163': 'e.g. the cheap paper should not sacrifice toughness and durability to a smooth and white surface,',
#  'LJ001-0164': 'which should be indications of a delicacy of material and manufacture which would of necessity increase its cost.',
#  'LJ001-0165': 'One fruitful source of badness in paper',
#  'LJ001-0166': 'is the habit that publishers have of eking out a thin volume by printing it on thick paper almost of the substance of cardboard,',
#  'LJ001-0167': 'a device which deceives nobody, and makes a book very unpleasant to read.',
#  'LJ001-0168': 'On the whole, a small book should be printed on paper which is as thin as may be without being transparent.',
#  'LJ001-0169': 'The paper used for printing the small highly ornamented French service-books about the beginning of the sixteenth century is a model in this respect,',
#  'LJ001-0170': 'being thin, tough, and opaque.',
#  'LJ001-0171': 'However, the fact must not be blinked that machine-made paper cannot in the nature of things be made of so good a texture as that made by hand.',
#  'LJ001-0172': 'The ornamentation of printed books is too wide a subject to be dealt with fully here; but one thing must be said on it.',
#  'LJ001-0173': 'The essential point to be remembered is that the ornament, whatever it is, whether picture or pattern-work, should form part of the page,',
#  'LJ001-0174': 'should be a part of the whole scheme of the book.',
#  'LJ001-0175': 'Simple as this proposition is, it is necessary to be stated,',
#  'LJ001-0176': 'because the modern practice is to disregard the relation between the printing and the ornament altogether,',
#  'LJ001-0177': 'so that if the two are helpful to one another it is a mere matter of accident.',
#  'LJ001-0178': 'The due relation of letter to pictures and other ornament was thoroughly understood by the old printers; so that',
#  'LJ001-0179': 'even when the woodcuts are very rude indeed,',
#  'LJ001-0180': 'the proportions of the page still give pleasure by the sense of richness that the cuts and letter together convey.',
#  'LJ001-0181': 'When, as is most often the case, there is actual beauty in the cuts,',
#  'LJ001-0182': 'the books so ornamented are amongst the most delightful works of art that have ever been produced.',
#  'LJ001-0183': 'Therefore, granted well-designed type, due spacing of the lines and words, and proper position of the page on the paper,',
#  'LJ001-0184': 'all books might be at least comely and well-looking: and if to these good qualities were added really beautiful ornament and pictures,',
#  'LJ001-0185': 'printed books might once again illustrate to the full',
#  'LJ001-0186': 'the position of our Society that a work of utility might be also a work of art, if we cared to make it so.',
#  'LJ002-0001': 'The Chronicles of Newgate, Volume two. By Arthur Griffiths. Section four: Newgate down to eighteen eighteen.',
#  'LJ002-0002': 'Under the conditions referred to in the previous chapter,',
#  'LJ002-0003': 'with criminals and misdemeanants of all shades crowding perpetually into its narrow limits, the latter state of Newgate was worse than the first.',
#  'LJ002-0004': 'The new jail fell as far short of the demands made on it as did the old.',
#  'LJ002-0005': 'The prison population fluctuated a great deal,',
#  'LJ002-0006': 'but it was almost always in excess of the accommodation available, and there were times when the place was full to overflowing.',
#  'LJ002-0007': 'Neild gives some figures which well illustrate this.',
#  'LJ002-0008': 'On the fourteenth June, eighteen hundred, there were one hundred ninety-nine debtors and two hundred eighty-nine felons in the prison.',
#  'LJ002-0009': 'On the twenty-seventh April, in the following year,',
#  'LJ002-0010': 'these numbers had risen to two hundred seventy-five and three hundred seventy-five respectively, or six hundred fifty in all.',
#  'LJ002-0011': 'For two more years these high figures were steadily maintained, and in eighteen oh three the total rose to seven hundred ten.',
#  'LJ002-0012': 'After that they fell as steadily,',
#  'LJ002-0013': 'till, eighteen oh eight, the lowest point was touched of one hundred ninety-seven debtors and one hundred eighty-two felons, or three hundred seventy-nine in all.',
#  'LJ002-0014': 'The numbers soon increased, however, and by eighteen eleven had again risen to six hundred twenty-nine; and Mr. Neild was told that there had been at one time',
#  'LJ002-0015': 'three hundred debtors and nine hundred criminals in Newgate, or twelve hundred prisoners in all.',
#  'LJ002-0016': "Previous to that date there had been seven hundred or eight hundred frequently, and once, in Mr. Akerman's time, one thousand.",
#  'LJ002-0017': 'Trustworthy evidence is forthcoming to the effect that these high figures were constantly maintained for many months at a time.',
#  'LJ002-0018': 'The inadequacy of the jail was noticed and reported upon again and again by the grand juries of the city of London,',
#  'LJ002-0019': 'who seldom let a session go by without visiting Newgate.',
#  'LJ002-0020': 'In eighteen thirteen',
#  'LJ002-0021': "the grand jury made a special presentment to the Court of Common Council, pointing out that on the debtors' side, which was intended for only one hundred,",
#  'LJ002-0022': 'no less than three hundred forty were crowded, to the great inconvenience and danger of the inmates.',
#  'LJ002-0023': 'On the female side matters were much worse;',
#  'LJ002-0024': 'Quote. the apartments set apart for them, being built to accommodate sixty persons, now contain about one hundred twenty. End quote.',
#  'LJ002-0025': 'Returns laid before the House of Commons showed that six thousand, four hundred thirty-nine persons had been committed to Newgate',
#  'LJ002-0026': 'in the three years between eighteen thirteen and eighteen sixteen,',
#  'LJ002-0027': 'and this number did not include the debtors, a numerous class, who were still committed to Newgate pending the completion of the White Cross Street prison.',
#  'LJ002-0028': 'In order to realize the evils entailed by incarceration in Newgate in these days, it is necessary to give some account of its interior',
#  'LJ002-0029': 'as it was occupied and appropriated in eighteen ten.',
#  'LJ002-0030': 'Full details of the arrangements are to be found in Mr. Neild\'s "State of Prisons in England, Scotland, and Wales," published in eighteen twelve.',
#  'LJ002-0031': 'The jail at that date was divided into eight separate and more or less distinct departments, each of which had its own wards and yard.',
#  'LJ002-0032': "These were: one. The male debtors' side.",
#  'LJ002-0033': "two. The female debtors' side. three. The chapel yard. four. The middle yard.",
#  'LJ002-0034': "five. The master felons' side. six. The female felons' side. seven. The state side.",
#  'LJ002-0035': 'eight. The press yard.',
#  'LJ002-0036': "one. The male debtors' side consisted of a yard forty-nine feet by thirty-one,",
#  'LJ002-0037': 'leading to thirteen wards on various floors, and a day room.',
#  'LJ002-0038': 'Of these wards, three were appropriated to the "cabin side," so called because',
#  'LJ002-0039': 'they each contained four small rooms or "cabins" seven feet square,',
#  'LJ002-0040': 'intended to accommodate a couple of prisoners apiece, but often much more crowded.',
#  'LJ002-0041': "Two other wards were appropriated to the master's side debtors; they were each twenty-three feet by fourteen and a half,",
#  'LJ002-0042': 'and supposed to accommodate twenty persons. The eight remaining wards were for the common side debtors,',
#  'LJ002-0043': 'long narrow rooms -- one thirty-six feet, six twenty-three feet, and the eighth eighteen,',
#  'LJ002-0044': 'the whole about fifteen feet wide.',
#  'LJ002-0045': 'The various wards were all about eleven feet in height,',
#  'LJ002-0046': 'and were occupied as a rule by ten to fifteen people when the prison was not crowded, but double the number was occasionally placed in them.',
#  'LJ002-0047': 'The day room was fitted with benches and settles after the manner of the tap in a public-house.',
#  'LJ002-0048': "two. The female debtors' side consisted of a court-yard forty-nine by sixteen feet,",
#  'LJ002-0049': 'leading to two wards, one of which was thirty-six feet by fifteen,',
#  'LJ002-0050': 'and the other eighteen by fifteen; and they nominally held twenty-two persons.',
#  'LJ002-0051': "A high wall fifteen feet in height divided the females' court-yard from the men's.",
#  'LJ002-0052': 'three. The chapel yard was about forty-three feet by twenty-five.',
#  'LJ002-0053': 'It had been for some time devoted principally to felons of the worst types,',
#  'LJ002-0054': 'those who were the oldest offenders, sentenced to transportation, and who had narrowly escaped the penalty of death.',
#  'LJ002-0055': 'This arrangement was, however, modified after eighteen eleven, and the chapel yard was allotted to misdemeanants and prisoners awaiting trial.',
#  'LJ002-0056': 'The wards in this part were five in number, all in dimensions twenty feet by fifteen, with a sixth ward fifteen feet square.',
#  'LJ002-0057': 'These wards were all fitted with barrack-beds, but no bedding was supplied.',
#  'LJ002-0058': "The chapel yard led to the chapel, and on the staircase were two rooms frequently set apart for the king's witnesses,",
#  'LJ002-0059': "those who had turned king's evidence, whose safety might have been imperiled had they been lodged with the men against whom they had informed.",
#  'LJ002-0060': "But these king's witnesses were also put at times into the press yard among the capital convicts, seemingly a very dangerous proceeding,",
#  'LJ002-0061': 'or they lodged with the gatesmen, the prisoner officers who had charge of the inner gates.',
#  'LJ002-0062': 'The middle yard was at first given up to the least heinous offenders. After eighteen twelve it changed functions with the chapel yard.',
#  'LJ002-0063': 'It was fifty feet by twenty-five, and had five wards each thirty-eight by fifteen. At one end of the yard was an arcade,',
#  'LJ002-0064': 'directly under the chapel, in which there were three cells, used either for the confinement of disorderly and refractory prisoners,',
#  'LJ002-0065': 'or female convicts ordered for execution.',
#  'LJ002-0066': "The master felons' side consisted of a yard the same size as the preceding, appropriated nominally to the most decent and better-behaved prisoners,",
#  'LJ002-0067': 'but really kept for the few who had funds sufficient to gain them admission to these more comfortable quarters.',
#  'LJ002-0068': 'Here were also lodged the gatesmen, the prisoners who had charge of the inner gates, and who were entrusted with the duty of escorting visitors from the gates',
#  'LJ002-0069': 'to the various wards their friends occupied.',
#  'LJ002-0070': "The state side was the part stolen from the female felons' side.",
#  'LJ002-0071': 'It was large and comparatively commodious, being maintained on a better footing than any other part of the prison.',
#  'LJ002-0072': 'The inmates were privileged, either by antecedents or the fortunate possession of sufficient funds to pay the charges of the place.',
#  'LJ002-0073': 'Neild takes it for granted that the former rather than the latter prevailed in the selection,',
#  'LJ002-0074': 'and tells us that in the state side, quote, such prisoners were safely associated whose manners and conduct evince a more liberal style of education,',
#  'LJ002-0075': 'and who are therefore lodged apart from all other districts of the jail. End quote.',
#  'LJ002-0076': 'The state side contained twelve good-sized rooms,',
#  'LJ002-0077': 'from twenty-one by eighteen feet to fifteen feet square, which were furnished with bedsteads and bedding.',
#  'LJ002-0078': 'seven. The press yard was that part set aside for the condemned.',
#  'LJ002-0079': 'Its name and its situation were the same as those of the old place of carrying out the terrible sentence inflicted on accused persons who stood mute.',
#  'LJ002-0080': 'The long narrow yard still remained as we saw it in Jacobite times,',
#  'LJ002-0081': 'and beyond it was now a day room for the capital convicts or those awaiting execution.',
#  'LJ002-0082': 'Beyond the press yard were three stories, condemned cells, fifteen in all, with vaulted ceilings nine feet high to the crown of the arch.',
#  'LJ002-0083': 'The ground floor cells were nine feet by six;',
#  'LJ002-0084': 'those on the first floor were rather larger on account of a set-off in the wall; and the uppermost were the largest, for the same reason.',
#  'LJ002-0085': 'Security was provided for in these condemned cells by lining the substantial stone walls with planks studded with broad-headed nails;',
#  'LJ002-0086': 'they were lighted by a double-grated window two feet nine inches by fourteen inches; and in the doors, which were four inches thick,',
#  'LJ002-0087': 'a circular aperture had been let in to give ventilation and secure a free current of air.',
#  'LJ002-0088': 'In each cell there was a barrack bedstead on the floor without bedding.',
#  'LJ002-0089': 'eight. The female felons were deprived of part of the space which the architect had intended for them.',
#  'LJ002-0090': 'More than half their quadrangle had been partitioned off for another purpose,',
#  'LJ002-0091': "and what remained was divided into a master's and a common side for female felons.",
#  'LJ002-0092': 'The two yards were adjoining, that for the common side much the largest.',
#  'LJ002-0093': 'There were nine wards in all on the female side, one of them in the attic,',
#  'LJ002-0094': 'with four casements and two fireplaces, being allotted for a female infirmary',
#  'LJ002-0095': 'and the rest being provided with barrack beds, and in dimensions varying from thirty feet by fifteen to fifteen feet by ten.',
#  'LJ002-0096': 'The eight courts above enumerated were well supplied with water;',
#  'LJ002-0097': 'they had dust-bins, sewers, and so forth, "properly disposed," and the city scavenger paid periodical visits to the prison.',
#  'LJ002-0098': 'The prisoners had few comforts, beyond the occasional use of a bath at some distance, situated in the press yard,',
#  'LJ002-0099': 'to which access was granted rarely and as a great favor. But they were allowed the luxury of drink -- if they could pay for it.',
#  'LJ002-0100': 'A recent reform had closed the tap kept by the jailer within the precincts, but',
#  'LJ002-0101': 'there was still a "convenient room" which served, and, quote,',
#  'LJ002-0102': 'near it a grating through which the debtors receive their beer from the neighboring public-houses.',
#  'LJ002-0103': "The felons' side has a similar accommodation, and this mode of introducing the beverage is adopted because no publican as such",
#  'LJ002-0104': "can be permitted to enter the interior of this prison. End quote. The tap-room and bar were just behind the felons' entrance lodge,",
#  'LJ002-0105': 'and beyond it was a room called the "wine room," because formerly used for the sale of wine, but',
#  'LJ002-0106': 'in which latterly a copper had been fixed for the cooking of provisions sent in by charitable persons.',
#  'LJ002-0107': 'Quote, On the top of the jail, continues Neild, are a watch-house and a sentry-box, where two or more guards, with dogs and firearms,',
#  'LJ002-0108': "watch all night. Adjoining the felons' side lodge is the keeper's office, where the prison books are kept, and his clerk,",
#  'LJ002-0109': 'called the clerk of the papers, attends daily. End quote.',
#  'LJ002-0110': 'Having thus briefly described the plan and appropriation of the prison, I propose to deal now with the general condition of the inmates, and the manner of their life.',
#  'LJ002-0111': 'Of these the debtors, male and female, formed a large proportion.',
#  'LJ002-0112': 'The frequency and extent of processes against debtors seventy or eighty years ago will appear almost incredible',
#  'LJ002-0113': 'in an age when insolvent acts and bankruptcy courts do so much to relieve the impecunious,',
#  'LJ002-0114': 'and imprisonment for debt has almost entirely disappeared.',
#  'LJ002-0116': 'The number of processes against debtors annually was extraordinary.',
#  'LJ002-0117': 'Neild gives, on the authority of Mr. Burchell, the under sheriff of Middlesex,',
#  'LJ002-0118': 'a table showing the figures for the year ending Michaelmas eighteen oh two.',
#  'LJ002-0119': 'In that period upwards of two hundred thousand writs',
#  'LJ002-0120': 'had been issued for the arrests of debtors in the kingdom, for sums varying from fourpence to five hundred pounds and upwards.',
#  'LJ002-0121': 'Fifteen thousand of these were issued in Middlesex alone, which at that time was reckoned as only a fifteenth of Great Britain.',
#  'LJ002-0122': 'The number of arrests actually made was one hundred fourteen thousand, three hundred for the kingdom, and seven thousand twenty for Middlesex.',
#  'LJ002-0123': 'Barely half of these gave bail bonds on arrests, and the remainder went to prison.',
#  'LJ002-0124': 'Quite half of the foregoing writs and arrests applied to sums under thirty pounds.',
#  'LJ002-0125': 'Neild also says that in seventeen ninety-three,',
#  'LJ002-0126': 'five thousand, seven hundred nineteen writs and executions for debts between ten pounds and twenty pounds were issued in Middlesex,',
#  'LJ002-0127': 'and the aggregate amount of debts sued for was eighty-one thousand, seven hundred ninety-one pounds.',
#  'LJ002-0128': 'He also makes the curious calculation that the costs of these actions if undefended',
#  'LJ002-0129': 'would have amounted to sixty-eight thousand, seven hundred twenty-eight pounds, and if defended,',
#  'LJ002-0130': 'two hundred eighty-five thousand, nine hundred fifty pounds; in other words, that to recover eighty odd thousand pounds,',
#  'LJ002-0131': 'three times the amount would be expended.',
#  'LJ002-0132': 'An elaborate machinery planned for the protection of the trader, and altogether on his side, had long existed for the recovery of debts.',
#  'LJ002-0133': 'Alfred the Great established the Court Baron, the Hundred Court, and the County Court, which among other matters entertained pleas for debt.',
#  'LJ002-0134': "The County Court was the sheriff's, who sat there surrounded by the bishop and the magnates of the county;",
#  'LJ002-0135': "but as time passed, difficulties and delays in obtaining judgment led to the removal of causes to the great Court of King's Bench,",
#  'LJ002-0136': 'and the disuse of the inferior courts.',
#  'LJ002-0137': 'So much inconvenience ensued, that in fifteen eighteen the Corporation obtained from Parliament an act empowering two aldermen',
#  'LJ002-0138': 'and four common councilmen to hold Courts of Requests, or Courts of Conscience, to hear and determine all causes of debt',
#  'LJ002-0139': 'under forty shillings arising within the city.',
#  'LJ002-0140': 'These courts were extended two centuries later to several large provincial towns, and all were in full activity when Neild wrote,',
#  'LJ002-0141': 'and indeed supplied the bulk of the poor debtors committed to prison.',
#  'LJ002-0142': 'These courts were open to many and grave objections.',
#  'LJ002-0143': 'The commissioners who presided were, quote, little otherwise than self-elected',
#  'LJ002-0144': 'and when once appointed continued to serve sine die; they were generally near in rank to the parties whose causes they decided.',
#  'LJ002-0145': 'Often a commissioner had to leave the bench because he was himself a party to the suit that was sub judice.',
#  'LJ002-0146': 'The activity as well as the futility of these courts may be estimated from the statement given by Neild',
#  'LJ002-0147': 'that thirteen hundred and twelve debtors were committed by them to Newgate between seventeen ninety-seven and eighteen oh eight,',
#  'LJ002-0148': 'and that no more than one hundred ninety-seven creditors recovered debts and costs.',
#  'LJ002-0149': 'The latter indeed hung like millstones round the neck of the unhappy insolvent wretches who found themselves in limbo.',
#  'LJ002-0150': 'Costs were the gallons of sack to the pennyworth of debt.',
#  'LJ002-0151': 'Neild found at his visit to Newgate in eighteen ten,',
#  'LJ002-0152': 'fourteen men and women who had lain there ten, eleven, and thirteen years for debts of a few shillings,',
#  'LJ002-0153': 'weighted by treble the amount of costs.',
#  'LJ002-0154': 'Thus, amongst others, Thomas Blackburn had been committed on October fifteenth for a debt of one shilling five pence.',
#  'LJ002-0155': 'for which the costs were six shillings ten pence.',
#  'LJ002-0156': 'Thomas Dobson, on twenty-second August, seventeen ninety-nine, for one shilling, with costs of eight shillings, ten pence.',
#  'LJ002-0157': 'and Susannah Evans, in October the same year, for two shillings, with costs of six shillings, eight pence.',
#  'LJ002-0158': 'Other cases are recorded elsewhere, as at the Giltspur Street Compter, where in eighteen oh five Mr. Neild found a man named William Grant',
#  'LJ002-0159': 'detained for one shilling nine pence, with costs of five shillings.',
#  'LJ002-0160': 'and John Lancaster for one shilling, eight pence, with costs of seven shillings, six pence. Quote.',
#  'LJ002-0161': 'These surely, I thought," says Mr. Neild, "were bad enough! But it was not so. End quote.',
#  'LJ002-0162': 'He recites another most outrageous and extraordinary case, in which one John Bird,',
#  'LJ002-0163': 'a market porter, was arrested and committed at the suit of a publican',
#  'LJ002-0164': 'for the paltry sum of four pence, with costs of seven shillings, six pence.',
#  'LJ002-0165': 'Bird was, however, discharged within three days by a subscription raised among his fellow-prisoners.',
#  'LJ002-0166': 'Mr. Buxton, in his "Inquiry into the System of Prison Discipline,"',
#  'LJ002-0167': 'quotes a case which came within his own knowledge of a boy sent to prison for non-payment of one penny.',
#  'LJ002-0168': 'The lad in question was found in Coldbath Fields prison, to which he had been sent for a month in default of paying a fine of forty shillings.',
#  'LJ002-0169': "He had been in the employ of a corn-chandler at Islington, and went into London with his master's cart and horse.",
#  'LJ002-0170': 'There was in the City Road a temporary bar, with a collector of tolls who was sometimes on the spot and sometimes not.',
#  'LJ002-0171': 'The boy declared he saw no one, and accordingly passed through without paying the toll of a penny.',
#  'LJ002-0172': 'For this he was summoned before a magistrate, and sentenced as already stated.',
#  'LJ002-0173': 'The lad was proved to be of good character and the son of respectable parents.',
#  'LJ002-0174': "Mr. Buxton's friends at once paid the forty shillings, and the boy was released.",
#  'LJ002-0175': 'The costs in heavier debts always doubled the sum; if the arrest was made in the country it trebled it.',
#  'LJ002-0176': 'Neild gives a list of the various items charged upon a debt of ten pounds, which included instructions to sue,',
#  'LJ002-0177': 'affidavit of debt, drawing praecipe (one pound, five shillings), capias, fee to officer on arrest,',
#  'LJ002-0178': 'affidavit of service, and many more, amounting in all to twenty-seven,',
#  'LJ002-0179': 'and costing eleven pounds, fifteen shillings, eight pence, within ten days.',
#  'LJ002-0180': 'Before dealing with the debtors in Newgate, I may refer incidentally',
#  'LJ002-0181': "to those in other London prisons, for Newgate was not the only place of durance for these unfortunate people. There were also the King's Bench,",
#  'LJ002-0182': 'the Fleet, and the Marshalsea prisons especially devoted to them,',
#  'LJ002-0183': 'whilst Ludgate, the Giltspur Street, and Borough Compters also received them',
#  'LJ002-0184': 'the latter two being also a prison for felons and vagrants arrested within certain limits.',
#  'LJ002-0185': "The King's Bench was a national prison, in which were confined all debtors arrested for debt or for contempt of the court of the King's Bench.",
#  'LJ002-0186': 'The population generally amounted to from five hundred to seven hundred, the accommodation being calculated for two hundred.',
#  'LJ002-0187': 'Every new-comer was entitled to a "chummage" ticket, but did not always get it,',
#  'LJ002-0188': 'being often obliged to pay a high rent for a bed at the coffee-house or in some room which was vacated by its regular occupant.',
#  'LJ002-0189': 'No fixed rates or rules governed the hiring out of rooms or parts of a room, and all sorts of imposition was practiced.',
#  'LJ002-0190': 'The best, or at least the most influential prisoners, got lodging in the State House, which contained "eight large handsome rooms."',
#  'LJ002-0191': 'Besides those actually resident within the walls,',
#  'LJ002-0192': 'another two hundred more or less took advantage of "the rules," and lived outside within a circumference of two miles and a half.',
#  'LJ002-0193': 'In these cases security was given for the amount of the debt,',
#  'LJ002-0194': 'and a heavy fee at the rate of eight pounds per one hundred pounds, with four pounds for every additional hundred.',
#  'LJ002-0195': 'Besides these, a number had the privilege of a "run on the key," which allowed a prisoner to go into the rules for the day.',
#  'LJ002-0196': 'The foregoing rentals and payments for privileges, together with fees exacted on commitment and discharge, went to the marshal or keeper of the prison,',
#  'LJ002-0197': 'whose net annual income thus entirely derived from the impecunious amounted to between three and four thousand pounds.',
#  'LJ002-0198': 'The office of marshal had been hereditary,',
#  'LJ002-0199': 'but in the twenty-seventh George the second the right of presentation was bought by the Crown for ten thousand, five hundred pounds.',
#  'LJ002-0200': 'The marshal was supposed to be resident either within the prison or the rules.',
#  'LJ002-0201': 'He seems to have felt no responsibility as to the welfare or comfort of those in charge, and out of whom he made all his money.',
#  'LJ002-0202': 'The prison was always in "the most filthy state imaginable."',
#  'LJ002-0203': 'The half or wholly starved prisoners fished for alms or food at the gratings.',
#  'LJ002-0204': 'When they were sick no more notice was taken of them than of a dog.',
#  'LJ002-0205': 'A man dying of liver complaint lay on the cold stones without a bed or food to eat.',
#  'LJ002-0206': 'Dissolute habits prevailed on all sides; drunkenness was universal, gambling perpetual.',
#  'LJ002-0207': 'The yards were taken up with rackets and five courts, and here and there were "bumble puppy grounds," a game in which the players rolled iron balls',
#  'LJ002-0208': 'into holes marked with numbers.',
#  'LJ002-0209': "How to make most profit out of the wretched denizens of the jail was the marshal's only care. He got a rent for the coffee-house and the bake-house;",
#  'LJ002-0210': 'the keeper of the large tap-room called the Brace, because it was once kept by two brothers named Partridge, also paid him toll.',
#  'LJ002-0211': 'The sale of spirits was forbidden, but gin could always be had at the whistling shops, where it was known as Moonshine, Sky Blue,',
#  'LJ002-0212': 'Mexico, and was consumed at the rate of a hogshead per week.',
#  'LJ002-0213': 'The Fleet, which stood in Farringdon Street,',
#  'LJ002-0214': 'was a prison for debtors and persons committed for contempt by the courts of Chancery, Exchequer, and Common Pleas.',
#  'LJ002-0215': 'It was so used for the date of the abolition of the Star Chamber in the sixteenth Charles the first',
#  'LJ002-0216': 'The shameful malpractices of Bambridge,',
#  'LJ002-0217': 'the warden of the Fleet at the commencement of the eighteenth century, are too well known to need more than a passing reference.',
#  'LJ002-0218': 'A committee of the House of Commons investigated the charges against Bambridge, who was proved to have connived at the escape of some debtors,',
#  'LJ002-0219': 'and to have been guilty of extortion to others. One Sir William Rich, Bart., he had loaded with heavy irons',
#  'LJ002-0220': 'In consequence of these disclosures, both Bambridge and Huggin, his predecessor in the office, were committed to Newgate,',
#  'LJ002-0221': 'and many reforms instituted. But the condition of the prison and its inmates remained unsatisfactory to the last.',
#  'LJ002-0222': 'It contained generally from six to seven hundred inmates, while another hundred more or less resided in the rules outside.',
#  'LJ002-0223': 'The principle of "chummage" prevailed as in the King\'s Bench,',
#  'LJ002-0224': 'but a number of rooms, fifteen more or less, were reserved for poor debtors under the name of Bartholomew Fair.',
#  'LJ002-0225': 'The rentals of rooms and fees went to the warden, whose income was two thousand three hundred seventy-two pounds.',
#  'LJ002-0226': 'The same evils of overcrowding, uncleanliness, want of medical attendance,',
#  'LJ002-0227': "absence or neglect of divine service, were present as in the King's Bench, but in an exaggerated form.",
# ...
#  'LJ003-0348': 'Again, there was the new Millbank penitentiary now ready for occupation.',
#  'LJ003-0349': 'Why not relieve Newgate by drawing more largely upon the superior accommodation which Millbank offered?',
#  'LJ004-0001': 'The Chronicles of Newgate, Volume two. By Arthur Griffiths. Section seven: The beginnings of prison reform.',
#  'LJ004-0002': 'While Mrs. Fry was diligently engaged upon her self-imposed task in Newgate,',
#  'LJ004-0003': 'other earnest people, inspired doubtless by her noble example, were stirred up to activity in the same great work.',
#  'LJ004-0004': 'It began to be understood that prison reform could only be compassed by continuous and combined effort.',
#  'LJ004-0005': 'The pleadings, however eloquent, of a single individual were unable to more than partially remedy the widespread and colossal evils of British prisons.',
#  'LJ004-0006': "Howard's energy and devotion were rewarded by lively sympathy, but the desire to improve which followed his exposures was but short-lived.",
#  'LJ004-0007': 'It was so powerless against the persistent neglect of those intrusted with prison management, that, five-and-twenty years later,',
#  'LJ004-0008': 'Mr. Neild, a second Howard,',
#  'LJ004-0009': 'as indefatigable and self-sacrificing, found by personal visitation that the condition of jails throughout the kingdom was,',
#  'LJ004-0010': 'with a few bright exceptions, still deplorable and disgraceful.',
#  'LJ004-0011': 'Mr. Neild was compelled to admit in eighteen twelve that "the great reformation produced by Howard',
#  'LJ004-0012': 'was in several places merely temporary:',
#  'LJ004-0013': 'some prisons that had been ameliorated under the persuasive influence of his kind advice were relapsing into their former horrid state of privation,',
#  'LJ004-0014': 'filthiness, severity, or neglect; many new dungeons had aggravated the evils against which his sagacity could not but remonstrate;',
#  'LJ004-0015': 'the motives for a transient amendment were becoming paralyzed, and the effect had ceased with the cause."',
#  'LJ004-0016': 'I have shown in a previous chapter what Newgate was at this period, despite a vast expenditure and boasted efforts to introduce reforms.',
#  'LJ004-0017': 'Some of the county jails, and one or two borough jails, had been rebuilt,',
#  'LJ004-0018': 'generally through the personal activity of influential and benevolent local magnates, but the true principles of prison construction',
#  'LJ004-0019': 'were as yet but imperfectly understood, and such portions of the "improved" jails of that period as were still extant a few years back,',
#  'LJ004-0020': "contrast ludicrously with the prison architecture based upon a century's experience of our own age.",
#  'LJ004-0021': 'The neglect of prison reform in those days was not to be visited upon the legislature.',
#  'LJ004-0022': 'The executive, although harassed by internal commotion and foreign war, was not entirely callous to the crying need for amelioration in jails.',
#  'LJ004-0023': 'Measures remedial, although at best partial and incomplete, were introduced from time to time.',
#  'LJ004-0024': 'Thus in eighteen thirteen the exaction of jail fees had been forbidden by law,',
#  'LJ004-0025': 'and two other acts more peremptory and precise followed on the same subject in succeeding years.',
#  'LJ004-0026': 'In eighteen fourteen a bill was brought in to insist upon the appointment of chaplains in jails, and when this had passed into law,',
#  'LJ004-0027': 'it was subsequently amplified, and the rates of salaries fixed.',
#  'LJ004-0028': 'Various acts were also passed to consolidate and amend previous jail acts.',
#  'LJ004-0029': 'The erection of new prison buildings was made imperative under certain conditions and following certain rules',
#  'LJ004-0030': 'the principle of classification was freshly enunciated; prison regulations were framed for general observance.',
#  'LJ004-0031': 'But the effect of this legislation was rather weakened by the remoteness of the pressure exercised.',
#  'LJ004-0032': 'The onus of improvement lay upon the magistracy, the local authorities administering local funds,',
#  'LJ004-0033': 'and they were not threatened with any particular penalties if they evaded or ignored the new acts.',
#  'LJ004-0034': 'Moreover, the laws applied more particularly to county jurisdictions.',
#  'LJ004-0035': 'The borough jails, those in fact under corporate management, were not included in the new measures;',
#  'LJ004-0036': 'it was hoped that their rulers would hire accommodation in the county prisons, and that the inferior establishments would in course of time disappear.',
#  'LJ004-0037': 'Yet the borough jails were destined to survive many years, and to exhibit for a long time to come all the worst features of jail mismanagement.',
#  'LJ004-0038': 'It was in eighteen seventeen that a small band of philanthropists resolved to form themselves into an association for the improvement of prison discipline.',
#  'LJ004-0039': 'They were hopeless of any general reform by the action of the executive alone.',
#  'LJ004-0040': 'They felt that private enterprise might',
#  'LJ004-0041': 'with advantage step in, and by the collection and diffusion of information, and the reiteration of sound advice, greatly assist the good work.',
#  'LJ004-0042': 'The association was organized under the most promising auspices.',
#  'LJ004-0043': "A king's son, the Duke of Gloucester, was the patron; among the vice-presidents were many great peers of the realm",
#  'LJ004-0044': 'several bishops, and a number of members of the House of Commons, including Mr. Manners Sutton,',
#  'LJ004-0045': 'Mr. Sturges Bourne, Sir James Mackintosh, Sir James Scarlett, and William Wilberforce.',
#  'LJ004-0046': 'An active committee was appointed, comprising many names already well known, some of them destined to become famous in the annals of philanthropy.',
#  'LJ004-0047': 'One of the moving spirits was the Honorable H. G. Bennet, M.P., whose vigorous protests against the lamentable condition of Newgate have already been recorded.',
#  'LJ004-0048': "Mrs. Fry's brother, Mr. Samuel Hoare, Junior, was chairman of the committee, on which also served many noted members of the Society of Friends",
#  'LJ004-0049': 'Mr. Gurney, Mr. Fry, Messrs. Forster, and Mr. T. F. Buxton, the coadjutor of Wilberforce in the great anti-slavery struggle.',
#  'LJ004-0050': 'Mr. Buxton had already been associated with Mrs. Fry in the Newgate visitation, and his attention had thus been drawn to the neglected state of English prisons.',
#  'LJ004-0051': 'When in Belgium he had examined with great satisfaction the admirable management of the great "Maison de Force" at Ghent,',
#  'LJ004-0052': 'which Howard had eulogized some forty years before.',
#  'LJ004-0054': 'In order to give greater value to the pamphlet,',
#  'LJ004-0055': 'he personally visited several English jails, and pointed his observations by drawing forcible contrasts between the good and bad.',
#  'LJ004-0056': "Mr. Buxton's small work on prison discipline gave a new aspect to the question he had so much at heart.",
#  'LJ004-0057': 'For the first time the doctrine was enunciated that prisoners had rights of their own.',
#  'LJ004-0058': 'The untried, and in the eyes of the law still innocent, could claim pure air, wholesome and sufficient food, and opportunities for exercise.',
#  'LJ004-0059': 'They had a right, Mr. Buxton affirmed, to be employed in their own crafts, provided it could be safely followed in prison.',
#  'LJ004-0060': '"You have no right," he says, addressing the authorities, "to subject a prisoner to suffering from cold,',
#  'LJ004-0061': 'by want of bed-clothing by night or firing by day',
#  'LJ004-0062': 'and the reason is plain: you have taken him from his home, and have deprived him of the means of providing himself with the necessaries or comforts of life,',
#  'LJ004-0063': 'and therefore you are bound to furnish him with moderate indeed but suitable accommodation."',
#  'LJ004-0064': '"You have for the same reason," he goes on, "no right to ruin his habits by compelling him to be idle,',
#  'LJ004-0065': 'his morals by compelling him to mix with a promiscuous assemblage of hardened and convicted criminals,',
#  'LJ004-0066': 'or his health by forcing him at night into a damp, unventilated cell, with such crowds of companions as very speedily render the air foul and putrid;',
#  'LJ004-0067': 'or to make him sleep in close contact with the victims of contagious and loathsome disease,',
#  'LJ004-0068': 'or amidst the noxious effluvia of dirt and corruption.',
#  'LJ004-0069': 'In short, attention to his feelings, mental and bodily, a supply of every necessary, abstraction from evil society,',
#  'LJ004-0070': 'the conservation of his health and industrious habits, are the clear, evident, undeniable rights of an unconvicted prisoner."',
#  'LJ004-0071': 'Nor even when found guilty and his liberty forfeited did his privileges cease. The law appointed a suitable punishment for the offense;',
#  'LJ004-0072': 'it was for those charged with the administration of the law to guard carefully against any aggravation of that punishment,',
#  'LJ004-0073': 'to see that "no circumstances of severity are found in his treatment which are not found in his sentence."',
#  'LJ004-0074': 'No judge ever condemned a man to be half-perished with cold by day, or half-suffocated with heat by night.',
#  'LJ004-0075': '"Who ever heard of a criminal being sentenced to catch the rheumatism or the typhus fever?"',
#  'LJ004-0076': '"Disease, cold, famine, nakedness, and contagious and polluted air are not lawful punishments in the hands of the civil magistrates;',
#  'LJ004-0077': 'nor has he a right to poison or starve his fellow-creatures."',
#  'LJ004-0078': '"The convicted delinquent has his rights," said Mr. Buxton authoritatively.',
#  'LJ004-0079': '"All measures and practices in prison which may injure him in any way are illegal,',
#  'LJ004-0080': 'because they are not specified in his sentence; he is therefore entitled to a wholesome atmosphere,',
#  'LJ004-0081': 'decent clothing and bedding, and a diet sufficient to support him."',
#  'LJ004-0082': 'These somewhat novel but undoubtedly indisputable propositions were backed up, not by sound arguments only, but by the letter of the law.',
#  'LJ004-0083': 'As Mr. Buxton pointed out, many old acts of parliament designed to protect the prisoner were still in full force.',
#  'LJ004-0084': 'Some might be in abeyance, but they had never been repealed, and some were quite freshly imported upon the Statute Book.',
#  'LJ004-0085': 'As far back as the reign of Charles the second, a law was passed declaring that sufficient provision should be made for the relief and setting on work',
#  'LJ004-0086': 'of "poor and needy prisoners committed to the common jail for felony and other misdemeanors, who many times perish before their trial;',
#  'LJ004-0087': 'and the poor there living idle and unemployed become debauched, and come forth instructed in the practice of thievery and lewdness."',
#  'LJ004-0088': 'As a remedy, justices of the peace were empowered to provide materials for the setting of poor prisoners to work,',
#  'LJ004-0089': 'and to pay overseers or instructors out of the county rates.',
#  'LJ004-0090': 'Again, the twenty-two Charles the second c twenty ordered the jailer to keep felons and debtors "separate and apart from one another,',
#  'LJ004-0091': 'in distinct rooms, on pain of forfeiting his office and treble damages to the party aggrieved."',
#  'LJ004-0092': 'A much later act, the fourteen George the third c. fifty-nine (seventeen seventy-four),',
#  'LJ004-0093': "which was contemporaneous with Howard's first journeys, laid down precise rules as regards cleanliness, and the proper supply of space and air.",
#  'LJ004-0094': 'This act set forth that "whereas the malignant fever commonly called the jail distemper',
#  'LJ004-0095': 'is found to be owing to want of cleanliness and fresh air in the several jails,',
#  'LJ004-0096': 'the fatal consequences whereof might be prevented if the justices of the peace were duly authorized',
#  'LJ004-0097': 'to provide such accommodations in jails as may be necessary to answer this salutary purpose,',
#  'LJ004-0098': 'it is enacted that the justices shall order the walls of every room to be scraped and white-washed once every year."',
#  'LJ004-0099': 'Ventilators, hand and others, were to be supplied.',
#  'LJ004-0100': 'An infirmary, consisting of two distinct rooms, one for males and one for females, should be provided for the separate accommodation of the sick.',
#  'LJ004-0101': 'Warm and cold baths, or "commodious bathing tubs,"',
#  'LJ004-0102': 'were to be kept in every jail, and the prisoners directed to wash in them before release. These provisions were almost a dead letter.',
#  'LJ004-0103': 'Yet another act passed in seventeen ninety-one, if properly observed, should have insured proper attention to them.',
#  'LJ004-0104': 'By the thirty-one George the third c. forty-six, s. five,',
#  'LJ004-0105': 'two or more justices were appointed visitors of prisons, and directed to visit and inspect three times every quarter.',
#  'LJ004-0106': 'They were to report in writing to quarter sessions as to the state of the jail, and as to all abuses which they might observe therein.',
#  'LJ004-0107': 'The most important jail act of that early period, however, was the twenty-four George the third c. fifty-four, s. four (seventeen eighty-four)',
#  'LJ004-0108': 'which was the first legislative attempt to compel the classification of prisoners, or their separation into classes',
#  'LJ004-0109': 'according to their categories or crimes.',
#  'LJ004-0110': 'It was made incumbent upon the justices to provide distinct places of confinement for five classes of prisoners, viz.',
#  'LJ004-0111': 'one. Prisoners convicted of felony. two. Prisoners committed on a charge or suspicion of felony.',
#  'LJ004-0112': 'three. Prisoners guilty of misdemeanors. four. Prisoners charged with misdemeanors. five. Debtors.',
#  'LJ004-0113': 'It was further ordered that male prisoners should be kept perfectly distinct from the females.',
#  'LJ004-0114': "King's evidences were also to be lodged apart.",
#  'LJ004-0115': 'Infirmaries separating the sexes were also to be provided, a chapel too, and warm and cold baths.',
#  'LJ004-0116': '"Care also was to be taken that the prisoners shall not be kept in any apartment underground."',
#  'LJ004-0117': 'In an early report of the Prison Discipline Improvement Society,',
#  'LJ004-0118': 'published some six-and-thirty years after the promulgation of this act, the flagrant and persistent violations of it and others',
#  'LJ004-0119': 'which had continued through that long period, are forcibly pointed out.',
#  'LJ004-0120': 'In eighteen eighteen, out of five hundred and eighteen prisons in the United Kingdom,',
#  'LJ004-0121': 'to which a total of upwards of one hundred thousand prisoners had been committed in the year, only twenty-three prisons were divided according to law;',
#  'LJ004-0122': 'fifty-nine had no division whatever to separate males and females; one hundred and thirty-six had only one division for the purpose;',
#  'LJ004-0123': 'sixty-eight had only two divisions, and so on.',
#  'LJ004-0124': 'In four hundred and forty-five prisons no work of any description had been introduced for the employment of prisoners;',
#  'LJ004-0125': 'in the balance some work was done, but with the most meager results.',
#  'LJ004-0126': 'The want of room was still a crying evil.',
#  'LJ004-0127': 'In one hundred jails,',
#  'LJ004-0128': 'capable of accommodating only eight thousand five hundred and forty-five persons, as many as thirteen thousand and fifty-seven were crowded.',
#  'LJ004-0129': 'Many of the jails were in the most deplorable condition:',
#  'LJ004-0130': 'incommodious, as has been stated, insecure, unhealthy, and unprovided with the printed or written regulations required by law.',
#  ...}

# %%
def get_data(wavs, id_to_text, maxlen=50):
    """ returns mapping of audio paths and transcription texts """
    data = []
    for w in wavs:
        id = w.split("\\")[-1].split(".")[0]
        if len(id_to_text[id]) < maxlen:
            data.append({"audio": w, "text": id_to_text[id]})
    return data

# %%
class VectorizeChar:
    def __init__(self, max_len=50):
        self.vocab = (
            ["-", "#", "<", ">"]
            + [chr(i + 96) for i in range(1, 27)]
            + [" ", ".", ",", "?"]
        )
        self.max_len = max_len
        self.char_to_idx = {}
        for i, ch in enumerate(self.vocab):
            self.char_to_idx[ch] = i

    def __call__(self, text):
        text = text.lower()
        text = text[: self.max_len - 2]
        text = "<" + text + ">"
        pad_len = self.max_len - len(text)
        return [self.char_to_idx.get(ch, 1) for ch in text] + [0] * pad_len

    def get_vocabulary(self):
        return self.vocab

# %%
max_target_len = 200  # all transcripts in out data are < 200 characters
data = get_data(wavs, id_to_text, max_target_len)
vectorizer = VectorizeChar(max_target_len)
#print("vocab size", len(vectorizer.get_vocabulary()))

# %%
data
# Out:
# [{'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0001.wav',
#   'text': 'Printing, in the only sense with which we are at present concerned, differs from most if not from all the arts and crafts represented in the Exhibition'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0002.wav',
#   'text': 'in being comparatively modern.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0003.wav',
#   'text': 'For although the Chinese took impressions from wood blocks engraved in relief for centuries before the woodcutters of the Netherlands, by a similar process'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0004.wav',
#   'text': 'produced the block books, which were the immediate predecessors of the true printed book,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0005.wav',
#   'text': 'the invention of movable metal letters in the middle of the fifteenth century may justly be considered as the invention of the art of printing.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0006.wav',
#   'text': 'And it is worth mention in passing that, as an example of fine typography,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0007.wav',
#   'text': 'the earliest book printed with movable types, the Gutenberg, or "forty-two line Bible" of about fourteen fifty-five,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0008.wav',
#   'text': 'has never been surpassed.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0009.wav',
#   'text': 'Printing, then, for our purpose, may be considered as the art of making books by means of movable types.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0010.wav',
#   'text': 'Now, as all books not primarily intended as picture-books consist principally of types composed to form letterpress,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0011.wav',
#   'text': 'it is of the first importance that the letter used should be fine in form;'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0012.wav',
#   'text': 'especially as no more time is occupied, or cost incurred, in casting, setting, or printing beautiful letters'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0013.wav',
#   'text': 'than in the same operations with ugly ones.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0014.wav',
#   'text': 'And it was a matter of course that in the Middle Ages, when the craftsmen took care that beautiful form should always be a part of their productions whatever they were,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0015.wav',
#   'text': 'the forms of printed letters should be beautiful, and that their arrangement on the page should be reasonable and a help to the shapeliness of the letters themselves.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0016.wav',
#   'text': 'The Middle Ages brought calligraphy to perfection, and it was natural therefore'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0017.wav',
#   'text': 'that the forms of printed letters should follow more or less closely those of the written character, and they followed them very closely.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0018.wav',
#   'text': 'The first books were printed in black letter, i.e. the letter which was a Gothic development of the ancient Roman character,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0019.wav',
#   'text': 'and which developed more completely and satisfactorily on the side of the "lower-case" than the capital letters;'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0020.wav',
#   'text': 'the "lower-case" being in fact invented in the early Middle Ages.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0021.wav',
#   'text': 'The earliest book printed with movable type, the aforesaid Gutenberg Bible, is printed in letters which are an exact imitation'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0022.wav',
#   'text': 'of the more formal ecclesiastical writing which obtained at that time; this has since been called "missal type,"'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0023.wav',
#   'text': 'and was in fact the kind of letter used in the many splendid missals, psalters, etc., produced by printing in the fifteenth century.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0024.wav',
#   'text': 'But the first Bible actually dated (which also was printed at Maintz by Peter Schoeffer in the year fourteen sixty-two)'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0025.wav',
#   'text': 'imitates a much freer hand, simpler, rounder, and less spiky, and therefore far pleasanter and easier to read.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0026.wav',
#   'text': 'On the whole the type of this book may be considered the ne-plus-ultra of Gothic type,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0027.wav',
#   'text': 'especially as regards the lower-case letters; and type very similar was used during the next fifteen or twenty years not only by Schoeffer,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0028.wav',
#   'text': 'but by printers in Strasburg, Basle, Paris, Lubeck, and other cities.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0029.wav',
#   'text': 'But though on the whole, except in Italy, Gothic letter was most often used'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0030.wav',
#   'text': 'a very few years saw the birth of Roman character not only in Italy, but in Germany and France.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0031.wav',
#   'text': 'In fourteen sixty-five Sweynheim and Pannartz began printing in the monastery of Subiaco near Rome,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0032.wav',
#   'text': 'and used an exceedingly beautiful type, which is indeed to look at a transition between Gothic and Roman,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0033.wav',
#   'text': 'but which must certainly have come from the study of the twelfth or even the eleventh century MSS.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0034.wav',
#   'text': 'They printed very few books in this type, three only; but in their very first books in Rome, beginning with the year fourteen sixty-eight,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0035.wav',
#   'text': 'they discarded this for a more completely Roman and far less beautiful letter.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0036.wav',
#   'text': 'But about the same year Mentelin at Strasburg began to print in a type which is distinctly Roman;'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0037.wav',
#   'text': 'and the next year Gunther Zeiner at Augsburg followed suit;'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0038.wav',
#   'text': 'while in fourteen seventy at Paris Udalric Gering and his associates turned out the first books printed in France, also in Roman character.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0039.wav',
#   'text': 'The Roman type of all these printers is similar in character,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0040.wav',
#   'text': 'and is very simple and legible, and unaffectedly designed for use; but it is by no means without beauty.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0041.wav',
#   'text': 'It must be said that it is in no way like the transition type of Subiaco,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0042.wav',
#   'text': 'and though more Roman than that, yet scarcely more like the complete Roman type of the earliest printers of Rome.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0043.wav',
#   'text': 'A further development of the Roman letter took place at Venice.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0044.wav',
#   'text': 'John of Spires and his brother Vindelin, followed by Nicholas Jenson, began to print in that city,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0045.wav',
#   'text': 'fourteen sixty-nine, fourteen seventy;'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0046.wav',
#   'text': 'their type is on the lines of the German and French rather than of the Roman printers.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0047.wav',
#   'text': 'Of Jenson it must be said that he carried the development of Roman type as far as it can go:'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0048.wav',
#   'text': 'his letter is admirably clear and regular, but at least as beautiful as any other Roman type.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0049.wav',
#   'text': 'After his death in the "fourteen eighties," or at least by fourteen ninety, printing in Venice had declined very much;'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0050.wav',
#   'text': 'and though the famous family of Aldus restored its technical excellence, rejecting battered letters,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0051.wav',
#   'text': 'and paying great attention to the "press work" or actual process of printing,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0052.wav',
#   'text': "yet their type is artistically on a much lower level than Jenson's, and in fact"},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0053.wav',
#   'text': 'they must be considered to have ended the age of fine printing in Italy.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0054.wav',
#   'text': 'Jenson, however, had many contemporaries who used beautiful type,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0055.wav',
#   'text': 'some of which -- as, e.g., that of Jacobus Rubeus or Jacques le Rouge -- is scarcely distinguishable from his.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0056.wav',
#   'text': 'It was these great Venetian printers, together with their brethren of Rome, Milan,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0057.wav',
#   'text': "Parma, and one or two other cities, who produced the splendid editions of the Classics, which are one of the great glories of the printer's art,"},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0058.wav',
#   'text': 'and are worthy representatives of the eager enthusiasm for the revived learning of that epoch. By far,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0059.wav',
#   'text': 'the greater part of these Italian printers, it should be mentioned, were Germans or Frenchmen, working under the influence of Italian opinion and aims.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0060.wav',
#   'text': 'It must be understood that through the whole of the fifteenth and the first quarter of the sixteenth centuries'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0061.wav',
#   'text': 'the Roman letter was used side by side with the Gothic.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0062.wav',
#   'text': 'Even in Italy most of the theological and law books were printed in Gothic letter,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0063.wav',
#   'text': 'which was generally more formally Gothic than the printing of the German workmen,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0064.wav',
#   'text': 'many of whose types, indeed, like that of the Subiaco works, are of a transitional character.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0065.wav',
#   'text': 'This was notably the case with the early works printed at Ulm, and in a somewhat lesser degree at Augsburg.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0066.wav',
#   'text': "In fact Gunther Zeiner's first type (afterwards used by Schussler) is remarkably like the type of the before-mentioned Subiaco books."},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0067.wav',
#   'text': 'In the Low Countries and Cologne, which were very fertile of printed books, Gothic was the favorite.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0068.wav',
#   'text': 'The characteristic Dutch type, as represented by the excellent printer Gerard Leew, is very pronounced and uncompromising Gothic.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0069.wav',
#   'text': "This type was introduced into England by Wynkyn de Worde, Caxton's successor,"},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0070.wav',
#   'text': 'and was used there with very little variation all through the sixteenth and seventeenth centuries, and indeed into the eighteenth.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0071.wav',
#   'text': "Most of Caxton's own types are of an earlier character, though they also much resemble Flemish or Cologne letter."},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0072.wav',
#   'text': 'After the end of the fifteenth century the degradation of printing, especially in Germany and Italy,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0073.wav',
#   'text': 'went on apace; and by the end of the sixteenth century there was no really beautiful printing done:'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0074.wav',
#   'text': 'the best, mostly French or Low-Country, was neat and clear, but without any distinction;'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0075.wav',
#   'text': 'the worst, which perhaps was the English, was a terrible falling-off from the work of the earlier presses;'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0076.wav',
#   'text': 'and things got worse and worse through the whole of the seventeenth century, so that in the eighteenth printing was very miserably performed.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0077.wav',
#   'text': 'In England about this time, an attempt was made (notably by Caslon, who started business in London as a type-founder in seventeen twenty)'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0078.wav',
#   'text': 'to improve the letter in form.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0079.wav',
#   'text': "Caslon's type is clear and neat, and fairly well designed;"},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0080.wav',
#   'text': 'he seems to have taken the letter of the Elzevirs of the seventeenth century for his model:'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0081.wav',
#   'text': 'type cast from his matrices is still in everyday use.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0082.wav',
#   'text': 'In spite, however, of his praiseworthy efforts, printing had still one last degradation to undergo.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0083.wav',
#   'text': 'The seventeenth century founts were bad rather negatively than positively.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0084.wav',
#   'text': 'But for the beauty of the earlier work they might have seemed tolerable.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0085.wav',
#   'text': 'It was reserved for the founders of the later eighteenth century to produce letters which are positively ugly, and which, it may be added,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0086.wav',
#   'text': 'are dazzling and unpleasant to the eye owing to the clumsy thickening and vulgar thinning of the lines:'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0087.wav',
#   'text': 'for the seventeenth-century letters are at least pure and simple in line. The Italian, Bodoni, and the Frenchman, Didot,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0088.wav',
#   'text': 'were the leaders in this luckless change, though our own Baskerville, who was at work some years before them, went much on the same lines;'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0089.wav',
#   'text': 'but his letters, though uninteresting and poor, are not nearly so gross and vulgar as those of either the Italian or the Frenchman.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0090.wav',
#   'text': 'With this change the art of printing touched bottom,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0091.wav',
#   'text': 'so far as fine printing is concerned, though paper did not get to its worst till about eighteen forty.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0092.wav',
#   'text': "The Chiswick press in eighteen forty-four revived Caslon's founts, printing for Messrs. Longman the Diary of Lady Willoughby."},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0093.wav',
#   'text': 'This experiment was so far successful that about eighteen fifty Messrs. Miller and Richard of Edinburgh'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0094.wav',
#   'text': 'were induced to cut punches for a series of "old style" letters.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0095.wav',
#   'text': 'These and similar founts, cast by the above firm and others,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0096.wav',
#   'text': 'have now come into general use and are obviously a great improvement on the ordinary "modern style" in use in England, which is in fact the Bodoni type'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0097.wav',
#   'text': 'a little reduced in ugliness. The design of the letters of this modern "old style" leaves a good deal to be desired,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0098.wav',
#   'text': 'and the whole effect is a little too gray, owing to the thinness of the letters.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0099.wav',
#   'text': 'It must be remembered, however, that most modern printing is done by machinery on soft paper, and not by the hand press,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0100.wav',
#   'text': 'and these somewhat wiry letters are suitable for the machine process, which would not do justice to letters of more generous design.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0101.wav',
#   'text': 'It is discouraging to note that the improvement of the last fifty years is almost wholly confined to Great Britain.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0102.wav',
#   'text': 'Here and there a book is printed in France or Germany with some pretension to good taste,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0103.wav',
#   'text': 'but the general revival of the old forms has made no way in those countries.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0104.wav',
#   'text': 'Italy is contentedly stagnant.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0105.wav',
#   'text': 'America has produced a good many showy books, the typography, paper, and illustrations of which are, however, all wrong,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0106.wav',
#   'text': 'oddity rather than rational beauty and meaning being apparently the thing sought for both in the letters and the illustrations.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0107.wav',
#   'text': 'To say a few words on the principles of design in typography:'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0108.wav',
#   'text': 'it is obvious that legibility is the first thing to be aimed at in the forms of the letters;'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0109.wav',
#   'text': 'this is best furthered by the avoidance of irrational swellings and spiky projections, and by the using of careful purity of line.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0110.wav',
#   'text': 'Even the Caslon type when enlarged shows great shortcomings in this respect:'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0111.wav',
#   'text': 'the ends of many of the letters such as the t and e are hooked up in a vulgar and meaningless way,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0112.wav',
#   'text': "instead of ending in the sharp and clear stroke of Jenson's letters;"},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0113.wav',
#   'text': 'there is a grossness in the upper finishings of letters like the c, the a, and so on,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0114.wav',
#   'text': 'an ugly pear-shaped swelling defacing the form of the letter:'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0115.wav',
#   'text': 'in short, it happens to this craft, as to others, that the utilitarian practice, though it professes to avoid ornament,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0116.wav',
#   'text': 'still clings to a foolish, because misunderstood conventionality, deduced from what was once ornament, and is by no means useful;'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0117.wav',
#   'text': 'which title can only be claimed by artistic practice, whether the art in it be conscious or unconscious.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0118.wav',
#   'text': 'In no characters is the contrast between the ugly and vulgar illegibility of the modern type'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0119.wav',
#   'text': 'and the elegance and legibility of the ancient more striking than in the Arabic numerals.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0120.wav',
#   'text': 'In the old print each figure has its definite individuality, and one cannot be mistaken for the other;'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0121.wav',
#   'text': 'in reading the modern figures the eyes must be strained before the reader can have any reasonable assurance'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0122.wav',
#   'text': 'that he has a five, an eight, or a three before him, unless the press work is of the best:'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0123.wav',
#   'text': "this is awkward if you have to read Bradshaw's Guide in a hurry."},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0124.wav',
#   'text': 'One of the differences between the fine type and the utilitarian must probably be put down to a misapprehension of a commercial necessity:'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0125.wav',
#   'text': 'this is the narrowing of the modern letters.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0126.wav',
#   'text': "Most of Jenson's letters are designed within a square,"},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0127.wav',
#   'text': 'the modern letters are narrowed by a third or thereabout; but while this gain of space very much hampers the possibility of beauty of design,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0128.wav',
#   'text': 'it is not a real gain, for the modern printer throws the gain away by putting inordinately wide spaces between his lines, which, probably,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0129.wav',
#   'text': 'the lateral compression of his letters renders necessary.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0130.wav',
#   'text': 'Commercialism again compels the use of type too small in size to be comfortable reading:'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0131.wav',
#   'text': 'the size known as "Long primer" ought to be the smallest size used in a book meant to be read.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0132.wav',
#   'text': 'Here, again, if the practice of "leading" were retrenched larger type could be used without enhancing the price of a book.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0133.wav',
#   'text': 'One very important matter in "setting up" for fine printing is the "spacing," that is, the lateral distance of words from one another.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0134.wav',
#   'text': 'In good printing the spaces between the words should be as near as possible equal'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0135.wav',
#   'text': 'it is impossible that they should be quite equal except in lines of poetry'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0136.wav',
#   'text': 'modern printers understand this, but it is only practiced in the very best establishments.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0137.wav',
#   'text': 'But another point which they should attend to they almost always disregard;'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0138.wav',
#   'text': 'this is the tendency to the formation of ugly meandering white lines or "rivers" in the page'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0139.wav',
#   'text': 'a blemish which can be nearly, though not wholly, avoided by care and forethought'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0140.wav',
#   'text': 'the desirable thing being "the breaking of the line" as in bonding masonry or brickwork'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0141.wav',
#   'text': 'The general solidity of a page is much to be sought for'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0142.wav',
#   'text': 'modern printers generally overdo the "whites" in the spacing, a defect probably forced on them by the characterless quality of the letters.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0143.wav',
#   'text': 'For where these are boldly and carefully designed, and each letter is thoroughly individual in form,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0144.wav',
#   'text': 'the words may be set much closer together, without loss of clearness.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0145.wav',
#   'text': 'No definite rules, however, except the avoidance of "rivers" and excess of white, can be given for the spacing,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0146.wav',
#   'text': 'which requires the constant exercise of judgment and taste on the part of the printer.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0147.wav',
#   'text': 'The position of the page on the paper should be considered if the book is to have a satisfactory look.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0148.wav',
#   'text': 'Here once more the almost invariable modern practice is in opposition to a natural sense of proportion.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0149.wav',
#   'text': 'From the time when books first took their present shape till the end of the sixteenth century, or indeed later,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0150.wav',
#   'text': 'the page so lay on the paper that there was more space allowed to the bottom and fore margin than to the top and back of the paper,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0151.wav',
#   'text': 'the unit of the book being looked on as the two pages forming an opening.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0152.wav',
#   'text': 'The modern printer, in the teeth of the evidence given by his own eyes, considers the single page as the unit, and prints the page in the middle of his paper'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0153.wav',
#   'text': 'only nominally so, however, in many cases, since when he uses a headline he counts that in,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0154.wav',
#   'text': 'the result as measured by the eye being that the lower margin is less than the top one, and that the whole opening has an upside-down look vertically'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0155.wav',
#   'text': 'and that laterally the page looks as if it were being driven off the paper.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0156.wav',
#   'text': 'The paper on which the printing is to be done is a necessary part of our subject:'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0157.wav',
#   'text': 'of this it may be said that though there is some good paper made now,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0158.wav',
#   'text': 'it is never used except for very expensive books, although it would not materially increase the cost in all but the very cheapest.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0159.wav',
#   'text': 'The paper that is used for ordinary books is exceedingly bad even in this country, but is beaten in the race for vileness'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0160.wav',
#   'text': 'by that made in America, which is the worst conceivable.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0161.wav',
#   'text': 'There seems to be no reason why ordinary paper should not be better made,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0162.wav',
#   'text': 'even allowing the necessity for a very low price; but any improvement must be based on showing openly that the cheap article is cheap,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0163.wav',
#   'text': 'e.g. the cheap paper should not sacrifice toughness and durability to a smooth and white surface,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0164.wav',
#   'text': 'which should be indications of a delicacy of material and manufacture which would of necessity increase its cost.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0165.wav',
#   'text': 'One fruitful source of badness in paper'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0166.wav',
#   'text': 'is the habit that publishers have of eking out a thin volume by printing it on thick paper almost of the substance of cardboard,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0167.wav',
#   'text': 'a device which deceives nobody, and makes a book very unpleasant to read.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0168.wav',
#   'text': 'On the whole, a small book should be printed on paper which is as thin as may be without being transparent.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0169.wav',
#   'text': 'The paper used for printing the small highly ornamented French service-books about the beginning of the sixteenth century is a model in this respect,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0170.wav',
#   'text': 'being thin, tough, and opaque.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0171.wav',
#   'text': 'However, the fact must not be blinked that machine-made paper cannot in the nature of things be made of so good a texture as that made by hand.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0172.wav',
#   'text': 'The ornamentation of printed books is too wide a subject to be dealt with fully here; but one thing must be said on it.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0173.wav',
#   'text': 'The essential point to be remembered is that the ornament, whatever it is, whether picture or pattern-work, should form part of the page,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0174.wav',
#   'text': 'should be a part of the whole scheme of the book.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0175.wav',
#   'text': 'Simple as this proposition is, it is necessary to be stated,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0176.wav',
#   'text': 'because the modern practice is to disregard the relation between the printing and the ornament altogether,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0177.wav',
#   'text': 'so that if the two are helpful to one another it is a mere matter of accident.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0178.wav',
#   'text': 'The due relation of letter to pictures and other ornament was thoroughly understood by the old printers; so that'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0179.wav',
#   'text': 'even when the woodcuts are very rude indeed,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0180.wav',
#   'text': 'the proportions of the page still give pleasure by the sense of richness that the cuts and letter together convey.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0181.wav',
#   'text': 'When, as is most often the case, there is actual beauty in the cuts,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0182.wav',
#   'text': 'the books so ornamented are amongst the most delightful works of art that have ever been produced.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0183.wav',
#   'text': 'Therefore, granted well-designed type, due spacing of the lines and words, and proper position of the page on the paper,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0184.wav',
#   'text': 'all books might be at least comely and well-looking: and if to these good qualities were added really beautiful ornament and pictures,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0185.wav',
#   'text': 'printed books might once again illustrate to the full'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ001-0186.wav',
#   'text': 'the position of our Society that a work of utility might be also a work of art, if we cared to make it so.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0001.wav',
#   'text': 'The Chronicles of Newgate, Volume two. By Arthur Griffiths. Section four: Newgate down to eighteen eighteen.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0002.wav',
#   'text': 'Under the conditions referred to in the previous chapter,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0003.wav',
#   'text': 'with criminals and misdemeanants of all shades crowding perpetually into its narrow limits, the latter state of Newgate was worse than the first.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0004.wav',
#   'text': 'The new jail fell as far short of the demands made on it as did the old.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0005.wav',
#   'text': 'The prison population fluctuated a great deal,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0006.wav',
#   'text': 'but it was almost always in excess of the accommodation available, and there were times when the place was full to overflowing.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0007.wav',
#   'text': 'Neild gives some figures which well illustrate this.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0008.wav',
#   'text': 'On the fourteenth June, eighteen hundred, there were one hundred ninety-nine debtors and two hundred eighty-nine felons in the prison.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0009.wav',
#   'text': 'On the twenty-seventh April, in the following year,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0010.wav',
#   'text': 'these numbers had risen to two hundred seventy-five and three hundred seventy-five respectively, or six hundred fifty in all.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0011.wav',
#   'text': 'For two more years these high figures were steadily maintained, and in eighteen oh three the total rose to seven hundred ten.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0012.wav',
#   'text': 'After that they fell as steadily,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0013.wav',
#   'text': 'till, eighteen oh eight, the lowest point was touched of one hundred ninety-seven debtors and one hundred eighty-two felons, or three hundred seventy-nine in all.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0014.wav',
#   'text': 'The numbers soon increased, however, and by eighteen eleven had again risen to six hundred twenty-nine; and Mr. Neild was told that there had been at one time'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0015.wav',
#   'text': 'three hundred debtors and nine hundred criminals in Newgate, or twelve hundred prisoners in all.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0016.wav',
#   'text': "Previous to that date there had been seven hundred or eight hundred frequently, and once, in Mr. Akerman's time, one thousand."},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0017.wav',
#   'text': 'Trustworthy evidence is forthcoming to the effect that these high figures were constantly maintained for many months at a time.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0018.wav',
#   'text': 'The inadequacy of the jail was noticed and reported upon again and again by the grand juries of the city of London,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0019.wav',
#   'text': 'who seldom let a session go by without visiting Newgate.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0020.wav',
#   'text': 'In eighteen thirteen'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0021.wav',
#   'text': "the grand jury made a special presentment to the Court of Common Council, pointing out that on the debtors' side, which was intended for only one hundred,"},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0022.wav',
#   'text': 'no less than three hundred forty were crowded, to the great inconvenience and danger of the inmates.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0023.wav',
#   'text': 'On the female side matters were much worse;'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0024.wav',
#   'text': 'Quote. the apartments set apart for them, being built to accommodate sixty persons, now contain about one hundred twenty. End quote.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0025.wav',
#   'text': 'Returns laid before the House of Commons showed that six thousand, four hundred thirty-nine persons had been committed to Newgate'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0026.wav',
#   'text': 'in the three years between eighteen thirteen and eighteen sixteen,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0027.wav',
#   'text': 'and this number did not include the debtors, a numerous class, who were still committed to Newgate pending the completion of the White Cross Street prison.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0028.wav',
#   'text': 'In order to realize the evils entailed by incarceration in Newgate in these days, it is necessary to give some account of its interior'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0029.wav',
#   'text': 'as it was occupied and appropriated in eighteen ten.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0030.wav',
#   'text': 'Full details of the arrangements are to be found in Mr. Neild\'s "State of Prisons in England, Scotland, and Wales," published in eighteen twelve.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0031.wav',
#   'text': 'The jail at that date was divided into eight separate and more or less distinct departments, each of which had its own wards and yard.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0032.wav',
#   'text': "These were: one. The male debtors' side."},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0033.wav',
#   'text': "two. The female debtors' side. three. The chapel yard. four. The middle yard."},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0034.wav',
#   'text': "five. The master felons' side. six. The female felons' side. seven. The state side."},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0035.wav',
#   'text': 'eight. The press yard.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0036.wav',
#   'text': "one. The male debtors' side consisted of a yard forty-nine feet by thirty-one,"},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0037.wav',
#   'text': 'leading to thirteen wards on various floors, and a day room.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0038.wav',
#   'text': 'Of these wards, three were appropriated to the "cabin side," so called because'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0039.wav',
#   'text': 'they each contained four small rooms or "cabins" seven feet square,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0040.wav',
#   'text': 'intended to accommodate a couple of prisoners apiece, but often much more crowded.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0041.wav',
#   'text': "Two other wards were appropriated to the master's side debtors; they were each twenty-three feet by fourteen and a half,"},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0042.wav',
#   'text': 'and supposed to accommodate twenty persons. The eight remaining wards were for the common side debtors,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0043.wav',
#   'text': 'long narrow rooms -- one thirty-six feet, six twenty-three feet, and the eighth eighteen,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0044.wav',
#   'text': 'the whole about fifteen feet wide.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0045.wav',
#   'text': 'The various wards were all about eleven feet in height,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ002-0046.wav',
# ...
#   'text': 'he personally visited several English jails, and pointed his observations by drawing forcible contrasts between the good and bad.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0056.wav',
#   'text': "Mr. Buxton's small work on prison discipline gave a new aspect to the question he had so much at heart."},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0057.wav',
#   'text': 'For the first time the doctrine was enunciated that prisoners had rights of their own.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0058.wav',
#   'text': 'The untried, and in the eyes of the law still innocent, could claim pure air, wholesome and sufficient food, and opportunities for exercise.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0059.wav',
#   'text': 'They had a right, Mr. Buxton affirmed, to be employed in their own crafts, provided it could be safely followed in prison.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0060.wav',
#   'text': '"You have no right," he says, addressing the authorities, "to subject a prisoner to suffering from cold,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0061.wav',
#   'text': 'by want of bed-clothing by night or firing by day'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0062.wav',
#   'text': 'and the reason is plain: you have taken him from his home, and have deprived him of the means of providing himself with the necessaries or comforts of life,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0063.wav',
#   'text': 'and therefore you are bound to furnish him with moderate indeed but suitable accommodation."'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0064.wav',
#   'text': '"You have for the same reason," he goes on, "no right to ruin his habits by compelling him to be idle,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0065.wav',
#   'text': 'his morals by compelling him to mix with a promiscuous assemblage of hardened and convicted criminals,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0066.wav',
#   'text': 'or his health by forcing him at night into a damp, unventilated cell, with such crowds of companions as very speedily render the air foul and putrid;'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0067.wav',
#   'text': 'or to make him sleep in close contact with the victims of contagious and loathsome disease,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0068.wav',
#   'text': 'or amidst the noxious effluvia of dirt and corruption.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0069.wav',
#   'text': 'In short, attention to his feelings, mental and bodily, a supply of every necessary, abstraction from evil society,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0070.wav',
#   'text': 'the conservation of his health and industrious habits, are the clear, evident, undeniable rights of an unconvicted prisoner."'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0071.wav',
#   'text': 'Nor even when found guilty and his liberty forfeited did his privileges cease. The law appointed a suitable punishment for the offense;'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0072.wav',
#   'text': 'it was for those charged with the administration of the law to guard carefully against any aggravation of that punishment,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0073.wav',
#   'text': 'to see that "no circumstances of severity are found in his treatment which are not found in his sentence."'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0074.wav',
#   'text': 'No judge ever condemned a man to be half-perished with cold by day, or half-suffocated with heat by night.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0075.wav',
#   'text': '"Who ever heard of a criminal being sentenced to catch the rheumatism or the typhus fever?"'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0076.wav',
#   'text': '"Disease, cold, famine, nakedness, and contagious and polluted air are not lawful punishments in the hands of the civil magistrates;'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0077.wav',
#   'text': 'nor has he a right to poison or starve his fellow-creatures."'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0078.wav',
#   'text': '"The convicted delinquent has his rights," said Mr. Buxton authoritatively.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0079.wav',
#   'text': '"All measures and practices in prison which may injure him in any way are illegal,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0080.wav',
#   'text': 'because they are not specified in his sentence; he is therefore entitled to a wholesome atmosphere,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0081.wav',
#   'text': 'decent clothing and bedding, and a diet sufficient to support him."'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0082.wav',
#   'text': 'These somewhat novel but undoubtedly indisputable propositions were backed up, not by sound arguments only, but by the letter of the law.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0083.wav',
#   'text': 'As Mr. Buxton pointed out, many old acts of parliament designed to protect the prisoner were still in full force.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0084.wav',
#   'text': 'Some might be in abeyance, but they had never been repealed, and some were quite freshly imported upon the Statute Book.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0085.wav',
#   'text': 'As far back as the reign of Charles the second, a law was passed declaring that sufficient provision should be made for the relief and setting on work'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0086.wav',
#   'text': 'of "poor and needy prisoners committed to the common jail for felony and other misdemeanors, who many times perish before their trial;'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0087.wav',
#   'text': 'and the poor there living idle and unemployed become debauched, and come forth instructed in the practice of thievery and lewdness."'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0088.wav',
#   'text': 'As a remedy, justices of the peace were empowered to provide materials for the setting of poor prisoners to work,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0089.wav',
#   'text': 'and to pay overseers or instructors out of the county rates.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0090.wav',
#   'text': 'Again, the twenty-two Charles the second c twenty ordered the jailer to keep felons and debtors "separate and apart from one another,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0091.wav',
#   'text': 'in distinct rooms, on pain of forfeiting his office and treble damages to the party aggrieved."'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0092.wav',
#   'text': 'A much later act, the fourteen George the third c. fifty-nine (seventeen seventy-four),'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0093.wav',
#   'text': "which was contemporaneous with Howard's first journeys, laid down precise rules as regards cleanliness, and the proper supply of space and air."},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0094.wav',
#   'text': 'This act set forth that "whereas the malignant fever commonly called the jail distemper'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0095.wav',
#   'text': 'is found to be owing to want of cleanliness and fresh air in the several jails,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0096.wav',
#   'text': 'the fatal consequences whereof might be prevented if the justices of the peace were duly authorized'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0097.wav',
#   'text': 'to provide such accommodations in jails as may be necessary to answer this salutary purpose,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0098.wav',
#   'text': 'it is enacted that the justices shall order the walls of every room to be scraped and white-washed once every year."'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0099.wav',
#   'text': 'Ventilators, hand and others, were to be supplied.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0100.wav',
#   'text': 'An infirmary, consisting of two distinct rooms, one for males and one for females, should be provided for the separate accommodation of the sick.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0101.wav',
#   'text': 'Warm and cold baths, or "commodious bathing tubs,"'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0102.wav',
#   'text': 'were to be kept in every jail, and the prisoners directed to wash in them before release. These provisions were almost a dead letter.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0103.wav',
#   'text': 'Yet another act passed in seventeen ninety-one, if properly observed, should have insured proper attention to them.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0104.wav',
#   'text': 'By the thirty-one George the third c. forty-six, s. five,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0105.wav',
#   'text': 'two or more justices were appointed visitors of prisons, and directed to visit and inspect three times every quarter.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0106.wav',
#   'text': 'They were to report in writing to quarter sessions as to the state of the jail, and as to all abuses which they might observe therein.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0107.wav',
#   'text': 'The most important jail act of that early period, however, was the twenty-four George the third c. fifty-four, s. four (seventeen eighty-four)'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0108.wav',
#   'text': 'which was the first legislative attempt to compel the classification of prisoners, or their separation into classes'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0109.wav',
#   'text': 'according to their categories or crimes.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0110.wav',
#   'text': 'It was made incumbent upon the justices to provide distinct places of confinement for five classes of prisoners, viz.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0111.wav',
#   'text': 'one. Prisoners convicted of felony. two. Prisoners committed on a charge or suspicion of felony.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0112.wav',
#   'text': 'three. Prisoners guilty of misdemeanors. four. Prisoners charged with misdemeanors. five. Debtors.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0113.wav',
#   'text': 'It was further ordered that male prisoners should be kept perfectly distinct from the females.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0114.wav',
#   'text': "King's evidences were also to be lodged apart."},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0115.wav',
#   'text': 'Infirmaries separating the sexes were also to be provided, a chapel too, and warm and cold baths.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0116.wav',
#   'text': '"Care also was to be taken that the prisoners shall not be kept in any apartment underground."'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0117.wav',
#   'text': 'In an early report of the Prison Discipline Improvement Society,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0118.wav',
#   'text': 'published some six-and-thirty years after the promulgation of this act, the flagrant and persistent violations of it and others'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0119.wav',
#   'text': 'which had continued through that long period, are forcibly pointed out.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0120.wav',
#   'text': 'In eighteen eighteen, out of five hundred and eighteen prisons in the United Kingdom,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0121.wav',
#   'text': 'to which a total of upwards of one hundred thousand prisoners had been committed in the year, only twenty-three prisons were divided according to law;'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0122.wav',
#   'text': 'fifty-nine had no division whatever to separate males and females; one hundred and thirty-six had only one division for the purpose;'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0123.wav',
#   'text': 'sixty-eight had only two divisions, and so on.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0124.wav',
#   'text': 'In four hundred and forty-five prisons no work of any description had been introduced for the employment of prisoners;'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0125.wav',
#   'text': 'in the balance some work was done, but with the most meager results.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0126.wav',
#   'text': 'The want of room was still a crying evil.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0127.wav',
#   'text': 'In one hundred jails,'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0128.wav',
#   'text': 'capable of accommodating only eight thousand five hundred and forty-five persons, as many as thirteen thousand and fifty-seven were crowded.'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0129.wav',
#   'text': 'Many of the jails were in the most deplorable condition:'},
#  {'audio': 'C:\\Users\\abdul\\project_presentation\\datasets\\LJSpeech\\wavs\\LJ004-0130.wav',
#   'text': 'incommodious, as has been stated, insecure, unhealthy, and unprovided with the printed or written regulations required by law.'},
#  ...]

# %%
len(data)
# Out:
# 3570

# %%
import tensorflow as tf


def create_text_ds(data):
    texts = [_["text"] for _ in data]
    text_ds = [vectorizer(t) for t in texts]
    text_ds = tf.data.Dataset.from_tensor_slices(text_ds)
    return text_ds

def path_to_audio(path):
    # spectrogram using stft
    audio = tf.io.read_file(path)
    audio, _ = tf.audio.decode_wav(audio, 1)
    audio = tf.squeeze(audio, axis=-1)
    
    # Apply spectrogram transformation
    stfts = tf.signal.stft(audio, frame_length=200, frame_step=80, fft_length=256)
    x = tf.math.pow(tf.abs(stfts), 0.5)
    
    # Convert to logarithmic scale
    log_spectrogram = tf.math.log(tf.abs(x) + 1e-5)
    
    # Normalization
    means = tf.math.reduce_mean(log_spectrogram, axis=1, keepdims=True)
    stddevs = tf.math.reduce_std(log_spectrogram, axis=1, keepdims=True)
    log_spectrogram = (log_spectrogram - means) / stddevs
    
    # Padding to 10 seconds
    pad_len = 2754
    paddings = tf.constant([[0, pad_len], [0, 0]])
    log_spectrogram = tf.pad(log_spectrogram, paddings, "CONSTANT")[:pad_len, :]
    
    return log_spectrogram

def create_audio_ds(data):
    flist = [_["audio"] for _ in data]
    audio_ds = tf.data.Dataset.from_tensor_slices(flist)
    audio_ds = audio_ds.map(
        path_to_audio, num_parallel_calls=tf.data.AUTOTUNE
    )
    return audio_ds

def create_tf_dataset(data, bs=4):
    audio_ds = create_audio_ds(data)
    text_ds = create_text_ds(data)
    ##print(text_ds)
    ds = tf.data.Dataset.zip((audio_ds, text_ds))
    ds = ds.map(lambda x, y: {"source": x, "target": y})
    ds = ds.batch(bs)
    ds = ds.prefetch(tf.data.AUTOTUNE)
    return ds

# Example usage
split = int(len(data) * 0.99)
train_data = data[:split]
test_data = data[split:]
ds = create_tf_dataset(train_data, bs=64)
val_ds = create_tf_dataset(test_data, bs=4)

# %%
def create_text_ds(data):
    texts = [_["text"] for _ in data]
    text_ds = [vectorizer(t) for t in texts]
    text_ds = tf.data.Dataset.from_tensor_slices(text_ds)
    return text_ds


def path_to_audio(path):
    # spectrogram using stft
    audio = tf.io.read_file(path)
    audio, _ = tf.audio.decode_wav(audio, 1)
    #print(audio)
    audio = tf.squeeze(audio, axis=-1)
    #print(audio)
    stfts = tf.signal.stft(audio, frame_length=200, frame_step=80, fft_length=256)
    x = tf.math.pow(tf.abs(stfts), 0.5)
    # normalisation
    means = tf.math.reduce_mean(x, 1, keepdims=True)
    stddevs = tf.math.reduce_std(x, 1, keepdims=True)
    x = (x - means) / stddevs
    audio_len = tf.shape(x)[0]
    # padding to 10 seconds
    pad_len = 2754
    paddings = tf.constant([[0, pad_len], [0, 0]])
    x = tf.pad(x, paddings, "CONSTANT")[:pad_len, :]
    return x


def create_audio_ds(data):
    flist = [_["audio"] for _ in data]
    audio_ds = tf.data.Dataset.from_tensor_slices(flist)
    audio_ds = audio_ds.map(
        path_to_audio, num_parallel_calls=tf.data.AUTOTUNE
    )
    return audio_ds


def create_tf_dataset(data, bs=4):
    audio_ds = create_audio_ds(data)
    text_ds = create_text_ds(data)
    ds = tf.data.Dataset.zip((audio_ds, text_ds))
    ds = ds.map(lambda x, y: {"source": x, "target": y})
    ds = ds.batch(bs)
    ds = ds.prefetch(tf.data.AUTOTUNE)
    return ds


split = int(len(data) * 0.99)
train_data = data[:split]
test_data = data[split:]
ds = create_tf_dataset(train_data, bs=64)
val_ds = create_tf_dataset(test_data, bs=4)

# %%
ds
# Out:
# <PrefetchDataset shapes: {source: (None, None, 129), target: (None, 200)}, types: {source: tf.float32, target: tf.int32}>

# %%
class TokenEmbedding(layers.Layer):
    def __init__(self, num_vocab=1000, maxlen=100, num_hid=64):
        super().__init__()
        self.emb = tf.keras.layers.Embedding(num_vocab, num_hid)
        self.pos_emb = layers.Embedding(input_dim=maxlen, output_dim=num_hid)

    def call(self, x):
        maxlen = tf.shape(x)[-1]
        #print("tokens", x[:20])
        #print(x.shape, "token embeddnng1")
        x = self.emb(x)
        #print(x.shape, "token embeddnng2")
        positions = tf.range(start=0, limit=maxlen, delta=1)
        positions = self.pos_emb(positions)
        return x + positions


class SpeechFeatureEmbedding(layers.Layer):
    def __init__(self, num_hid=64, maxlen=100):
        super().__init__()
        self.conv1 = tf.keras.layers.Conv1D(
            num_hid, 11, strides=2, padding="same", activation="relu"
        )
        self.conv2 = tf.keras.layers.Conv1D(
            num_hid, 11, strides=2, padding="same", activation="relu"
        )
        self.conv3 = tf.keras.layers.Conv1D(
            num_hid, 11, strides=2, padding="same", activation="relu"
        )
        self.pos_emb = layers.Embedding(input_dim=maxlen, output_dim=num_hid)

    def call(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        return self.conv3(x)

# %%
class TransformerEncoder(layers.Layer):
    def __init__(self, embed_dim, num_heads, feed_forward_dim, rate=0.1):
        super().__init__()
        self.att = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.ffn = keras.Sequential(
            [
                layers.Dense(feed_forward_dim, activation="relu"),
                layers.Dense(embed_dim),
            ]
        )
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = layers.Dropout(rate)
        self.dropout2 = layers.Dropout(rate)

    def call(self, inputs, training):
        attn_output = self.att(inputs, inputs)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output)

# %%
class TransformerDecoder(layers.Layer):
    def __init__(self, embed_dim, num_heads, feed_forward_dim, dropout_rate=0.1):
        super().__init__()
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm3 = layers.LayerNormalization(epsilon=1e-6)
        self.self_att = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim
        )
        self.enc_att = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.self_dropout = layers.Dropout(0.5)
        self.enc_dropout = layers.Dropout(0.1)
        self.ffn_dropout = layers.Dropout(0.1)
        self.ffn = keras.Sequential(
            [
                layers.Dense(feed_forward_dim, activation="relu"),
                layers.Dense(embed_dim),
            ]
        )

    def causal_attention_mask(self, batch_size, n_dest, n_src, dtype):
        """Masks the upper half of the dot product matrix in self attention.

        This prevents flow of information from future tokens to current token.
        1's in the lower triangle, counting from the lower right corner.
        """
        i = tf.range(n_dest)[:, None]
        j = tf.range(n_src)
        m = i >= j - n_src + n_dest
        mask = tf.cast(m, dtype)
        mask = tf.reshape(mask, [1, n_dest, n_src])
        mult = tf.concat(
            [tf.expand_dims(batch_size, -1), tf.constant([1, 1], dtype=tf.int32)], 0
        )
        return tf.tile(mask, mult)

    def call(self, enc_out, target):
        input_shape = tf.shape(target)
        batch_size = input_shape[0]
        seq_len = input_shape[1]
        causal_mask = self.causal_attention_mask(batch_size, seq_len, seq_len, tf.bool)
        target_att = self.self_att(target, target, attention_mask=causal_mask)
        target_norm = self.layernorm1(target + self.self_dropout(target_att))
        enc_out = self.enc_att(target_norm, enc_out)
        enc_out_norm = self.layernorm2(self.enc_dropout(enc_out) + target_norm)
        ffn_out = self.ffn(enc_out_norm)
        ffn_out_norm = self.layernorm3(enc_out_norm + self.ffn_dropout(ffn_out))
        return ffn_out_norm

# %%
#with accuracy
class Transformer(keras.Model):
    def __init__(
        self,
        num_hid=64,
        num_head=2,
        num_feed_forward=128,
        source_maxlen=100,
        target_maxlen=100,
        num_layers_enc=4,
        num_layers_dec=1,
        num_classes=10,
    ):
        super().__init__()
        self.loss_metric = keras.metrics.Mean(name="loss")
        self.accuracy_metric = keras.metrics.CategoricalAccuracy(name="accuracy")
        self.num_layers_enc = num_layers_enc
        self.num_layers_dec = num_layers_dec
        self.target_maxlen = target_maxlen
        self.num_classes = num_classes

        self.enc_input = SpeechFeatureEmbedding(num_hid=num_hid, maxlen=source_maxlen)
        self.dec_input = TokenEmbedding(
            num_vocab=num_classes, maxlen=target_maxlen, num_hid=num_hid
        )

        self.encoder = keras.Sequential(
            [self.enc_input]
            + [
                TransformerEncoder(num_hid, num_head, num_feed_forward)
                for _ in range(num_layers_enc)
            ]
        )

        for i in range(num_layers_dec):
            setattr(
                self,
                f"dec_layer_{i}",
                TransformerDecoder(num_hid, num_head, num_feed_forward),
            )

        self.classifier = layers.Dense(num_classes)

    def decode(self, enc_out, target):
        y = self.dec_input(target)
        for i in range(self.num_layers_dec):
            y = getattr(self, f"dec_layer_{i}")(enc_out, y)
        return y

    def call(self, inputs):
        source = inputs[0]
        target = inputs[1]
        x = self.encoder(source)
        y = self.decode(x, target)
        return self.classifier(y)

    @property
    def metrics(self):
        return [self.loss_metric, self.accuracy_metric]

    def train_step(self, batch):
        source = batch["source"]
        target = batch["target"]
        dec_input = target[:, :-1]
        dec_target = target[:, 1:]
        with tf.GradientTape() as tape:
            preds = self([source, dec_input])
            one_hot = tf.one_hot(dec_target, depth=self.num_classes)
            mask = tf.math.logical_not(tf.math.equal(dec_target, 0))
            loss = self.compiled_loss(one_hot, preds, sample_weight=mask)
        trainable_vars = self.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))
        self.loss_metric.update_state(loss)
        self.accuracy_metric.update_state(one_hot, preds, sample_weight=mask)
        return {"loss": self.loss_metric.result(), "accuracy": self.accuracy_metric.result()}

    def test_step(self, batch):
        source = batch["source"]
        target = batch["target"]
        dec_input = target[:, :-1]
        dec_target = target[:, 1:]
        preds = self([source, dec_input])
        one_hot = tf.one_hot(dec_target, depth=self.num_classes)
        mask = tf.math.logical_not(tf.math.equal(dec_target, 0))
        loss = self.compiled_loss(one_hot, preds, sample_weight=mask)
        self.loss_metric.update_state(loss)
        self.accuracy_metric.update_state(one_hot, preds, sample_weight=mask)
        return {"loss": self.loss_metric.result(), "accuracy": self.accuracy_metric.result()}

    def generate(self, source, target_start_token_idx):
        """Performs inference over one batch of inputs using greedy decoding."""
        bs = tf.shape(source)[0]
        enc = self.encoder(source)
        dec_input = tf.ones((bs, 1), dtype=tf.int32) * target_start_token_idx
        dec_logits = []
        for i in range(self.target_maxlen - 1):
            dec_out = self.decode(enc, dec_input)
            logits = self.classifier(dec_out)
            logits = tf.argmax(logits, axis=-1, output_type=tf.int32)
            last_logit = tf.expand_dims(logits[:, -1], axis=-1)
            dec_logits.append(last_logit)
            dec_input = tf.concat([dec_input, last_logit], axis=-1)
        return dec_input

# %%
class DisplayOutputs(keras.callbacks.Callback):
    def __init__(
        self, batch, idx_to_token, target_start_token_idx=27, target_end_token_idx=28
    ):
        """Displays a batch of outputs after every epoch

        Args:
            batch: A test batch containing the keys "source" and "target"
            idx_to_token: A List containing the vocabulary tokens corresponding to their indices
            target_start_token_idx: A start token index in the target vocabulary
            target_end_token_idx: An end token index in the target vocabulary
        """
        self.batch = batch
        self.target_start_token_idx = target_start_token_idx
        self.target_end_token_idx = target_end_token_idx
        self.idx_to_char = idx_to_token

    def on_epoch_end(self, epoch, logs=None):
        if epoch % 4 != 0:
            return
        source = self.batch["source"]
        target = self.batch["target"].numpy()
        bs = tf.shape(source)[0]
        preds = self.model.generate(source, self.target_start_token_idx)
        preds = preds.numpy()
        for i in range(bs):
            target_text = "".join([self.idx_to_char[_] for _ in target[i, :]])
            prediction = ""
            for idx in preds[i, :]:
                ##print(idx)
                prediction += self.idx_to_char[idx]
                if idx == self.target_end_token_idx:
                    break
            print(f"target:     {target_text.replace('-','')}")
            print(f"prediction: {prediction}\n")

# %%
class CustomSchedule(keras.optimizers.schedules.LearningRateSchedule):
    def __init__(
        self,
        init_lr=0.00001,
        lr_after_warmup=0.001,
        final_lr=0.00001,
        warmup_epochs=15,
        decay_epochs=85,
        steps_per_epoch=203,
    ):
        super().__init__()
        self.init_lr = init_lr
        self.lr_after_warmup = lr_after_warmup
        self.final_lr = final_lr
        self.warmup_epochs = warmup_epochs
        self.decay_epochs = decay_epochs
        self.steps_per_epoch = steps_per_epoch

    def calculate_lr(self, epoch):
        """ linear warm up - linear decay """
        warmup_lr = (
            self.init_lr
            + ((self.lr_after_warmup - self.init_lr) / (self.warmup_epochs - 1)) * epoch
        )
        decay_lr = tf.math.maximum(
            self.final_lr,
            self.lr_after_warmup
            - (epoch - self.warmup_epochs)
            * (self.lr_after_warmup - self.final_lr)
            / (self.decay_epochs),
        )
        return tf.math.minimum(warmup_lr, decay_lr)

    def __call__(self, step):
        epoch = step // self.steps_per_epoch
        return self.calculate_lr(epoch)

# %%
batch = next(iter(val_ds))

# The vocabulary to convert predicted indices into characters
idx_to_char = vectorizer.get_vocabulary()
display_cb = DisplayOutputs(
    batch, idx_to_char, target_start_token_idx=2, target_end_token_idx=3
)  # set the arguments as per vocabulary index for '<' and '>'

model = Transformer(
    num_hid=200,
    num_head=2,
    num_feed_forward=400,
    target_maxlen=max_target_len,
    num_layers_enc=4,
    num_layers_dec=1,
    num_classes=34,
)
loss_fn = tf.keras.losses.CategoricalCrossentropy(
    from_logits=True, label_smoothing=0.1,
)

learning_rate = CustomSchedule(
    init_lr=0.00001,
    lr_after_warmup=0.001,
    final_lr=0.00001,
    warmup_epochs=15,
    decay_epochs=85,
    steps_per_epoch=len(ds),
)
optimizer = keras.optimizers.Adam(learning_rate)
model.compile(optimizer=optimizer, loss=loss_fn)

history = model.fit(ds, validation_data=val_ds, callbacks=[display_cb], epochs=203)
model.save_weights("ljspeech.h5")
# Out:
# Epoch 1/203
# 203/203 [==============================] - 114s 510ms/step - loss: 1.7361 - accuracy: 0.1284 - val_loss: 1.6562 - val_accuracy: 0.1828
# target:     <the increased information supplied by other agencies will be wasted.>
# prediction: <the e the s to ter e cte at t ther te s o t a the the t ae tre ie t ie te o t the t c e te e the tentenhe te te tor s rie on athe aienene re theriedit the ie ierete there te ie t stettento t te ene a
#
# target:     <prs must develop the capacity to classify its subjects on a more sophisticated basis than the present geographic breakdown.>
# prediction: <the e the s to te s t te at t ther te s o t a the the t ae tre ie t ie te o t the t c e te e the t enenhe t aie tor s rie on athe aienene re theriedit the ie ierete there te ie t stettento t te ene a
#
# target:     <its present manual filing system is obsolete#>
# prediction: <the e the s to ter e cte at t ther te s o t a the the t ae tre ie t ie te o t the t c e te e the tentenhe te te tor s rie on athe aienene re theriedit the ie ierete there te ie t stettento t te ene a
#
# target:     <it makes no use of the recent developments in automatic data processing which are widely used in the business world and in other government offices.>
# prediction: <the e the s to te s t te at t ther te s o t a the the t ae tre ie t ie te o t the t c e te e the t enenhe t aie tor s rie on athe aienene re theriedit the ie ierete there te ie t stettento t te ene a
#
# Epoch 2/203
# 203/203 [==============================] - 102s 499ms/step - loss: 1.4005 - accuracy: 0.2636 - val_loss: 1.4341 - val_accuracy: 0.2705
# Epoch 3/203
# 203/203 [==============================] - 103s 505ms/step - loss: 1.3263 - accuracy: 0.2850 - val_loss: 1.4029 - val_accuracy: 0.2748
# Epoch 4/203
# 203/203 [==============================] - 103s 503ms/step - loss: 1.3112 - accuracy: 0.2897 - val_loss: 1.3926 - val_accuracy: 0.2814
# Epoch 5/203
# 203/203 [==============================] - 104s 509ms/step - loss: 1.3051 - accuracy: 0.2920 - val_loss: 1.3862 - val_accuracy: 0.2834
# target:     <the increased information supplied by other agencies will be wasted.>
# prediction: <the as the onthe the the the the the as as the the the on of the the the the the asion the the the the the of these on.>
#
# target:     <prs must develop the capacity to classify its subjects on a more sophisticated basis than the present geographic breakdown.>
# prediction: <the as athe the the of the the the the the the the the ore ore the the the the the as the the as the ore the the the the the the the the ase the the thesioresin of presinent tennedy.>
#
# target:     <its present manual filing system is obsolete#>
# prediction: <the as the of the the the ore the the se the sionsin the asins the the the the of the the the theseresin the the thes.>
#
# target:     <it makes no use of the recent developments in automatic data processing which are widely used in the business world and in other government offices.>
# prediction: <the as athe on the the of the the the the the the the ore of the the the the the are the ore the the ore the the the the the the the the the the the the ore the of presionge tennedy.>
#
# Epoch 6/203
# 203/203 [==============================] - 102s 498ms/step - loss: 1.3001 - accuracy: 0.2945 - val_loss: 1.3779 - val_accuracy: 0.2920
# Epoch 7/203
# 203/203 [==============================] - 104s 512ms/step - loss: 1.2925 - accuracy: 0.2996 - val_loss: 1.3619 - val_accuracy: 0.3043
# Epoch 8/203
# 203/203 [==============================] - 104s 513ms/step - loss: 1.2730 - accuracy: 0.3145 - val_loss: 1.3237 - val_accuracy: 0.3369
# Epoch 9/203
# 203/203 [==============================] - 103s 506ms/step - loss: 1.2107 - accuracy: 0.3644 - val_loss: 1.2232 - val_accuracy: 0.4195
# target:     <the increased information supplied by other agencies will be wasted.>
# prediction: <the secres and the secres and the secres and and the secres and and the secres.>
#
# target:     <prs must develop the capacity to classify its subjects on a more sophisticated basis than the present geographic breakdown.>
# prediction: <the secres and the secres and and the secres and and the secres and and the secres and the secor the the secor secre thesesecofofofoffofofofonthendesesidesesinthestherendentheconedy.>
#
# target:     <its present manual filing system is obsolete#>
# prediction: <the secres and secres and the secres and the secres and and the secres.>
#
# target:     <it makes no use of the recent developments in automatic data processing which are widely used in the business world and in other government offices.>
# prediction: <the secres and and the secre and and the secrent and and the secres are and and and the secre and and asin the a the ase ase the the the the thesesese asese sthe thesesthent kennedendere.>
#
# Epoch 10/203
# 203/203 [==============================] - 100s 490ms/step - loss: 1.1398 - accuracy: 0.4175 - val_loss: 1.1521 - val_accuracy: 0.4701
# Epoch 11/203
# 203/203 [==============================] - 104s 508ms/step - loss: 1.0938 - accuracy: 0.4505 - val_loss: 1.1028 - val_accuracy: 0.5006
# Epoch 12/203
# 203/203 [==============================] - 105s 515ms/step - loss: 1.0515 - accuracy: 0.4805 - val_loss: 1.0378 - val_accuracy: 0.5424
# Epoch 13/203
#  61/203 [========>.....................] - ETA: 1:12 - loss: 1.0310 - accuracy: 0.5070
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-dc052ec0fe20> in <module>
#      31 model.compile(optimizer=optimizer, loss=loss_fn)
#      32
# ---> 33 history = model.fit(ds, validation_data=val_ds, callbacks=[display_cb], epochs=203)
#
# c:\Users\abdul\anaconda3\envs\myenv\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1187               logs = tmp_logs  # No error, now safe to assign to logs.
#    1188               end_step = step + data_handler.step_increment
# -> 1189               callbacks.on_train_batch_end(end_step, logs)
#    1190               if self.stop_training:
#    1191                 break
#
# c:\Users\abdul\anaconda3\envs\myenv\lib\site-packages\keras\callbacks.py in on_train_batch_end(self, batch, logs)
#     433     """
#     434     if self._should_call_train_batch_hooks:
# --> 435       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     436
#     437   def on_test_batch_begin(self, batch, logs=None):
#
# c:\Users\abdul\anaconda3\envs\myenv\lib\site-packages\keras\callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     293       self._call_batch_begin_hook(mode, batch, logs)
#     294     elif hook == 'end':
# --> 295       self._call_batch_end_hook(mode, batch, logs)
#     296     else:
#     297       raise ValueError('Unrecognized hook: {}'.format(hook))
#
# c:\Users\abdul\anaconda3\envs\myenv\lib\site-packages\keras\callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     313       self._batch_times.append(batch_time)
#     314
# --> 315     self._call_batch_hook_helper(hook_name, batch, logs)
#     316
#     317     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# c:\Users\abdul\anaconda3\envs\myenv\lib\site-packages\keras\callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     351     for callback in self.callbacks:
#     352       hook = getattr(callback, hook_name)
# --> 353       hook(batch, logs)
#     354
#     355     if self._check_timing:
#
# c:\Users\abdul\anaconda3\envs\myenv\lib\site-packages\keras\callbacks.py in on_train_batch_end(self, batch, logs)
#    1026
#    1027   def on_train_batch_end(self, batch, logs=None):
# -> 1028     self._batch_update_progbar(batch, logs)
#    1029
#    1030   def on_test_batch_end(self, batch, logs=None):
#
# c:\Users\abdul\anaconda3\envs\myenv\lib\site-packages\keras\callbacks.py in _batch_update_progbar(self, batch, logs)
#    1098     if self.verbose == 1:
#    1099       # Only block async when verbose = 1.
# -> 1100       logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1101       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1102
#
# c:\Users\abdul\anaconda3\envs\myenv\lib\site-packages\keras\utils\tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     514     return t  # Don't turn ragged or sparse tensors to NumPy.
#     515
# --> 516   return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     517
#     518
#
# c:\Users\abdul\anaconda3\envs\myenv\lib\site-packages\tensorflow\python\util\nest.py in map_structure(func, *structure, **kwargs)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# c:\Users\abdul\anaconda3\envs\myenv\lib\site-packages\tensorflow\python\util\nest.py in <listcomp>(.0)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# c:\Users\abdul\anaconda3\envs\myenv\lib\site-packages\keras\utils\tf_utils.py in _to_single_numpy_or_python_type(t)
#     510   def _to_single_numpy_or_python_type(t):
#     511     if isinstance(t, tf.Tensor):
# --> 512       x = t.numpy()
#     513       return x.item() if np.ndim(x) == 0 else x
#     514     return t  # Don't turn ragged or sparse tensors to NumPy.
#
# c:\Users\abdul\anaconda3\envs\myenv\lib\site-packages\tensorflow\python\framework\ops.py in numpy(self)
#    1092     """
#    1093     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1094     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1095     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1096
#
# c:\Users\abdul\anaconda3\envs\myenv\lib\site-packages\tensorflow\python\framework\ops.py in _numpy(self)
#    1058   def _numpy(self):
#    1059     try:
# -> 1060       return self._numpy_internal()
#    1061     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1062       six.raise_from(core._status_to_exception(e.code, e.message), None)  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
ds
# Out:
# <PrefetchDataset shapes: {source: (None, None, 129), target: (None, 200)}, types: {source: tf.float32, target: tf.int32}>

# %%
rmodel = Transformer(
    num_hid=200,
    num_head=2,
    num_feed_forward=400,
    target_maxlen=max_target_len,
    num_layers_enc=4,
    num_layers_dec=1,
    num_classes=34,
)

# Build the model by calling it with some input data (you can use a dummy batch)
dummy_batch = (tf.ones((1,1, 129)), tf.ones((1, 200)))
_ = rmodel(dummy_batch)

# Compile the model
rmodel.compile(optimizer=optimizer, loss=loss_fn, metrics=["accuracy"])


#history = model.fit(ds, validation_data=val_ds, callbacks=[display_cb], epochs=203)

# %%
rmodel.save_weights("control.h5")

# %%
rmodel.load_weights("control2.h5")

# %%
history = rmodel.fit(ds, validation_data=val_ds, callbacks=[display_cb], epochs=50)
# Out:
# Epoch 1/50
# 56/56 [==============================] - 17s 298ms/step - loss: 0.0616 - accuracy: 0.6526 - val_loss: 0.0556 - val_accuracy: 0.6975
# target:     <pencil>
# prediction: <hongal>
#
# target:     <bathtub>
# prediction: <bathool>
#
# target:     <bathtub>
# prediction: <dequileath>
#
# target:     <bathtub>
# prediction: <footh>
#
# Epoch 2/50
# 56/56 [==============================] - 17s 307ms/step - loss: 0.0512 - accuracy: 0.7244 - val_loss: 0.0522 - val_accuracy: 0.7143
# Epoch 3/50
# 56/56 [==============================] - 17s 307ms/step - loss: 0.0435 - accuracy: 0.7803 - val_loss: 0.0511 - val_accuracy: 0.6765
# Epoch 4/50
# 56/56 [==============================] - 18s 312ms/step - loss: 0.0382 - accuracy: 0.8324 - val_loss: 0.0485 - val_accuracy: 0.7017
# Epoch 5/50
# 56/56 [==============================] - 18s 322ms/step - loss: 0.0336 - accuracy: 0.8817 - val_loss: 0.0492 - val_accuracy: 0.7227
# target:     <pencil>
# prediction: <pencil>
#
# target:     <bathtub>
# prediction: <battlefield>
#
# target:     <bathtub>
# prediction: <bathool>
#
# target:     <bathtub>
# prediction: <thu>
#
# Epoch 6/50
# 56/56 [==============================] - 18s 322ms/step - loss: 0.0303 - accuracy: 0.9142 - val_loss: 0.0490 - val_accuracy: 0.7437
# Epoch 7/50
# 56/56 [==============================] - 19s 331ms/step - loss: 0.0277 - accuracy: 0.9407 - val_loss: 0.0473 - val_accuracy: 0.7605
# Epoch 8/50
# 56/56 [==============================] - 19s 334ms/step - loss: 0.0257 - accuracy: 0.9606 - val_loss: 0.0446 - val_accuracy: 0.7941
# Epoch 9/50
# 56/56 [==============================] - 19s 343ms/step - loss: 0.0247 - accuracy: 0.9713 - val_loss: 0.0489 - val_accuracy: 0.7521
# target:     <pencil>
# prediction: <pencil>
#
# target:     <bathtub>
# prediction: <battlefield>
#
# target:     <bathtub>
# prediction: <battlefield>
#
# target:     <bathtub>
# prediction: <some>
#
# Epoch 10/50
# 56/56 [==============================] - 19s 337ms/step - loss: 0.0278 - accuracy: 0.9378 - val_loss: 0.0478 - val_accuracy: 0.7731
# Epoch 11/50
# 56/56 [==============================] - 20s 351ms/step - loss: 0.0266 - accuracy: 0.9480 - val_loss: 0.0479 - val_accuracy: 0.7605
# Epoch 12/50
# 56/56 [==============================] - 20s 351ms/step - loss: 0.0247 - accuracy: 0.9687 - val_loss: 0.0533 - val_accuracy: 0.7311
# Epoch 13/50
# 56/56 [==============================] - 20s 355ms/step - loss: 0.0234 - accuracy: 0.9836 - val_loss: 0.0517 - val_accuracy: 0.7563
# target:     <pencil>
# prediction: <pencil>
#
# target:     <bathtub>
# prediction: <battlefield>
#
# target:     <bathtub>
# prediction: <baths>
#
# target:     <bathtub>
# prediction: <so>
#
# Epoch 14/50
# 56/56 [==============================] - 20s 355ms/step - loss: 0.0229 - accuracy: 0.9885 - val_loss: 0.0483 - val_accuracy: 0.8025
# Epoch 15/50
# 56/56 [==============================] - 20s 365ms/step - loss: 0.0229 - accuracy: 0.9881 - val_loss: 0.0485 - val_accuracy: 0.7689
# Epoch 16/50
# 56/56 [==============================] - 21s 371ms/step - loss: 0.0224 - accuracy: 0.9936 - val_loss: 0.0565 - val_accuracy: 0.6975
# Epoch 17/50
# 56/56 [==============================] - 21s 373ms/step - loss: 0.0223 - accuracy: 0.9939 - val_loss: 0.0552 - val_accuracy: 0.6975
# target:     <pencil>
# prediction: <pencil>
#
# target:     <bathtub>
# prediction: <backspace>
#
# target:     <bathtub>
# prediction: <delta>
#
# target:     <bathtub>
# prediction: <the>
#
# Epoch 18/50
# 56/56 [==============================] - 20s 364ms/step - loss: 0.0222 - accuracy: 0.9950 - val_loss: 0.0531 - val_accuracy: 0.7479
# Epoch 19/50
# 56/56 [==============================] - 21s 370ms/step - loss: 0.0220 - accuracy: 0.9965 - val_loss: 0.0516 - val_accuracy: 0.7227
# Epoch 20/50
# 56/56 [==============================] - 21s 374ms/step - loss: 0.0218 - accuracy: 0.9986 - val_loss: 0.0515 - val_accuracy: 0.7437
# Epoch 21/50
# 56/56 [==============================] - 21s 377ms/step - loss: 0.0217 - accuracy: 0.9991 - val_loss: 0.0515 - val_accuracy: 0.7521
# target:     <pencil>
# prediction: <pencil>
#
# target:     <bathtub>
# prediction: <baths>
#
# target:     <bathtub>
# prediction: <delta>
#
# target:     <bathtub>
# prediction: <some>
#
# Epoch 22/50
# 56/56 [==============================] - 21s 374ms/step - loss: 0.0216 - accuracy: 0.9991 - val_loss: 0.0516 - val_accuracy: 0.7479
# Epoch 23/50
# 56/56 [==============================] - 21s 380ms/step - loss: 0.0216 - accuracy: 0.9988 - val_loss: 0.0518 - val_accuracy: 0.7479
# Epoch 24/50
# 56/56 [==============================] - 21s 371ms/step - loss: 0.0216 - accuracy: 0.9988 - val_loss: 0.0519 - val_accuracy: 0.7521
# Epoch 25/50
# 56/56 [==============================] - 21s 378ms/step - loss: 0.0216 - accuracy: 0.9988 - val_loss: 0.0519 - val_accuracy: 0.7521
# target:     <pencil>
# prediction: <pencil>
#
# target:     <bathtub>
# prediction: <bathool>
#
# target:     <bathtub>
# prediction: <backspace>
#
# target:     <bathtub>
# prediction: <some>
#
# Epoch 26/50
# 56/56 [==============================] - 21s 376ms/step - loss: 0.0216 - accuracy: 0.9988 - val_loss: 0.0520 - val_accuracy: 0.7521
# Epoch 27/50
# 56/56 [==============================] - 21s 379ms/step - loss: 0.0216 - accuracy: 0.9988 - val_loss: 0.0520 - val_accuracy: 0.7521
# Epoch 28/50
# 56/56 [==============================] - 22s 392ms/step - loss: 0.0216 - accuracy: 0.9988 - val_loss: 0.0520 - val_accuracy: 0.7563
# Epoch 29/50
# 56/56 [==============================] - 23s 401ms/step - loss: 0.0216 - accuracy: 0.9988 - val_loss: 0.0521 - val_accuracy: 0.7563
# target:     <pencil>
# prediction: <pencil>
#
# target:     <bathtub>
# prediction: <bathool>
#
# target:     <bathtub>
# prediction: <backspace>
#
# target:     <bathtub>
# prediction: <some>
#
# Epoch 30/50
# 56/56 [==============================] - 22s 396ms/step - loss: 0.0216 - accuracy: 0.9988 - val_loss: 0.0521 - val_accuracy: 0.7563
# Epoch 31/50
# 56/56 [==============================] - 22s 388ms/step - loss: 0.0216 - accuracy: 0.9988 - val_loss: 0.0521 - val_accuracy: 0.7563
# Epoch 32/50
# 56/56 [==============================] - 22s 384ms/step - loss: 0.0216 - accuracy: 0.9988 - val_loss: 0.0522 - val_accuracy: 0.7563
# Epoch 33/50
# 56/56 [==============================] - 23s 403ms/step - loss: 0.0216 - accuracy: 0.9988 - val_loss: 0.0522 - val_accuracy: 0.7521
# target:     <pencil>
# prediction: <pencil>
#
# target:     <bathtub>
# prediction: <bathool>
#
# target:     <bathtub>
# prediction: <backspace>
#
# target:     <bathtub>
# prediction: <some>
#
# Epoch 34/50
# 45/56 [=======================>......] - ETA: 4s - loss: 0.0199 - accuracy: 0.9988
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-f8da803d086f> in <module>
# ----> 1 history = rmodel.fit(ds, validation_data=val_ds, callbacks=[display_cb], epochs=50)
#
# ~\anaconda3\envs\myenv\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1182                 _r=1):
#    1183               callbacks.on_train_batch_begin(step)
# -> 1184               tmp_logs = self.train_function(iterator)
#    1185               if data_handler.should_sync:
#    1186                 context.async_wait()
#
# ~\anaconda3\envs\myenv\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     883
#     884       with OptionalXlaContext(self._jit_compile):
# --> 885         result = self._call(*args, **kwds)
#     886
#     887       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\anaconda3\envs\myenv\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     915       # In this case we have created variables on the first call, so we run the
#     916       # defunned version which is guaranteed to never create variables.
# --> 917       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918     elif self._stateful_fn is not None:
#     919       # Release the lock early so that multiple threads can perform the call
#
# ~\anaconda3\envs\myenv\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    3038        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3039     return graph_function._call_flat(
# -> 3040         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3041
#    3042   @property
#
# ~\anaconda3\envs\myenv\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1962       # No tape is watching; skip to running the function.
#    1963       return self._build_call_outputs(self._inference_function.call(
# -> 1964           ctx, args, cancellation_manager=cancellation_manager))
#    1965     forward_backward = self._select_forward_and_backward_functions(
#    1966         args,
#
# ~\anaconda3\envs\myenv\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     594               inputs=args,
#     595               attrs=attrs,
# --> 596               ctx=ctx)
#     597         else:
#     598           outputs = execute.execute_with_cancellation(
#
# ~\anaconda3\envs\myenv\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
rmodel.summary()
# Out:
# Model: "transformer_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# speech_feature_embedding_1 ( (1, 1, 200)               1164400
# _________________________________________________________________
# token_embedding_1 (TokenEmbe multiple                  46800
# _________________________________________________________________
# sequential_10 (Sequential)   (1, 1, 200)               3095600
# _________________________________________________________________
# transformer_decoder_1 (Trans multiple                  804600
# _________________________________________________________________
# dense_21 (Dense)             multiple                  6834
# =================================================================
# Total params: 3,953,838
# Trainable params: 3,953,834
# Non-trainable params: 4
# _________________________________________________________________

# %%
rmodel.save_weights("M04transfromer.h5")

# %%
rmodel.load_weights("M04transfromer.h5")

# %%
import pandas as pd
import os
from glob import glob

# Assuming saveto is the directory where the CSV file is located
saveto = r"C:\Users\abdul\Downloads\F04"
wavs = glob("{}/**/*.wav".format(saveto), recursive=True)
id_to_text = {}

# Load the CSV file into a pandas DataFrame, skipping the first row
csv_file_path = os.path.join(saveto, "dictionary_UASPEECH.csv")
df = pd.read_csv(csv_file_path, sep=',', header=None, names=['ID', 'Text'], skiprows=1)

# Create a dictionary with formatted keys and values
id_to_text = {row["Text"]: row["ID"] for _, row in df.iterrows()}

# %%
id_to_text
# Out:
# {'D3': 'Three',
#  'D9': 'Nine',
#  'D0': 'Zero',
#  'D6': 'Six',
#  'D7': 'Seven',
#  'D8': 'Eight',
#  'D4': 'Four',
#  'D5': 'Five',
#  'D1': 'One',
#  'D2': 'Two',
#  'LE': 'Echo',
#  'LD': 'Delta',
#  'LW': 'Whiskey',
#  'LK': 'Kilo',
#  'LS': 'Sierra',
#  'LT': 'Tango',
#  'LU': 'Uniform',
#  'LX': 'X-ray',
#  'LJ': 'Juliet',
#  'LC': 'Charlie',
#  'LQ': 'Quebec',
#  'LP': 'Papa',
#  'LZ': 'Zulu',
#  'LR': 'Romeo',
#  'LF': 'Foxtrot',
#  'LI': 'India',
#  'LL': 'Lima',
#  'LV': 'Victor',
#  'LY': 'Yankee',
#  'LG': 'Golf',
#  'LH': 'Hotel',
#  'LN': 'November',
#  'LB': 'Bravo',
#  'LO': 'Oscar',
#  'LA': 'Alpha',
#  'LM': 'Mike',
#  'C1': 'Command',
#  'C2': 'Backspace',
#  'C3': 'Delete',
#  'C4': 'Enter',
#  'C5': 'Tab',
#  'C6': 'Escape',
#  'C7': 'Alt',
#  'C8': 'Control',
#  'C9': 'Shift',
#  'C10': 'Line',
#  'C11': 'Paragraph',
#  'C12': 'Sentence',
#  'C13': 'Paste',
#  'C14': 'Cut',
#  'C15': 'Copy',
#  'C16': 'Upward',
#  'C17': 'Downward',
#  'C18': 'Left',
#  'C19': 'Right',
#  'CW1': 'the',
#  'CW2': 'of',
#  'CW3': 'and',
#  'CW4': 'a',
#  'CW5': 'to',
#  'CW6': 'in',
#  'CW7': 'is',
#  'CW8': 'you',
#  'CW9': 'that',
#  'CW10': 'it',
#  'CW11': 'he',
#  'CW12': 'was',
#  'CW13': 'for',
#  'CW14': 'on',
#  'CW15': 'are',
#  'CW16': 'as',
#  'CW17': 'with',
#  'CW18': 'his',
#  'CW19': 'they',
#  'CW20': 'I',
#  'CW21': 'at',
#  'CW22': 'be',
#  'CW23': 'this',
#  'CW24': 'have',
#  'CW25': 'from',
#  'CW26': 'or',
#  'CW27': 'had',
#  'CW28': 'by',
#  'CW29': 'word',
#  'CW30': 'but',
#  'CW31': 'not',
#  'CW32': 'what',
#  'CW33': 'all',
#  'CW34': 'were',
#  'CW35': 'we',
#  'CW36': 'when',
#  'CW37': 'your',
#  'CW38': 'can',
#  'CW39': 'said',
#  'CW40': 'there',
#  'CW41': 'use',
#  'CW42': 'an',
#  'CW43': 'each',
#  'CW44': 'which',
#  'CW45': 'she',
#  'CW46': 'do',
#  'CW47': 'how',
#  'CW48': 'their',
#  'CW49': 'if',
#  'CW50': 'will',
#  'CW51': 'up',
#  'CW52': 'other',
#  'CW53': 'about',
#  'CW54': 'out',
#  'CW55': 'many',
#  'CW56': 'then',
#  'CW57': 'them',
#  'CW58': 'these',
#  'CW59': 'so',
#  'CW60': 'some',
#  'CW61': 'her',
#  'CW62': 'would',
#  'CW63': 'make',
#  'CW64': 'like',
#  'CW65': 'him',
#  'CW66': 'into',
#  'CW67': 'time',
#  'CW68': 'has',
#  'CW69': 'look',
#  'CW70': 'more',
#  'CW71': 'write',
#  'CW72': 'go',
#  'CW73': 'see',
#  'CW74': 'number',
#  'CW75': 'no',
#  'CW76': 'way',
#  'CW77': 'could',
#  'CW78': 'people',
#  'CW79': 'my',
#  'CW80': 'than',
#  'CW81': 'first',
#  'CW82': 'water',
#  'CW83': 'been',
#  'CW84': 'call',
#  'CW85': 'who',
#  'CW86': 'oil',
#  'CW87': 'its',
#  'CW88': 'now',
#  'CW89': 'find',
#  'CW90': 'long',
#  'CW91': 'down',
#  'CW92': 'day',
#  'CW93': 'did',
#  'CW94': 'get',
#  'CW95': 'come',
#  'CW96': 'made',
#  'CW97': 'may',
#  'CW98': 'part',
#  'CW99': 'oh',
#  'CW100': 'yes',
#  'B1_UW1': 'naturalization',
#  'B1_UW2': 'faithfulness',
#  'B1_UW3': 'frugality',
#  'B1_UW4': 'irresolute',
#  'B1_UW5': 'psychological',
#  'B1_UW6': 'supervision',
#  'B1_UW7': 'able-bodied',
#  'B1_UW8': 'bushels',
#  'B1_UW9': 'cowboys',
#  'B1_UW10': 'entertainer',
#  'B1_UW11': 'gentlewoman',
#  'B1_UW12': 'giggled',
#  'B1_UW13': 'hypothesis',
#  'B1_UW14': 'lethargy',
#  'B1_UW15': 'merchandise',
#  'B1_UW16': 'nevertheless',
#  'B1_UW17': 'Pennsylvania',
#  'B1_UW18': 'rejoinder',
#  'B1_UW19': 'southeast',
#  'B1_UW20': 'vouchsafe',
#  'B1_UW21': 'achieve',
#  'B1_UW22': 'adapt',
#  'B1_UW23': 'autobiography',
#  'B1_UW24': 'avenues',
#  'B1_UW25': 'babyhood',
#  'B1_UW26': 'behavior',
#  'B1_UW27': 'bogies',
#  'B1_UW28': 'boquets',
#  'B1_UW29': 'casualties',
#  'B1_UW30': 'cheshire',
#  'B1_UW31': 'choking',
#  'B1_UW32': 'circular',
#  'B1_UW33': 'composure',
#  'B1_UW34': 'epithet',
#  'B1_UW35': 'equilibrium',
#  'B1_UW36': 'exactitude',
#  'B1_UW37': 'eyebrows',
#  'B1_UW38': 'footmarks',
#  'B1_UW39': 'fowler',
#  'B1_UW40': 'ha-ha',
#  'B1_UW41': 'inalienable',
#  'B1_UW42': 'inquirers',
#  'B1_UW43': 'jackdaws',
#  'B1_UW44': 'journalism',
#  'B1_UW45': 'legislature',
#  'B1_UW46': 'moustache',
#  'B1_UW47': 'overshadowed',
#  'B1_UW48': 'perpetual',
#  'B1_UW49': 'powwow',
#  'B1_UW50': 'promulgate',
#  'B1_UW51': 'python',
#  'B1_UW52': 'adulation',
#  'B1_UW53': 'advice',
#  'B1_UW54': 'amethysts',
#  'B1_UW55': 'annoyed',
#  'B1_UW56': 'ashamed',
#  'B1_UW57': 'Asia',
#  'B1_UW58': 'azure',
#  'B1_UW59': 'beguile',
#  'B1_UW60': 'Birmingham',
#  'B1_UW61': 'burrows',
#  'B1_UW62': 'chatterbox',
#  'B1_UW63': 'chauffeur',
#  'B1_UW64': 'choice',
#  'B1_UW65': 'chowder',
#  'B1_UW66': 'cobblestones',
#  'B1_UW67': 'Copenhagen',
#  'B1_UW68': 'dissatisfaction',
#  'B1_UW69': 'employment',
#  'B1_UW70': 'futurity',
#  'B1_UW71': 'gigantic',
#  'B1_UW72': 'gouged',
#  'B1_UW73': 'goulash',
#  'B1_UW74': 'hallelujah',
#  'B1_UW75': 'haranguing',
#  'B1_UW76': 'hulk',
#  'B1_UW77': 'immovable',
#  'B1_UW78': 'interwoven',
#  'B1_UW79': 'Joseph',
#  'B1_UW80': 'massage',
#  'B1_UW81': 'moisten',
#  'B1_UW82': 'house',
#  'B1_UW83': 'tree',
#  'B1_UW84': 'window',
#  'B1_UW85': 'telephone',
#  'B1_UW86': 'cup',
#  'B1_UW87': 'knife',
#  'B1_UW88': 'spoon',
#  'B1_UW89': 'girl',
#  'B1_UW90': 'ball',
#  'B1_UW91': 'wagon',
#  'B1_UW92': 'shovel',
#  'B1_UW93': 'monkey',
#  'B1_UW94': 'banana',
#  'B1_UW95': 'zipper',
#  'B1_UW96': 'scissors',
#  'B1_UW97': 'duck',
#  'B1_UW98': 'quack',
#  'B1_UW99': 'yellow',
#  'B1_UW100': 'vacuum',
#  'B2_UW1': 'mouth',
#  'B2_UW2': 'needlepoint',
#  'B2_UW3': 'Nuremberg',
#  'B2_UW4': 'pennyworth',
#  'B2_UW5': 're-united',
#  'B2_UW6': 'roof',
#  'B2_UW7': 'schoolyard',
#  'B2_UW8': 'sharpshooter',
#  'B2_UW9': 'skyward',
#  'B2_UW10': 'sugar',
#  'B2_UW11': 'supreme',
#  'B2_UW12': 'toothache',
#  'B2_UW13': 'unusual',
#  'B2_UW14': 'voyage',
#  'B2_UW15': 'abbreviated',
#  'B2_UW16': 'ablutions',
#  'B2_UW17': 'absolve',
#  'B2_UW18': 'absorb',
#  'B2_UW19': 'adhesion',
#  'B2_UW20': 'adjacent',
#  'B2_UW21': 'advantageous',
#  'B2_UW22': 'agricultural',
#  'B2_UW23': 'allure',
#  'B2_UW24': 'aloft',
#  'B2_UW25': 'aloof',
#  'B2_UW26': 'although',
#  'B2_UW27': 'anxieties',
#  'B2_UW28': 'anybody',
#  'B2_UW29': 'anything',
#  'B2_UW30': 'apothecary',
#  'B2_UW31': 'appreciable',
#  'B2_UW32': 'apprehend',
#  'B2_UW33': 'approach',
#  'B2_UW34': 'astounded',
#  'B2_UW35': 'atrocious',
#  'B2_UW36': 'authoritative',
#  'B2_UW37': 'aversion',
#  'B2_UW38': 'bachelor',
#  'B2_UW39': 'bathe',
#  'B2_UW40': 'baths',
#  'B2_UW41': 'battlefield',
#  'B2_UW42': 'battlements',
#  'B2_UW43': 'battleship',
#  'B2_UW44': 'beef',
#  'B2_UW45': 'beleaguering',
#  'B2_UW46': 'Bengal',
#  'B2_UW47': 'bequeath',
#  'B2_UW48': 'betook',
#  'B2_UW49': 'betroth',
#  'B2_UW50': 'blithe',
#  'B2_UW51': 'bloodshed',
#  'B2_UW52': 'bluebells',
#  'B2_UW53': 'booth',
#  'B2_UW54': 'bosom',
#  'B2_UW55': 'both',
#  'B2_UW56': 'bother',
#  'B2_UW57': 'boulevard',
#  'B2_UW58': 'boyhood',
#  'B2_UW59': 'broil',
#  'B2_UW60': 'brotherhood',
#  'B2_UW61': 'buffoon',
#  'B2_UW62': 'bulge',
#  'B2_UW63': 'bulrush',
#  'B2_UW64': 'butcher',
#  'B2_UW65': 'butterflies',
#  'B2_UW66': 'candlelight',
#  'B2_UW67': 'Catholic',
#  'B2_UW68': 'celebrity',
#  'B2_UW69': 'chide',
#  'B2_UW70': 'coherent',
#  'B2_UW71': 'coil',
#  'B2_UW72': 'convulsion',
#  'B2_UW73': 'cowhide',
#  'B2_UW74': 'deluge',
#  'B2_UW75': 'digest',
#  'B2_UW76': 'displeasure',
#  'B2_UW77': 'dispossess',
#  'B2_UW78': 'dowry',
#  'B2_UW79': 'durable',
#  'B2_UW80': 'Emilio',
#  'B2_UW81': 'endowments',
#  'B2_UW82': 'watch',
#  'B2_UW83': 'plane',
#  'B2_UW84': 'swimming',
#  'B2_UW85': 'watches',
#  'B2_UW86': 'lamp',
#  'B2_UW87': 'car',
#  'B2_UW88': 'blue',
#  'B2_UW89': 'rabbit',
#  'B2_UW90': 'carrot',
#  'B2_UW91': 'orange',
#  'B2_UW92': 'fishing',
#  'B2_UW93': 'chair',
#  'B2_UW94': 'feather',
#  'B2_UW95': 'pencil',
#  'B2_UW96': 'bathtub',
#  'B2_UW97': 'bath',
#  'B2_UW98': 'ring',
#  'B2_UW99': 'finger',
#  'B2_UW100': 'thumb',
#  'B3_UW1': 'enthuse',
#  'B3_UW2': 'exploit',
#  'B3_UW3': 'Fayetteville',
#  'B3_UW4': 'foil',
#  'B3_UW5': 'good',
#  'B3_UW6': 'greyhound',
#  'B3_UW7': 'hanger',
#  'B3_UW8': 'Heyward',
#  'B3_UW9': 'hoist',
#  'B3_UW10': 'Iroquois',
#  'B3_UW11': 'jowls',
#  'B3_UW12': 'joyful',
#  'B3_UW13': 'juries',
#  'B3_UW14': 'lawyer',
#  'B3_UW15': 'Missouri',
#  'B3_UW16': 'moonshine',
#  'B3_UW17': 'Nathaniel',
#  'B3_UW18': 'nodule',
#  'B3_UW19': 'nowhere',
#  'B3_UW20': 'output',
#  'B3_UW21': 'ploughshare',
#  'B3_UW22': 'protege',
#  'B3_UW23': 'refugee',
#  'B3_UW24': 'regime',
#  'B3_UW25': 'rendezvous',
#  'B3_UW26': 'resound',
#  'B3_UW27': 'reward',
#  'B3_UW28': 'righteous',
#  'B3_UW29': 'Sawyer',
#  'B3_UW30': 'scullion',
#  'B3_UW31': 'shout',
#  'B3_UW32': 'stringy',
#  'B3_UW33': 'swoon',
#  'B3_UW34': 'sympathize',
#  'B3_UW35': 'thine',
#  'B3_UW36': 'thou',
#  'B3_UW37': 'toil',
#  'B3_UW38': 'unyielding',
#  'B3_UW39': 'wherewithal',
#  'B3_UW40': 'without',
#  'B3_UW41': 'Yale',
#  'B3_UW42': 'Massachusetts',
#  'B3_UW43': 'designate',
#  'B3_UW44': 'forgetfulness',
#  'B3_UW45': 'quadrupled',
#  'B3_UW46': 'southeasterly',
#  'B3_UW47': 'berserker',
#  'B3_UW48': 'chambermaid',
#  'B3_UW49': 'demolish',
#  'B3_UW50': 'exaggerate',
#  'B3_UW51': 'multiflora',
#  'B3_UW52': 'observation',
#  'B3_UW53': 'professionals',
#  'B3_UW54': 'roly-poly',
#  'B3_UW55': 'thirty-five',
#  'B3_UW56': 'vouchsafe',
#  'B3_UW57': 'washerwoman',
#  'B3_UW58': 'afterthought',
#  'B3_UW59': 'awhile',
#  'B3_UW60': 'browbeat',
#  'B3_UW61': 'bungalows',
#  'B3_UW62': 'choking',
#  'B3_UW63': 'clergyman',
#  'B3_UW64': 'commercial',
#  'B3_UW65': 'convenience',
#  'B3_UW66': 'cushy',
#  'B3_UW67': 'dodgers',
#  'B3_UW68': 'episode',
#  'B3_UW69': 'equilibrium',
#  'B3_UW70': 'fathom',
#  'B3_UW71': 'Gustave',
#  'B3_UW72': 'homeopath',
#  'B3_UW73': 'inexhaustible',
#  'B3_UW74': 'Judith',
#  'B3_UW75': 'Morgantown',
#  'B3_UW76': 'moustache',
#  'B3_UW77': 'nausea',
#  'B3_UW78': 'newfound',
#  'B3_UW79': 'powwow',
#  'B3_UW80': 'praiseworthy',
#  'B3_UW81': 'sandpipers',
#  'B3_UW82': 'soothing',
#  'B3_UW83': 'jumping',
#  'B3_UW84': 'pajamas',
#  'B3_UW85': 'flowers',
#  'B3_UW86': 'brush',
#  'B3_UW87': 'drum',
#  'B3_UW88': 'frog',
#  'B3_UW89': 'clown',
#  'B3_UW90': 'green',
#  'B3_UW91': 'balloons',
#  'B3_UW92': 'crying',
#  'B3_UW93': 'glasses',
#  'B3_UW94': 'slide',
#  'B3_UW95': 'stars',
#  'B3_UW96': 'fire',
#  'B3_UW97': 'watch',
#  'B3_UW98': 'ahead',
#  'B3_UW99': 'away',
#  'B3_UW100': 'crayon'}

# %%
def get_data(wavs, id_to_text, maxlen=50):
    """ returns mapping of audio paths and transcription texts """
    data = []
    for w in wavs:
        id = w.split("\\")[-1]
        for item in k:
            if item+"_" in id and len(id_to_text[item]) < maxlen:
                data.append({"audio": w, "text": id_to_text[item]})
                #print("hi")
    return data

# %%
class VectorizeChar:
    def __init__(self, max_len=50):
        self.vocab = (
            ["-", "#", "<", ">"]
            + [chr(i + 96) for i in range(1, 27)]
            + [" ", ".", ",", "?"]
        )
        self.max_len = max_len
        self.char_to_idx = {}
        for i, ch in enumerate(self.vocab):
            self.char_to_idx[ch] = i

    def __call__(self, text):
        text = text.lower()
        text = text[: self.max_len - 2]
        text = "<" + text + ">"
        pad_len = self.max_len - len(text)
        return [self.char_to_idx.get(ch, 1) for ch in text] + [0] * pad_len

    def get_vocabulary(self):
        return self.vocab

# %%
max_target_len = 200  # all transcripts in out data are < 200 characters
data = get_data(wavs, id_to_text, max_target_len)
vectorizer = VectorizeChar(max_target_len)

# %%
data
# Out:
# [{'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C10_M2.wav',
#   'text': 'Line'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C10_M3.wav',
#   'text': 'Line'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C10_M4.wav',
#   'text': 'Line'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C10_M5.wav',
#   'text': 'Line'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C10_M6.wav',
#   'text': 'Line'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C10_M7.wav',
#   'text': 'Line'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C10_M8.wav',
#   'text': 'Line'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C11_M2.wav',
#   'text': 'Paragraph'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C11_M3.wav',
#   'text': 'Paragraph'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C11_M4.wav',
#   'text': 'Paragraph'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C11_M5.wav',
#   'text': 'Paragraph'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C11_M6.wav',
#   'text': 'Paragraph'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C11_M7.wav',
#   'text': 'Paragraph'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C11_M8.wav',
#   'text': 'Paragraph'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C12_M2.wav',
#   'text': 'Sentence'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C12_M3.wav',
#   'text': 'Sentence'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C12_M4.wav',
#   'text': 'Sentence'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C12_M5.wav',
#   'text': 'Sentence'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C12_M6.wav',
#   'text': 'Sentence'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C12_M7.wav',
#   'text': 'Sentence'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C12_M8.wav',
#   'text': 'Sentence'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C13_M2.wav',
#   'text': 'Paste'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C13_M3.wav',
#   'text': 'Paste'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C13_M4.wav',
#   'text': 'Paste'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C13_M5.wav',
#   'text': 'Paste'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C13_M6.wav',
#   'text': 'Paste'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C13_M7.wav',
#   'text': 'Paste'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C13_M8.wav',
#   'text': 'Paste'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C14_M2.wav',
#   'text': 'Cut'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C14_M3.wav',
#   'text': 'Cut'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C14_M4.wav',
#   'text': 'Cut'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C14_M5.wav',
#   'text': 'Cut'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C14_M6.wav',
#   'text': 'Cut'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C14_M7.wav',
#   'text': 'Cut'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C14_M8.wav',
#   'text': 'Cut'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C15_M2.wav',
#   'text': 'Copy'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C15_M3.wav',
#   'text': 'Copy'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C15_M4.wav',
#   'text': 'Copy'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C15_M5.wav',
#   'text': 'Copy'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C15_M6.wav',
#   'text': 'Copy'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C15_M7.wav',
#   'text': 'Copy'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C15_M8.wav',
#   'text': 'Copy'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C16_M2.wav',
#   'text': 'Upward'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C16_M3.wav',
#   'text': 'Upward'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C16_M4.wav',
#   'text': 'Upward'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C16_M5.wav',
#   'text': 'Upward'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C16_M6.wav',
#   'text': 'Upward'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C16_M7.wav',
#   'text': 'Upward'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C16_M8.wav',
#   'text': 'Upward'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C17_M2.wav',
#   'text': 'Downward'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C17_M3.wav',
#   'text': 'Downward'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C17_M4.wav',
#   'text': 'Downward'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C17_M5.wav',
#   'text': 'Downward'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C17_M6.wav',
#   'text': 'Downward'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C17_M7.wav',
#   'text': 'Downward'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C17_M8.wav',
#   'text': 'Downward'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C18_M2.wav',
#   'text': 'Left'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C18_M3.wav',
#   'text': 'Left'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C18_M4.wav',
#   'text': 'Left'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C18_M5.wav',
#   'text': 'Left'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C18_M6.wav',
#   'text': 'Left'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C18_M7.wav',
#   'text': 'Left'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C18_M8.wav',
#   'text': 'Left'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C19_M2.wav',
#   'text': 'Right'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C19_M3.wav',
#   'text': 'Right'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C19_M4.wav',
#   'text': 'Right'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C19_M5.wav',
#   'text': 'Right'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C19_M6.wav',
#   'text': 'Right'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C19_M7.wav',
#   'text': 'Right'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C19_M8.wav',
#   'text': 'Right'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C1_M2.wav',
#   'text': 'Command'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C1_M3.wav',
#   'text': 'Command'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C1_M4.wav',
#   'text': 'Command'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C1_M5.wav',
#   'text': 'Command'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C1_M6.wav',
#   'text': 'Command'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C1_M7.wav',
#   'text': 'Command'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C1_M8.wav',
#   'text': 'Command'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C2_M2.wav',
#   'text': 'Backspace'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C2_M3.wav',
#   'text': 'Backspace'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C2_M4.wav',
#   'text': 'Backspace'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C2_M5.wav',
#   'text': 'Backspace'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C2_M6.wav',
#   'text': 'Backspace'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C2_M7.wav',
#   'text': 'Backspace'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C2_M8.wav',
#   'text': 'Backspace'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C3_M2.wav',
#   'text': 'Delete'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C3_M3.wav',
#   'text': 'Delete'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C3_M4.wav',
#   'text': 'Delete'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C3_M5.wav',
#   'text': 'Delete'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C3_M6.wav',
#   'text': 'Delete'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C3_M7.wav',
#   'text': 'Delete'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C3_M8.wav',
#   'text': 'Delete'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C4_M2.wav',
#   'text': 'Enter'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C4_M3.wav',
#   'text': 'Enter'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C4_M4.wav',
#   'text': 'Enter'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C4_M5.wav',
#   'text': 'Enter'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C4_M6.wav',
#   'text': 'Enter'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C4_M7.wav',
#   'text': 'Enter'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C4_M8.wav',
#   'text': 'Enter'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C5_M2.wav',
#   'text': 'Tab'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C5_M3.wav',
#   'text': 'Tab'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C5_M4.wav',
#   'text': 'Tab'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C5_M5.wav',
#   'text': 'Tab'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C5_M6.wav',
#   'text': 'Tab'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C5_M7.wav',
#   'text': 'Tab'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C5_M8.wav',
#   'text': 'Tab'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C6_M2.wav',
#   'text': 'Escape'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C6_M3.wav',
#   'text': 'Escape'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C6_M4.wav',
#   'text': 'Escape'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C6_M5.wav',
#   'text': 'Escape'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C6_M6.wav',
#   'text': 'Escape'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C6_M7.wav',
#   'text': 'Escape'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C6_M8.wav',
#   'text': 'Escape'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C7_M2.wav',
#   'text': 'Alt'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C7_M3.wav',
#   'text': 'Alt'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C7_M4.wav',
#   'text': 'Alt'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C7_M5.wav',
#   'text': 'Alt'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C7_M6.wav',
#   'text': 'Alt'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C7_M7.wav',
#   'text': 'Alt'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C7_M8.wav',
#   'text': 'Alt'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C8_M2.wav',
#   'text': 'Control'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C8_M3.wav',
#   'text': 'Control'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C8_M4.wav',
#   'text': 'Control'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C8_M5.wav',
#   'text': 'Control'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C8_M6.wav',
#   'text': 'Control'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C8_M7.wav',
#   'text': 'Control'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C8_M8.wav',
#   'text': 'Control'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C9_M2.wav',
#   'text': 'Shift'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C9_M3.wav',
#   'text': 'Shift'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C9_M4.wav',
#   'text': 'Shift'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C9_M5.wav',
#   'text': 'Shift'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C9_M6.wav',
#   'text': 'Shift'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C9_M7.wav',
#   'text': 'Shift'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_C9_M8.wav',
#   'text': 'Shift'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW100_M2.wav',
#   'text': 'yes'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW100_M3.wav',
#   'text': 'yes'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW100_M4.wav',
#   'text': 'yes'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW100_M5.wav',
#   'text': 'yes'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW100_M6.wav',
#   'text': 'yes'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW100_M7.wav',
#   'text': 'yes'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW100_M8.wav',
#   'text': 'yes'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW10_M2.wav',
#   'text': 'it'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW10_M3.wav',
#   'text': 'it'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW10_M4.wav',
#   'text': 'it'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW10_M5.wav',
#   'text': 'it'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW10_M6.wav',
#   'text': 'it'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW10_M7.wav',
#   'text': 'it'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW10_M8.wav',
#   'text': 'it'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW11_M2.wav',
#   'text': 'he'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW11_M3.wav',
#   'text': 'he'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW11_M4.wav',
#   'text': 'he'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW11_M5.wav',
#   'text': 'he'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW11_M6.wav',
#   'text': 'he'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW11_M7.wav',
#   'text': 'he'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW11_M8.wav',
#   'text': 'he'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW12_M2.wav',
#   'text': 'was'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW12_M3.wav',
#   'text': 'was'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW12_M4.wav',
#   'text': 'was'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW12_M5.wav',
#   'text': 'was'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW12_M6.wav',
#   'text': 'was'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW12_M7.wav',
#   'text': 'was'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW12_M8.wav',
#   'text': 'was'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW13_M2.wav',
#   'text': 'for'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW13_M3.wav',
#   'text': 'for'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW13_M4.wav',
#   'text': 'for'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW13_M5.wav',
#   'text': 'for'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW13_M6.wav',
#   'text': 'for'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW13_M7.wav',
#   'text': 'for'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW13_M8.wav',
#   'text': 'for'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW14_M2.wav',
#   'text': 'on'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW14_M3.wav',
#   'text': 'on'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW14_M4.wav',
#   'text': 'on'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW14_M5.wav',
#   'text': 'on'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW14_M6.wav',
#   'text': 'on'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW14_M7.wav',
#   'text': 'on'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW14_M8.wav',
#   'text': 'on'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW15_M2.wav',
#   'text': 'are'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW15_M3.wav',
#   'text': 'are'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW15_M4.wav',
#   'text': 'are'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW15_M5.wav',
#   'text': 'are'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW15_M6.wav',
#   'text': 'are'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW15_M7.wav',
#   'text': 'are'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW15_M8.wav',
#   'text': 'are'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW16_M2.wav',
#   'text': 'as'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW16_M3.wav',
#   'text': 'as'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW16_M4.wav',
#   'text': 'as'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW16_M5.wav',
#   'text': 'as'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW16_M6.wav',
#   'text': 'as'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW16_M7.wav',
#   'text': 'as'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW16_M8.wav',
#   'text': 'as'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW17_M2.wav',
#   'text': 'with'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW17_M3.wav',
#   'text': 'with'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW17_M4.wav',
#   'text': 'with'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW17_M5.wav',
#   'text': 'with'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW17_M6.wav',
#   'text': 'with'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW17_M7.wav',
#   'text': 'with'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW17_M8.wav',
#   'text': 'with'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW18_M2.wav',
#   'text': 'his'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW18_M3.wav',
#   'text': 'his'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW18_M4.wav',
#   'text': 'his'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW18_M5.wav',
#   'text': 'his'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW18_M6.wav',
#   'text': 'his'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW18_M7.wav',
#   'text': 'his'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW18_M8.wav',
#   'text': 'his'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW19_M2.wav',
#   'text': 'they'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW19_M3.wav',
#   'text': 'they'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW19_M4.wav',
#   'text': 'they'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW19_M5.wav',
#   'text': 'they'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW19_M6.wav',
#   'text': 'they'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW19_M7.wav',
#   'text': 'they'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW19_M8.wav',
#   'text': 'they'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW1_M2.wav',
#   'text': 'the'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW1_M3.wav',
#   'text': 'the'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW1_M4.wav',
#   'text': 'the'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW1_M5.wav',
#   'text': 'the'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW1_M6.wav',
#   'text': 'the'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW1_M7.wav',
#   'text': 'the'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW1_M8.wav',
#   'text': 'the'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW20_M2.wav',
#   'text': 'I'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW20_M3.wav',
#   'text': 'I'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW20_M4.wav',
#   'text': 'I'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW20_M5.wav',
#   'text': 'I'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW20_M6.wav',
#   'text': 'I'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW20_M7.wav',
#   'text': 'I'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW20_M8.wav',
#   'text': 'I'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW21_M2.wav',
#   'text': 'at'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW21_M3.wav',
#   'text': 'at'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW21_M4.wav',
#   'text': 'at'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW21_M5.wav',
#   'text': 'at'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW21_M6.wav',
#   'text': 'at'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW21_M7.wav',
#   'text': 'at'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW21_M8.wav',
#   'text': 'at'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW22_M2.wav',
#   'text': 'be'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW22_M3.wav',
#   'text': 'be'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW22_M4.wav',
#   'text': 'be'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW22_M5.wav',
#   'text': 'be'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW22_M6.wav',
#   'text': 'be'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW22_M7.wav',
#   'text': 'be'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW22_M8.wav',
#   'text': 'be'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW23_M2.wav',
#   'text': 'this'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW23_M3.wav',
#   'text': 'this'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW23_M4.wav',
#   'text': 'this'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW23_M5.wav',
#   'text': 'this'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW23_M6.wav',
#   'text': 'this'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW23_M7.wav',
#   'text': 'this'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW23_M8.wav',
#   'text': 'this'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW24_M2.wav',
#   'text': 'have'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW24_M3.wav',
#   'text': 'have'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW24_M4.wav',
#   'text': 'have'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW24_M5.wav',
#   'text': 'have'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW24_M6.wav',
#   'text': 'have'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW24_M7.wav',
#   'text': 'have'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW24_M8.wav',
#   'text': 'have'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW25_M2.wav',
#   'text': 'from'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW25_M3.wav',
#   'text': 'from'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW25_M4.wav',
#   'text': 'from'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW25_M5.wav',
#   'text': 'from'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW25_M6.wav',
#   'text': 'from'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW25_M7.wav',
#   'text': 'from'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW25_M8.wav',
#   'text': 'from'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW26_M2.wav',
#   'text': 'or'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW26_M3.wav',
#   'text': 'or'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW26_M4.wav',
#   'text': 'or'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW26_M5.wav',
#   'text': 'or'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW26_M6.wav',
#   'text': 'or'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW26_M7.wav',
#   'text': 'or'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW26_M8.wav',
#   'text': 'or'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW27_M2.wav',
#   'text': 'had'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW27_M3.wav',
#   'text': 'had'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW27_M4.wav',
#   'text': 'had'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW27_M5.wav',
#   'text': 'had'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW27_M6.wav',
#   'text': 'had'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW27_M7.wav',
#   'text': 'had'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW27_M8.wav',
#   'text': 'had'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW28_M2.wav',
#   'text': 'by'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW28_M3.wav',
#   'text': 'by'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW28_M4.wav',
#   'text': 'by'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW28_M5.wav',
#   'text': 'by'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW28_M6.wav',
#   'text': 'by'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW28_M7.wav',
#   'text': 'by'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW28_M8.wav',
#   'text': 'by'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW29_M2.wav',
#   'text': 'word'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW29_M3.wav',
#   'text': 'word'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW29_M4.wav',
#   'text': 'word'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW29_M5.wav',
#   'text': 'word'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW29_M6.wav',
#   'text': 'word'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW29_M7.wav',
#   'text': 'word'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW29_M8.wav',
#   'text': 'word'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW2_M2.wav',
#   'text': 'of'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW2_M3.wav',
#   'text': 'of'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW2_M4.wav',
#   'text': 'of'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW2_M5.wav',
#   'text': 'of'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW2_M6.wav',
#   'text': 'of'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW2_M7.wav',
#   'text': 'of'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW2_M8.wav',
#   'text': 'of'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW30_M2.wav',
#   'text': 'but'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW30_M3.wav',
#   'text': 'but'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW30_M4.wav',
#   'text': 'but'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW30_M5.wav',
#   'text': 'but'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW30_M6.wav',
#   'text': 'but'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW30_M7.wav',
#   'text': 'but'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW30_M8.wav',
#   'text': 'but'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW31_M2.wav',
#   'text': 'not'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW31_M3.wav',
#   'text': 'not'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW31_M4.wav',
#   'text': 'not'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW31_M5.wav',
#   'text': 'not'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW31_M6.wav',
#   'text': 'not'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW31_M7.wav',
#   'text': 'not'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW31_M8.wav',
#   'text': 'not'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW32_M2.wav',
#   'text': 'what'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW32_M3.wav',
#   'text': 'what'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW32_M4.wav',
#   'text': 'what'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW32_M5.wav',
#   'text': 'what'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW32_M6.wav',
#   'text': 'what'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW32_M7.wav',
#   'text': 'what'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW32_M8.wav',
#   'text': 'what'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW33_M2.wav',
#   'text': 'all'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW33_M3.wav',
#   'text': 'all'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW33_M4.wav',
#   'text': 'all'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW33_M5.wav',
#   'text': 'all'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW33_M6.wav',
#   'text': 'all'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW33_M7.wav',
#   'text': 'all'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW33_M8.wav',
#   'text': 'all'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW34_M2.wav',
#   'text': 'were'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW34_M3.wav',
#   'text': 'were'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW34_M4.wav',
#   'text': 'were'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW34_M5.wav',
#   'text': 'were'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW34_M6.wav',
#   'text': 'were'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW34_M7.wav',
#   'text': 'were'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW34_M8.wav',
#   'text': 'were'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW35_M2.wav',
#   'text': 'we'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW35_M3.wav',
#   'text': 'we'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW35_M4.wav',
#   'text': 'we'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW35_M5.wav',
#   'text': 'we'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW35_M6.wav',
#   'text': 'we'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW35_M7.wav',
#   'text': 'we'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW35_M8.wav',
#   'text': 'we'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW36_M2.wav',
#   'text': 'when'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW36_M3.wav',
#   'text': 'when'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW36_M4.wav',
#   'text': 'when'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW36_M5.wav',
#   'text': 'when'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW36_M6.wav',
#   'text': 'when'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW36_M7.wav',
#   'text': 'when'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW36_M8.wav',
#   'text': 'when'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW37_M2.wav',
#   'text': 'your'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW37_M3.wav',
#   'text': 'your'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW37_M4.wav',
#   'text': 'your'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW37_M5.wav',
#   'text': 'your'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW37_M6.wav',
#   'text': 'your'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW37_M7.wav',
#   'text': 'your'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW37_M8.wav',
#   'text': 'your'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW38_M2.wav',
#   'text': 'can'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW38_M3.wav',
#   'text': 'can'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW38_M4.wav',
#   'text': 'can'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW38_M5.wav',
#   'text': 'can'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW38_M6.wav',
#   'text': 'can'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW38_M7.wav',
#   'text': 'can'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW38_M8.wav',
#   'text': 'can'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW39_M2.wav',
#   'text': 'said'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW39_M3.wav',
#   'text': 'said'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW39_M4.wav',
#   'text': 'said'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW39_M5.wav',
#   'text': 'said'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW39_M6.wav',
#   'text': 'said'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW39_M7.wav',
#   'text': 'said'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW39_M8.wav',
#   'text': 'said'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW3_M2.wav',
#   'text': 'and'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW3_M3.wav',
#   'text': 'and'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW3_M4.wav',
#   'text': 'and'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW3_M5.wav',
#   'text': 'and'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW3_M6.wav',
#   'text': 'and'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW3_M7.wav',
#   'text': 'and'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW3_M8.wav',
#   'text': 'and'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW40_M2.wav',
#   'text': 'there'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW40_M3.wav',
#   'text': 'there'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW40_M4.wav',
#   'text': 'there'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW40_M5.wav',
#   'text': 'there'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW40_M6.wav',
#   'text': 'there'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW40_M7.wav',
#   'text': 'there'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW40_M8.wav',
#   'text': 'there'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW41_M2.wav',
#   'text': 'use'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW41_M3.wav',
#   'text': 'use'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW41_M4.wav',
#   'text': 'use'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW41_M5.wav',
#   'text': 'use'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW41_M6.wav',
#   'text': 'use'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW41_M7.wav',
#   'text': 'use'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW41_M8.wav',
#   'text': 'use'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW42_M2.wav',
#   'text': 'an'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW42_M3.wav',
#   'text': 'an'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW42_M4.wav',
#   'text': 'an'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW42_M5.wav',
#   'text': 'an'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW42_M6.wav',
#   'text': 'an'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW42_M7.wav',
#   'text': 'an'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW42_M8.wav',
#   'text': 'an'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW43_M2.wav',
#   'text': 'each'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW43_M3.wav',
#   'text': 'each'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW43_M4.wav',
#   'text': 'each'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW43_M5.wav',
#   'text': 'each'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW43_M6.wav',
#   'text': 'each'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW43_M7.wav',
#   'text': 'each'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW43_M8.wav',
#   'text': 'each'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW44_M2.wav',
#   'text': 'which'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW44_M3.wav',
#   'text': 'which'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW44_M4.wav',
#   'text': 'which'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW44_M5.wav',
#   'text': 'which'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW44_M6.wav',
#   'text': 'which'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW44_M7.wav',
#   'text': 'which'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW44_M8.wav',
#   'text': 'which'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW45_M2.wav',
#   'text': 'she'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW45_M3.wav',
#   'text': 'she'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW45_M4.wav',
#   'text': 'she'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW45_M5.wav',
#   'text': 'she'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW45_M6.wav',
#   'text': 'she'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW45_M7.wav',
#   'text': 'she'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW45_M8.wav',
#   'text': 'she'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW46_M2.wav',
#   'text': 'do'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW46_M3.wav',
#   'text': 'do'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW46_M4.wav',
#   'text': 'do'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW46_M5.wav',
#   'text': 'do'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW46_M6.wav',
#   'text': 'do'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW46_M7.wav',
#   'text': 'do'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW46_M8.wav',
#   'text': 'do'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW47_M2.wav',
#   'text': 'how'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW47_M3.wav',
#   'text': 'how'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW47_M4.wav',
#   'text': 'how'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW47_M5.wav',
#   'text': 'how'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW47_M6.wav',
#   'text': 'how'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW47_M7.wav',
#   'text': 'how'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW47_M8.wav',
#   'text': 'how'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW48_M2.wav',
#   'text': 'their'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW48_M3.wav',
#   'text': 'their'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW48_M4.wav',
#   'text': 'their'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW48_M5.wav',
#   'text': 'their'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW48_M6.wav',
#   'text': 'their'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW48_M7.wav',
#   'text': 'their'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW48_M8.wav',
#   'text': 'their'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW49_M2.wav',
#   'text': 'if'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW49_M3.wav',
#   'text': 'if'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW49_M4.wav',
#   'text': 'if'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW49_M5.wav',
#   'text': 'if'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW49_M6.wav',
#   'text': 'if'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW49_M7.wav',
#   'text': 'if'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW49_M8.wav',
#   'text': 'if'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW4_M2.wav', 'text': 'a'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW4_M3.wav', 'text': 'a'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW4_M4.wav', 'text': 'a'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW4_M5.wav', 'text': 'a'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW4_M6.wav', 'text': 'a'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW4_M7.wav', 'text': 'a'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW4_M8.wav', 'text': 'a'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW50_M2.wav',
#   'text': 'will'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW50_M3.wav',
#   'text': 'will'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW50_M4.wav',
#   'text': 'will'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW50_M5.wav',
#   'text': 'will'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW50_M6.wav',
#   'text': 'will'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW50_M7.wav',
#   'text': 'will'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW50_M8.wav',
#   'text': 'will'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW51_M2.wav',
#   'text': 'up'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW51_M3.wav',
#   'text': 'up'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW51_M4.wav',
#   'text': 'up'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW51_M5.wav',
#   'text': 'up'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW51_M6.wav',
#   'text': 'up'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW51_M7.wav',
#   'text': 'up'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW51_M8.wav',
#   'text': 'up'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW52_M2.wav',
#   'text': 'other'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW52_M3.wav',
#   'text': 'other'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW52_M4.wav',
#   'text': 'other'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW52_M5.wav',
#   'text': 'other'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW52_M6.wav',
#   'text': 'other'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW52_M7.wav',
#   'text': 'other'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW52_M8.wav',
#   'text': 'other'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW53_M2.wav',
#   'text': 'about'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW53_M3.wav',
#   'text': 'about'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW53_M4.wav',
#   'text': 'about'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW53_M5.wav',
#   'text': 'about'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW53_M6.wav',
#   'text': 'about'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW53_M7.wav',
#   'text': 'about'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW53_M8.wav',
#   'text': 'about'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW54_M2.wav',
#   'text': 'out'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW54_M3.wav',
#   'text': 'out'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW54_M4.wav',
#   'text': 'out'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW54_M5.wav',
#   'text': 'out'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW54_M6.wav',
#   'text': 'out'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW54_M7.wav',
#   'text': 'out'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW54_M8.wav',
#   'text': 'out'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW55_M2.wav',
#   'text': 'many'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW55_M3.wav',
#   'text': 'many'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW55_M4.wav',
#   'text': 'many'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW55_M5.wav',
#   'text': 'many'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW55_M6.wav',
#   'text': 'many'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW55_M7.wav',
#   'text': 'many'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW55_M8.wav',
#   'text': 'many'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW56_M2.wav',
#   'text': 'then'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW56_M3.wav',
#   'text': 'then'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW56_M4.wav',
#   'text': 'then'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW56_M5.wav',
#   'text': 'then'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW56_M6.wav',
#   'text': 'then'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW56_M7.wav',
#   'text': 'then'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW56_M8.wav',
#   'text': 'then'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW57_M2.wav',
#   'text': 'them'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW57_M3.wav',
#   'text': 'them'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW57_M4.wav',
#   'text': 'them'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW57_M5.wav',
#   'text': 'them'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW57_M6.wav',
#   'text': 'them'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW57_M7.wav',
#   'text': 'them'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW57_M8.wav',
#   'text': 'them'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW58_M2.wav',
#   'text': 'these'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW58_M3.wav',
#   'text': 'these'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW58_M4.wav',
#   'text': 'these'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW58_M5.wav',
#   'text': 'these'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW58_M6.wav',
#   'text': 'these'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW58_M7.wav',
#   'text': 'these'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW58_M8.wav',
#   'text': 'these'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW59_M2.wav',
#   'text': 'so'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW59_M3.wav',
#   'text': 'so'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW59_M4.wav',
#   'text': 'so'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW59_M5.wav',
#   'text': 'so'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW59_M6.wav',
#   'text': 'so'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW59_M7.wav',
#   'text': 'so'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW59_M8.wav',
#   'text': 'so'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW5_M2.wav',
#   'text': 'to'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW5_M3.wav',
#   'text': 'to'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW5_M4.wav',
#   'text': 'to'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW5_M5.wav',
#   'text': 'to'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW5_M6.wav',
#   'text': 'to'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW5_M7.wav',
#   'text': 'to'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW5_M8.wav',
#   'text': 'to'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW60_M2.wav',
#   'text': 'some'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW60_M3.wav',
#   'text': 'some'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW60_M4.wav',
#   'text': 'some'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW60_M5.wav',
#   'text': 'some'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW60_M6.wav',
#   'text': 'some'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW60_M7.wav',
#   'text': 'some'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW60_M8.wav',
#   'text': 'some'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW61_M2.wav',
#   'text': 'her'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW61_M3.wav',
#   'text': 'her'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW61_M4.wav',
#   'text': 'her'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW61_M5.wav',
#   'text': 'her'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW61_M6.wav',
#   'text': 'her'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW61_M7.wav',
#   'text': 'her'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW61_M8.wav',
#   'text': 'her'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW62_M2.wav',
#   'text': 'would'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW62_M3.wav',
#   'text': 'would'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW62_M4.wav',
#   'text': 'would'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW62_M5.wav',
#   'text': 'would'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW62_M6.wav',
#   'text': 'would'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW62_M7.wav',
#   'text': 'would'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW62_M8.wav',
#   'text': 'would'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW63_M2.wav',
#   'text': 'make'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW63_M3.wav',
#   'text': 'make'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW63_M4.wav',
#   'text': 'make'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW63_M5.wav',
#   'text': 'make'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW63_M6.wav',
#   'text': 'make'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW63_M7.wav',
#   'text': 'make'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW63_M8.wav',
#   'text': 'make'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW64_M2.wav',
#   'text': 'like'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW64_M3.wav',
#   'text': 'like'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW64_M4.wav',
#   'text': 'like'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW64_M5.wav',
#   'text': 'like'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW64_M6.wav',
#   'text': 'like'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW64_M7.wav',
#   'text': 'like'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW64_M8.wav',
#   'text': 'like'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW65_M2.wav',
#   'text': 'him'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW65_M3.wav',
#   'text': 'him'},
# ...
#   'text': 'may'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW98_M2.wav',
#   'text': 'part'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW98_M3.wav',
#   'text': 'part'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW98_M4.wav',
#   'text': 'part'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW98_M5.wav',
#   'text': 'part'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW98_M6.wav',
#   'text': 'part'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW98_M7.wav',
#   'text': 'part'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW98_M8.wav',
#   'text': 'part'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW99_M2.wav',
#   'text': 'oh'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW99_M3.wav',
#   'text': 'oh'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW99_M4.wav',
#   'text': 'oh'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW99_M5.wav',
#   'text': 'oh'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW99_M6.wav',
#   'text': 'oh'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW99_M7.wav',
#   'text': 'oh'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW99_M8.wav',
#   'text': 'oh'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW9_M2.wav',
#   'text': 'that'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW9_M3.wav',
#   'text': 'that'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW9_M4.wav',
#   'text': 'that'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW9_M5.wav',
#   'text': 'that'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW9_M6.wav',
#   'text': 'that'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW9_M7.wav',
#   'text': 'that'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_CW9_M8.wav',
#   'text': 'that'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D0_M2.wav',
#   'text': 'Zero'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D0_M3.wav',
#   'text': 'Zero'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D0_M4.wav',
#   'text': 'Zero'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D0_M5.wav',
#   'text': 'Zero'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D0_M6.wav',
#   'text': 'Zero'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D0_M7.wav',
#   'text': 'Zero'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D0_M8.wav',
#   'text': 'Zero'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D1_M2.wav',
#   'text': 'One'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D1_M3.wav',
#   'text': 'One'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D1_M4.wav',
#   'text': 'One'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D1_M5.wav',
#   'text': 'One'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D1_M6.wav',
#   'text': 'One'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D1_M7.wav',
#   'text': 'One'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D1_M8.wav',
#   'text': 'One'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D2_M2.wav',
#   'text': 'Two'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D2_M3.wav',
#   'text': 'Two'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D2_M4.wav',
#   'text': 'Two'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D2_M5.wav',
#   'text': 'Two'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D2_M6.wav',
#   'text': 'Two'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D2_M7.wav',
#   'text': 'Two'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D2_M8.wav',
#   'text': 'Two'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D3_M2.wav',
#   'text': 'Three'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D3_M3.wav',
#   'text': 'Three'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D3_M4.wav',
#   'text': 'Three'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D3_M5.wav',
#   'text': 'Three'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D3_M6.wav',
#   'text': 'Three'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D3_M7.wav',
#   'text': 'Three'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D3_M8.wav',
#   'text': 'Three'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D4_M2.wav',
#   'text': 'Four'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D4_M3.wav',
#   'text': 'Four'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D4_M4.wav',
#   'text': 'Four'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D4_M5.wav',
#   'text': 'Four'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D4_M6.wav',
#   'text': 'Four'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D4_M7.wav',
#   'text': 'Four'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D4_M8.wav',
#   'text': 'Four'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D5_M2.wav',
#   'text': 'Five'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D5_M3.wav',
#   'text': 'Five'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D5_M4.wav',
#   'text': 'Five'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D5_M5.wav',
#   'text': 'Five'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D5_M6.wav',
#   'text': 'Five'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D5_M7.wav',
#   'text': 'Five'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D5_M8.wav',
#   'text': 'Five'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D6_M2.wav',
#   'text': 'Six'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D6_M3.wav',
#   'text': 'Six'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D6_M4.wav',
#   'text': 'Six'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D6_M5.wav',
#   'text': 'Six'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D6_M6.wav',
#   'text': 'Six'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D6_M7.wav',
#   'text': 'Six'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D6_M8.wav',
#   'text': 'Six'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D7_M2.wav',
#   'text': 'Seven'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D7_M3.wav',
#   'text': 'Seven'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D7_M4.wav',
#   'text': 'Seven'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D7_M5.wav',
#   'text': 'Seven'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D7_M6.wav',
#   'text': 'Seven'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D7_M7.wav',
#   'text': 'Seven'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D7_M8.wav',
#   'text': 'Seven'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D8_M2.wav',
#   'text': 'Eight'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D8_M3.wav',
#   'text': 'Eight'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D8_M4.wav',
#   'text': 'Eight'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D8_M5.wav',
#   'text': 'Eight'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D8_M6.wav',
#   'text': 'Eight'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D8_M7.wav',
#   'text': 'Eight'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D8_M8.wav',
#   'text': 'Eight'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D9_M2.wav',
#   'text': 'Nine'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D9_M3.wav',
#   'text': 'Nine'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D9_M4.wav',
#   'text': 'Nine'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D9_M5.wav',
#   'text': 'Nine'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D9_M6.wav',
#   'text': 'Nine'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D9_M7.wav',
#   'text': 'Nine'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_D9_M8.wav',
#   'text': 'Nine'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LA_M2.wav',
#   'text': 'Alpha'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LA_M3.wav',
#   'text': 'Alpha'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LA_M4.wav',
#   'text': 'Alpha'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LA_M5.wav',
#   'text': 'Alpha'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LA_M6.wav',
#   'text': 'Alpha'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LA_M7.wav',
#   'text': 'Alpha'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LA_M8.wav',
#   'text': 'Alpha'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LB_M2.wav',
#   'text': 'Bravo'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LB_M3.wav',
#   'text': 'Bravo'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LB_M4.wav',
#   'text': 'Bravo'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LB_M5.wav',
#   'text': 'Bravo'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LB_M6.wav',
#   'text': 'Bravo'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LB_M7.wav',
#   'text': 'Bravo'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LB_M8.wav',
#   'text': 'Bravo'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LC_M2.wav',
#   'text': 'Charlie'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LC_M3.wav',
#   'text': 'Charlie'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LC_M4.wav',
#   'text': 'Charlie'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LC_M5.wav',
#   'text': 'Charlie'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LC_M6.wav',
#   'text': 'Charlie'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LC_M7.wav',
#   'text': 'Charlie'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LC_M8.wav',
#   'text': 'Charlie'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LD_M2.wav',
#   'text': 'Delta'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LD_M3.wav',
#   'text': 'Delta'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LD_M4.wav',
#   'text': 'Delta'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LD_M5.wav',
#   'text': 'Delta'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LD_M6.wav',
#   'text': 'Delta'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LD_M7.wav',
#   'text': 'Delta'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LD_M8.wav',
#   'text': 'Delta'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LE_M2.wav',
#   'text': 'Echo'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LE_M3.wav',
#   'text': 'Echo'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LE_M4.wav',
#   'text': 'Echo'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LE_M5.wav',
#   'text': 'Echo'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LE_M6.wav',
#   'text': 'Echo'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LE_M7.wav',
#   'text': 'Echo'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LE_M8.wav',
#   'text': 'Echo'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LF_M2.wav',
#   'text': 'Foxtrot'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LF_M3.wav',
#   'text': 'Foxtrot'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LF_M4.wav',
#   'text': 'Foxtrot'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LF_M5.wav',
#   'text': 'Foxtrot'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LF_M6.wav',
#   'text': 'Foxtrot'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LF_M7.wav',
#   'text': 'Foxtrot'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LF_M8.wav',
#   'text': 'Foxtrot'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LG_M2.wav',
#   'text': 'Golf'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LG_M3.wav',
#   'text': 'Golf'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LG_M4.wav',
#   'text': 'Golf'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LG_M5.wav',
#   'text': 'Golf'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LG_M6.wav',
#   'text': 'Golf'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LG_M7.wav',
#   'text': 'Golf'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LG_M8.wav',
#   'text': 'Golf'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LH_M2.wav',
#   'text': 'Hotel'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LH_M3.wav',
#   'text': 'Hotel'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LH_M4.wav',
#   'text': 'Hotel'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LH_M5.wav',
#   'text': 'Hotel'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LH_M6.wav',
#   'text': 'Hotel'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LH_M7.wav',
#   'text': 'Hotel'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LH_M8.wav',
#   'text': 'Hotel'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LI_M2.wav',
#   'text': 'India'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LI_M3.wav',
#   'text': 'India'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LI_M4.wav',
#   'text': 'India'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LI_M5.wav',
#   'text': 'India'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LI_M6.wav',
#   'text': 'India'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LI_M7.wav',
#   'text': 'India'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LI_M8.wav',
#   'text': 'India'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LJ_M2.wav',
#   'text': 'Juliet'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LJ_M3.wav',
#   'text': 'Juliet'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LJ_M4.wav',
#   'text': 'Juliet'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LJ_M5.wav',
#   'text': 'Juliet'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LJ_M6.wav',
#   'text': 'Juliet'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LJ_M7.wav',
#   'text': 'Juliet'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LJ_M8.wav',
#   'text': 'Juliet'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LK_M2.wav',
#   'text': 'Kilo'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LK_M3.wav',
#   'text': 'Kilo'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LK_M4.wav',
#   'text': 'Kilo'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LK_M5.wav',
#   'text': 'Kilo'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LK_M6.wav',
#   'text': 'Kilo'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LK_M7.wav',
#   'text': 'Kilo'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LK_M8.wav',
#   'text': 'Kilo'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LL_M2.wav',
#   'text': 'Lima'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LL_M3.wav',
#   'text': 'Lima'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LL_M4.wav',
#   'text': 'Lima'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LL_M5.wav',
#   'text': 'Lima'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LL_M6.wav',
#   'text': 'Lima'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LL_M7.wav',
#   'text': 'Lima'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LL_M8.wav',
#   'text': 'Lima'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LM_M2.wav',
#   'text': 'Mike'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LM_M3.wav',
#   'text': 'Mike'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LM_M4.wav',
#   'text': 'Mike'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LM_M5.wav',
#   'text': 'Mike'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LM_M6.wav',
#   'text': 'Mike'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LM_M7.wav',
#   'text': 'Mike'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LM_M8.wav',
#   'text': 'Mike'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LN_M2.wav',
#   'text': 'November'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LN_M3.wav',
#   'text': 'November'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LN_M4.wav',
#   'text': 'November'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LN_M5.wav',
#   'text': 'November'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LN_M6.wav',
#   'text': 'November'},
#  {'audio': 'C:\\Users\\abdul\\Downloads\\F04\\F04_B1_LN_M7.wav',
#   'text': 'November'},
#  ...]

# %%
ds = create_tf_dataset(data, bs=64)
# Out:
# Tensor("DecodeWav:0", shape=(None, 1), dtype=float32)
# Tensor("Squeeze:0", shape=(None,), dtype=float32)

# %%
evaluation_result = rmodel.evaluate(ds)

# Print the evaluation results
print("Test Loss:", evaluation_result)
print("Test Accuracy:", rmodel.metrics_names)  # Prints all metric names
print("Test Accuracy:", evaluation_result)
# Out:
# 56/56 [==============================] - 9s 162ms/step - loss: 0.0219 - accuracy: 0.9965
# Test Loss: [0.021915392950177193, 0.9965347051620483]
# Test Accuracy: ['loss', 'accuracy']
# Test Accuracy: [0.021915392950177193, 0.9965347051620483]

# %%
import numpy as np

def predict_label(model, audio_path):
    # Load and process the audio file
    audio = path_to_audio(audio_path)
    audio = tf.expand_dims(audio, axis=0)  # Add batch dimensionprint

    # Generate predictions
    start_token_idx = 2  # Adjust this based on your vocabulary
    preds = model.generate(audio, start_token_idx).numpy()

    # Convert predicted indices to label
    idx_to_char = vectorizer.get_vocabulary()
    predicted_label = ""
    for idx in preds[0, :]:
        predicted_label += idxprint_to_char[idx]
        if idx == 3:  # End token index, adjust based on your vocabulary
            break

    return predicted_label.replace("-", "")  # Adjust based on your preprocessing

# Example usage:

# %%
def target(wav, id_to_text, maxlen=50):
    """ returns mapping of audio paths and transcription texts """
    
    id = wav.split("\\")[-1]
    for item in k:
        if item+"_" in id and len(id_to_text[item]) < maxlen:
            return id_to_text[item]

# %%
audio_path = r"C:\Users\abdul\project_presentation\output_file.wav"

predicted_label = predict_label(rmodel, audio_path)
print("Predicted Label:", predicted_label)
# Out:
# Predicted Label: <

# %%
def calculate_accuracy(predictions, targets):
    # Remove "<,<"
    predictions_cleaned = [p.replace("<", "") for p in predictions]
    predictions_cleaned = [p.replace(">", "") for p in predictions_cleaned]
    # Convert both predicted and target labels to lowercase for case-insensitive comparison
    predictions_lower = [p.lower() for p in predictions_cleaned]
    #print(predictions_lower)
    targets_lower = [t.lower() for t in targets]
    #print(targets_lower)
    correct_predictions = sum(p == t for p, t in zip(predictions_lower, targets_lower))
    accuracy = correct_predictions / len(targets) if len(targets) > 0 else 0.0
    return accuracy

# %%
audio_folder = r"C:\Users\abdul\Downloads\Test"
# Get a list of all audio files in the folder
audio_files = [file for file in os.listdir(audio_folder) if file.endswith(".wav")]

# Initialize lists to store predictions and targets
predicted_labels = []
target_labels = []

# Iterate through all audio files
for audio_file in audio_files:
    audio_path = os.path.join(audio_folder, audio_file)
    print(audio_path)
    # Get target label
    target_label = target(audio_file, id_to_text)

    # Load and process the audio file
    #audio = path_to_audio(audio_path)

    # Generate predictions
    predicted_label = predict_label(rmodel, audio_path)

    # Print target and predicted labels
    print(f"Target Label: {target_label}")
    print(f"Predicted Label: {predicted_label}\n")

    # Store predictions and targets for accuracy calculation
    predicted_labels.append(predicted_label)
    target_labels.append(target_label)

# Calculate and print accuracy
accuracy = calculate_accuracy(predicted_labels, target_labels)
print(f"Overall Accuracy: {accuracy * 100:.2f}%")
# Out:
# C:\Users\abdul\Downloads\Test\F04_B3_C10_M2.wav
# Target Label: Line
# Predicted Label: <line>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C10_M3.wav
# Target Label: Line
# Predicted Label: <find>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C10_M4.wav
# Target Label: Line
# Predicted Label: <line>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C10_M5.wav
# Target Label: Line
# Predicted Label: <line>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C10_M6.wav
# Target Label: Line
# Predicted Label: <five>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C10_M7.wav
# Target Label: Line
# Predicted Label: <line>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C10_M8.wav
# Target Label: Line
# Predicted Label: <line>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C11_M2.wav
# Target Label: Paragraph
# Predicted Label: <paragraph>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C11_M3.wav
# Target Label: Paragraph
# Predicted Label: <paragraph>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C11_M4.wav
# Target Label: Paragraph
# Predicted Label: <paragraph>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C11_M5.wav
# Target Label: Paragraph
# Predicted Label: <paragraph>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C11_M6.wav
# Target Label: Paragraph
# Predicted Label: <paragraph>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C11_M7.wav
# Target Label: Paragraph
# Predicted Label: <paragraph>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C11_M8.wav
# Target Label: Paragraph
# Predicted Label: <paragraph>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C12_M2.wav
# Target Label: Sentence
# Predicted Label: <entertheless>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C12_M3.wav
# Target Label: Sentence
# Predicted Label: <contence>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C12_M4.wav
# Target Label: Sentence
# Predicted Label: <anterthel>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C12_M5.wav
# Target Label: Sentence
# Predicted Label: <anter>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C12_M6.wav
# Target Label: Sentence
# Predicted Label: <antertheless>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C12_M7.wav
# Target Label: Sentence
# Predicted Label: <and>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C12_M8.wav
# Target Label: Sentence
# Predicted Label: <convence>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C13_M2.wav
# Target Label: Paste
# Predicted Label: <paste>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C13_M3.wav
# Target Label: Paste
# Predicted Label: <paste>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C13_M4.wav
# Target Label: Paste
# Predicted Label: <paste>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C13_M5.wav
# Target Label: Paste
# Predicted Label: <paste>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C13_M6.wav
# Target Label: Paste
# Predicted Label: <paste>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C13_M7.wav
# Target Label: Paste
# Predicted Label: <paste>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C13_M8.wav
# Target Label: Paste
# Predicted Label: <paste>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C14_M2.wav
# Target Label: Cut
# Predicted Label: <could>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C14_M3.wav
# Target Label: Cut
# Predicted Label: <could>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C14_M4.wav
# Target Label: Cut
# Predicted Label: <cut>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C14_M5.wav
# Target Label: Cut
# Predicted Label: <could>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C14_M6.wav
# Target Label: Cut
# Predicted Label: <could>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C14_M7.wav
# Target Label: Cut
# Predicted Label: <couth>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C14_M8.wav
# Target Label: Cut
# Predicted Label: <could>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C15_M2.wav
# Target Label: Copy
# Predicted Label: <southeast>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C15_M3.wav
# Target Label: Copy
# Predicted Label: <southeast>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C15_M4.wav
# Target Label: Copy
# Predicted Label: <be>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C15_M5.wav
# Target Label: Copy
# Predicted Label: <see>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C15_M6.wav
# Target Label: Copy
# Predicted Label: <copy>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C15_M7.wav
# Target Label: Copy
# Predicted Label: <southeast>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C15_M8.wav
# Target Label: Copy
# Predicted Label: <southeast>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C16_M2.wav
# Target Label: Upward
# Predicted Label: <upwrer>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C16_M3.wav
# Target Label: Upward
# Predicted Label: <upward>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C16_M4.wav
# Target Label: Upward
# Predicted Label: <upward>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C16_M5.wav
# Target Label: Upward
# Predicted Label: <upward>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C16_M6.wav
# Target Label: Upward
# Predicted Label: <other>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C16_M7.wav
# Target Label: Upward
# Predicted Label: <uper>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C16_M8.wav
# Target Label: Upward
# Predicted Label: <upward>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C17_M2.wav
# Target Label: Downward
# Predicted Label: <downward>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C17_M3.wav
# Target Label: Downward
# Predicted Label: <downward>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C17_M4.wav
# Target Label: Downward
# Predicted Label: <downward>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C17_M5.wav
# Target Label: Downward
# Predicted Label: <downward>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C17_M6.wav
# Target Label: Downward
# Predicted Label: <downward>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C17_M7.wav
# Target Label: Downward
# Predicted Label: <downward>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C17_M8.wav
# Target Label: Downward
# Predicted Label: <downward>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C18_M2.wav
# Target Label: Left
# Predicted Label: <left>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C18_M3.wav
# Target Label: Left
# Predicted Label: <left>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C18_M4.wav
# Target Label: Left
# Predicted Label: <left>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C18_M5.wav
# Target Label: Left
# Predicted Label: <what>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C18_M6.wav
# Target Label: Left
# Predicted Label: <left>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C18_M7.wav
# Target Label: Left
# Predicted Label: <what>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C18_M8.wav
# Target Label: Left
# Predicted Label: <left>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C19_M2.wav
# Target Label: Right
# Predicted Label: <right>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C19_M3.wav
# Target Label: Right
# Predicted Label: <mike>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C19_M4.wav
# Target Label: Right
# Predicted Label: <right>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C19_M5.wav
# Target Label: Right
# Predicted Label: <right>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C19_M6.wav
# Target Label: Right
# Predicted Label: <right>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C19_M7.wav
# Target Label: Right
# Predicted Label: <right>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C19_M8.wav
# Target Label: Right
# Predicted Label: <mike>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C1_M2.wav
# Target Label: Command
# Predicted Label: <command>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C1_M3.wav
# Target Label: Command
# Predicted Label: <commhng>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C1_M4.wav
# Target Label: Command
# Predicted Label: <hind>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C1_M5.wav
# Target Label: Command
# Predicted Label: <hind>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C1_M6.wav
# Target Label: Command
# Predicted Label: <hin>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C1_M7.wav
# Target Label: Command
# Predicted Label: <mahsend>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C1_M8.wav
# Target Label: Command
# Predicted Label: <mahend>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C2_M2.wav
# Target Label: Backspace
# Predicted Label: <lesis>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C2_M3.wav
# Target Label: Backspace
# Predicted Label: <backspace>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C2_M4.wav
# Target Label: Backspace
# Predicted Label: <backspace>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C2_M5.wav
# Target Label: Backspace
# Predicted Label: <backspace>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C2_M6.wav
# Target Label: Backspace
# Predicted Label: <bathe>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C2_M7.wav
# Target Label: Backspace
# Predicted Label: <if>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C2_M8.wav
# Target Label: Backspace
# Predicted Label: <it>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C3_M2.wav
# Target Label: Delete
# Predicted Label: <three>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C3_M3.wav
# Target Label: Delete
# Predicted Label: <thirty>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C3_M4.wav
# Target Label: Delete
# Predicted Label: <three>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C3_M5.wav
# Target Label: Delete
# Predicted Label: <ser>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C3_M6.wav
# Target Label: Delete
# Predicted Label: <thirty>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C3_M7.wav
# Target Label: Delete
# Predicted Label: <if>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C3_M8.wav
# Target Label: Delete
# Predicted Label: <we>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C4_M2.wav
# Target Label: Enter
# Predicted Label: <enter>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C4_M3.wav
# Target Label: Enter
# Predicted Label: <enter>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C4_M4.wav
# Target Label: Enter
# Predicted Label: <enterthel>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C4_M5.wav
# Target Label: Enter
# Predicted Label: <enter>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C4_M6.wav
# Target Label: Enter
# Predicted Label: <enter>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C4_M7.wav
# Target Label: Enter
# Predicted Label: <enter>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C4_M8.wav
# Target Label: Enter
# Predicted Label: <enter>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C5_M2.wav
# Target Label: Tab
# Predicted Label: <get>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C5_M3.wav
# Target Label: Tab
# Predicted Label: <get>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C5_M4.wav
# Target Label: Tab
# Predicted Label: <can>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C5_M5.wav
# Target Label: Tab
# Predicted Label: <casualties>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C5_M6.wav
# Target Label: Tab
# Predicted Label: <get>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C5_M7.wav
# Target Label: Tab
# Predicted Label: <tan>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C5_M8.wav
# Target Label: Tab
# Predicted Label: <cand>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C6_M2.wav
# Target Label: Escape
# Predicted Label: <escape>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C6_M3.wav
# Target Label: Escape
# Predicted Label: <bethese>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C6_M4.wav
# Target Label: Escape
# Predicted Label: <es>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C6_M5.wav
# Target Label: Escape
# Predicted Label: <bees>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C6_M6.wav
# Target Label: Escape
# Predicted Label: <is>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C6_M7.wav
# Target Label: Escape
# Predicted Label: <beef>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C6_M8.wav
# Target Label: Escape
# Predicted Label: <escape>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C7_M2.wav
# Target Label: Alt
# Predicted Label: <alt>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C7_M3.wav
# Target Label: Alt
# Predicted Label: <alt>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C7_M4.wav
# Target Label: Alt
# Predicted Label: <up>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C7_M5.wav
# Target Label: Alt
# Predicted Label: <up>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C7_M6.wav
# Target Label: Alt
# Predicted Label: <all>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C7_M7.wav
# Target Label: Alt
# Predicted Label: <alt>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C7_M8.wav
# Target Label: Alt
# Predicted Label: <alt>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C8_M2.wav
# Target Label: Control
# Predicted Label: <sentrol>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C8_M3.wav
# Target Label: Control
# Predicted Label: <control>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C8_M4.wav
# Target Label: Control
# Predicted Label: <ho>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C8_M5.wav
# Target Label: Control
# Predicted Label: <control>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C8_M6.wav
# Target Label: Control
# Predicted Label: <control>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C8_M7.wav
# Target Label: Control
# Predicted Label: <untwo>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C8_M8.wav
# Target Label: Control
# Predicted Label: <holk>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C9_M2.wav
# Target Label: Shift
# Predicted Label: <six>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C9_M3.wav
# Target Label: Shift
# Predicted Label: <his>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C9_M4.wav
# Target Label: Shift
# Predicted Label: <six>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C9_M5.wav
# Target Label: Shift
# Predicted Label: <six>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C9_M6.wav
# Target Label: Shift
# Predicted Label: <six>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C9_M7.wav
# Target Label: Shift
# Predicted Label: <six>
#
# C:\Users\abdul\Downloads\Test\F04_B3_C9_M8.wav
# Target Label: Shift
# Predicted Label: <his>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW100_M2.wav
# Target Label: yes
# Predicted Label: <yes>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW100_M3.wav
# Target Label: yes
# Predicted Label: <yes>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW100_M4.wav
# Target Label: yes
# Predicted Label: <yes>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW100_M5.wav
# Target Label: yes
# Predicted Label: <yes>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW100_M6.wav
# Target Label: yes
# Predicted Label: <yes>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW100_M7.wav
# Target Label: yes
# Predicted Label: <yes>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW100_M8.wav
# Target Label: yes
# Predicted Label: <yes>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW10_M2.wav
# Target Label: it
# Predicted Label: <it>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW10_M3.wav
# Target Label: it
# Predicted Label: <it>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW10_M4.wav
# Target Label: it
# Predicted Label: <it>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW10_M5.wav
# Target Label: it
# Predicted Label: <it>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW10_M6.wav
# Target Label: it
# Predicted Label: <it>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW10_M7.wav
# Target Label: it
# Predicted Label: <int>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW10_M8.wav
# Target Label: it
# Predicted Label: <int>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW11_M2.wav
# Target Label: he
# Predicted Label: <senthing>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW11_M3.wav
# Target Label: he
# Predicted Label: <sentence>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW11_M4.wav
# Target Label: he
# Predicted Label: <see>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW11_M5.wav
# Target Label: he
# Predicted Label: <he>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW11_M6.wav
# Target Label: he
# Predicted Label: <he>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW11_M7.wav
# Target Label: he
# Predicted Label: <he>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW11_M8.wav
# Target Label: he
# Predicted Label: <he>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW12_M2.wav
# Target Label: was
# Predicted Label: <bushe>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW12_M3.wav
# Target Label: was
# Predicted Label: <bushe>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW12_M4.wav
# Target Label: was
# Predicted Label: <blithe>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW12_M5.wav
# Target Label: was
# Predicted Label: <but>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW12_M6.wav
# Target Label: was
# Predicted Label: <but>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW12_M7.wav
# Target Label: was
# Predicted Label: <but>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW12_M8.wav
# Target Label: was
# Predicted Label: <blast>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW13_M2.wav
# Target Label: for
# Predicted Label: <for>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW13_M3.wav
# Target Label: for
# Predicted Label: <for>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW13_M4.wav
# Target Label: for
# Predicted Label: <for>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW13_M5.wav
# Target Label: for
# Predicted Label: <for>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW13_M6.wav
# Target Label: for
# Predicted Label: <for>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW13_M7.wav
# Target Label: for
# Predicted Label: <for>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW13_M8.wav
# Target Label: for
# Predicted Label: <for>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW14_M2.wav
# Target Label: on
# Predicted Label: <on>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW14_M3.wav
# Target Label: on
# Predicted Label: <on>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW14_M4.wav
# Target Label: on
# Predicted Label: <on>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW14_M5.wav
# Target Label: on
# Predicted Label: <on>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW14_M6.wav
# Target Label: on
# Predicted Label: <on>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW14_M7.wav
# Target Label: on
# Predicted Label: <on>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW14_M8.wav
# Target Label: on
# Predicted Label: <on>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW15_M2.wav
# Target Label: are
# Predicted Label: <are>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW15_M3.wav
# Target Label: are
# Predicted Label: <are>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW15_M4.wav
# Target Label: are
# Predicted Label: <are>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW15_M5.wav
# Target Label: are
# Predicted Label: <are>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW15_M6.wav
# Target Label: are
# Predicted Label: <are>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW15_M7.wav
# Target Label: are
# Predicted Label: <are>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW15_M8.wav
# Target Label: are
# Predicted Label: <are>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW16_M2.wav
# Target Label: as
# Predicted Label: <has>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW16_M3.wav
# Target Label: as
# Predicted Label: <as>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW16_M4.wav
# Target Label: as
# Predicted Label: <ad>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW16_M5.wav
# Target Label: as
# Predicted Label: <os>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW16_M6.wav
# Target Label: as
# Predicted Label: <as>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW16_M7.wav
# Target Label: as
# Predicted Label: <as>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW16_M8.wav
# Target Label: as
# Predicted Label: <as>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW17_M2.wav
# Target Label: with
# Predicted Label: <woith>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW17_M3.wav
# Target Label: with
# Predicted Label: <whiskey>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW17_M4.wav
# Target Label: with
# Predicted Label: <with>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW17_M5.wav
# Target Label: with
# Predicted Label: <with>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW17_M6.wav
# Target Label: with
# Predicted Label: <with>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW17_M7.wav
# Target Label: with
# Predicted Label: <whiskey>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW17_M8.wav
# Target Label: with
# Predicted Label: <whes>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW18_M2.wav
# Target Label: his
# Predicted Label: <his>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW18_M3.wav
# Target Label: his
# Predicted Label: <his>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW18_M4.wav
# Target Label: his
# Predicted Label: <his>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW18_M5.wav
# Target Label: his
# Predicted Label: <his>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW18_M6.wav
# Target Label: his
# Predicted Label: <his>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW18_M7.wav
# Target Label: his
# Predicted Label: <his>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW18_M8.wav
# Target Label: his
# Predicted Label: <his>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW19_M2.wav
# Target Label: they
# Predicted Label: <they>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW19_M3.wav
# Target Label: they
# Predicted Label: <they>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW19_M4.wav
# Target Label: they
# Predicted Label: <they>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW19_M5.wav
# Target Label: they
# Predicted Label: <they>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW19_M6.wav
# Target Label: they
# Predicted Label: <they>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW19_M7.wav
# Target Label: they
# Predicted Label: <they>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW19_M8.wav
# Target Label: they
# Predicted Label: <they>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW1_M2.wav
# Target Label: the
# Predicted Label: <the>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW1_M3.wav
# Target Label: the
# Predicted Label: <the>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW1_M4.wav
# Target Label: the
# Predicted Label: <the>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW1_M5.wav
# Target Label: the
# Predicted Label: <the>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW1_M6.wav
# Target Label: the
# Predicted Label: <the>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW1_M7.wav
# Target Label: the
# Predicted Label: <the>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW1_M8.wav
# Target Label: the
# Predicted Label: <the>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW20_M2.wav
# Target Label: I
# Predicted Label: <five>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW20_M3.wav
# Target Label: I
# Predicted Label: <five>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW20_M4.wav
# Target Label: I
# Predicted Label: <five>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW20_M5.wav
# Target Label: I
# Predicted Label: <os>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW20_M6.wav
# Target Label: I
# Predicted Label: <five>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW20_M7.wav
# Target Label: I
# Predicted Label: <on>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW20_M8.wav
# Target Label: I
# Predicted Label: <on>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW21_M2.wav
# Target Label: at
# Predicted Label: <at>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW21_M3.wav
# Target Label: at
# Predicted Label: <at>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW21_M4.wav
# Target Label: at
# Predicted Label: <apprehe>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW21_M5.wav
# Target Label: at
# Predicted Label: <alpha>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW21_M6.wav
# Target Label: at
# Predicted Label: <ale>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW21_M7.wav
# Target Label: at
# Predicted Label: <alpha>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW21_M8.wav
# Target Label: at
# Predicted Label: <alpha>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW22_M2.wav
# Target Label: be
# Predicted Label: <be>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW22_M3.wav
# Target Label: be
# Predicted Label: <we>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW22_M4.wav
# Target Label: be
# Predicted Label: <he>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW22_M5.wav
# Target Label: be
# Predicted Label: <he>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW22_M6.wav
# Target Label: be
# Predicted Label: <the>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW22_M7.wav
# Target Label: be
# Predicted Label: <we>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW22_M8.wav
# Target Label: be
# Predicted Label: <we>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW23_M2.wav
# Target Label: this
# Predicted Label: <this>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW23_M3.wav
# Target Label: this
# Predicted Label: <this>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW23_M4.wav
# Target Label: this
# Predicted Label: <this>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW23_M5.wav
# Target Label: this
# Predicted Label: <this>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW23_M6.wav
# Target Label: this
# Predicted Label: <these>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW23_M7.wav
# Target Label: this
# Predicted Label: <this>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW23_M8.wav
# Target Label: this
# Predicted Label: <this>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW24_M2.wav
# Target Label: have
# Predicted Label: <ham>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW24_M3.wav
# Target Label: have
# Predicted Label: <have>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW24_M4.wav
# Target Label: have
# Predicted Label: <a>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW24_M5.wav
# Target Label: have
# Predicted Label: <him>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW24_M6.wav
# Target Label: have
# Predicted Label: <as>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW24_M7.wav
# Target Label: have
# Predicted Label: <him>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW24_M8.wav
# Target Label: have
# Predicted Label: <him>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW25_M2.wav
# Target Label: from
# Predicted Label: <long>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW25_M3.wav
# Target Label: from
# Predicted Label: <thumb>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW25_M4.wav
# Target Label: from
# Predicted Label: <long>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW25_M5.wav
# Target Label: from
# Predicted Label: <long>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW25_M6.wav
# Target Label: from
# Predicted Label: <lamp>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW25_M7.wav
# Target Label: from
# Predicted Label: <long>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW25_M8.wav
# Target Label: from
# Predicted Label: <long>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW26_M2.wav
# Target Label: or
# Predicted Label: <or>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW26_M3.wav
# Target Label: or
# Predicted Label: <or>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW26_M4.wav
# Target Label: or
# Predicted Label: <or>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW26_M5.wav
# Target Label: or
# Predicted Label: <or>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW26_M6.wav
# Target Label: or
# Predicted Label: <more>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW26_M7.wav
# Target Label: or
# Predicted Label: <for>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW26_M8.wav
# Target Label: or
# Predicted Label: <or>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW27_M2.wav
# Target Label: had
# Predicted Label: <had>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW27_M3.wav
# Target Label: had
# Predicted Label: <had>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW27_M4.wav
# Target Label: had
# Predicted Label: <had>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW27_M5.wav
# Target Label: had
# Predicted Label: <had>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW27_M6.wav
# Target Label: had
# Predicted Label: <hid>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW27_M7.wav
# Target Label: had
# Predicted Label: <had>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW27_M8.wav
# Target Label: had
# Predicted Label: <hid>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW28_M2.wav
# Target Label: by
# Predicted Label: <by>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW28_M3.wav
# Target Label: by
# Predicted Label: <by>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW28_M4.wav
# Target Label: by
# Predicted Label: <five>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW28_M5.wav
# Target Label: by
# Predicted Label: <five>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW28_M6.wav
# Target Label: by
# Predicted Label: <five>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW28_M7.wav
# Target Label: by
# Predicted Label: <by>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW28_M8.wav
# Target Label: by
# Predicted Label: <five>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW29_M2.wav
# Target Label: word
# Predicted Label: <water>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW29_M3.wav
# Target Label: word
# Predicted Label: <water>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW29_M4.wav
# Target Label: word
# Predicted Label: <water>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW29_M5.wav
# Target Label: word
# Predicted Label: <or>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW29_M6.wav
# Target Label: word
# Predicted Label: <or>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW29_M7.wav
# Target Label: word
# Predicted Label: <oran>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW29_M8.wav
# Target Label: word
# Predicted Label: <or>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW2_M2.wav
# Target Label: of
# Predicted Label: <out>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW2_M3.wav
# Target Label: of
# Predicted Label: <out>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW2_M4.wav
# Target Label: of
# Predicted Label: <up>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW2_M5.wav
# Target Label: of
# Predicted Label: <up>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW2_M6.wav
# Target Label: of
# Predicted Label: <up>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW2_M7.wav
# Target Label: of
# Predicted Label: <up>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW2_M8.wav
# Target Label: of
# Predicted Label: <up>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW30_M2.wav
# Target Label: but
# Predicted Label: <but>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW30_M3.wav
# Target Label: but
# Predicted Label: <but>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW30_M4.wav
# Target Label: but
# Predicted Label: <quack>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW30_M5.wav
# Target Label: but
# Predicted Label: <but>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW30_M6.wav
# Target Label: but
# Predicted Label: <quack>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW30_M7.wav
# Target Label: but
# Predicted Label: <but>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW30_M8.wav
# Target Label: but
# Predicted Label: <but>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW31_M2.wav
# Target Label: not
# Predicted Label: <not>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW31_M3.wav
# Target Label: not
# Predicted Label: <not>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW31_M4.wav
# Target Label: not
# Predicted Label: <nut>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW31_M5.wav
# Target Label: not
# Predicted Label: <nut>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW31_M6.wav
# Target Label: not
# Predicted Label: <nut>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW31_M7.wav
# Target Label: not
# Predicted Label: <not>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW31_M8.wav
# Target Label: not
# Predicted Label: <nut>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW32_M2.wav
# Target Label: what
# Predicted Label: <watch>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW32_M3.wav
# Target Label: what
# Predicted Label: <watch>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW32_M4.wav
# Target Label: what
# Predicted Label: <watch>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW32_M5.wav
# Target Label: what
# Predicted Label: <watch>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW32_M6.wav
# Target Label: what
# Predicted Label: <what>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW32_M7.wav
# Target Label: what
# Predicted Label: <watch>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW32_M8.wav
# Target Label: what
# Predicted Label: <was>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW33_M2.wav
# Target Label: all
# Predicted Label: <all>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW33_M3.wav
# Target Label: all
# Predicted Label: <oh>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW33_M4.wav
# Target Label: all
# Predicted Label: <all>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW33_M5.wav
# Target Label: all
# Predicted Label: <how>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW33_M6.wav
# Target Label: all
# Predicted Label: <ow>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW33_M7.wav
# Target Label: all
# Predicted Label: <all>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW33_M8.wav
# Target Label: all
# Predicted Label: <up>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW34_M2.wav
# Target Label: were
# Predicted Label: <were>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW34_M3.wav
# Target Label: were
# Predicted Label: <were>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW34_M4.wav
# Target Label: were
# Predicted Label: <were>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW34_M5.wav
# Target Label: were
# Predicted Label: <were>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW34_M6.wav
# Target Label: were
# Predicted Label: <were>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW34_M7.wav
# Target Label: were
# Predicted Label: <were>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW34_M8.wav
# Target Label: were
# Predicted Label: <were>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW35_M2.wav
# Target Label: we
# Predicted Label: <with>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW35_M3.wav
# Target Label: we
# Predicted Label: <we>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW35_M4.wav
# Target Label: we
# Predicted Label: <we>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW35_M5.wav
# Target Label: we
# Predicted Label: <we>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW35_M6.wav
# Target Label: we
# Predicted Label: <we>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW35_M7.wav
# Target Label: we
# Predicted Label: <we>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW35_M8.wav
# Target Label: we
# Predicted Label: <we>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW36_M2.wav
# Target Label: when
# Predicted Label: <wind>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW36_M3.wav
# Target Label: when
# Predicted Label: <wind>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW36_M4.wav
# Target Label: when
# Predicted Label: <lima>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW36_M5.wav
# Target Label: when
# Predicted Label: <litht>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW36_M6.wav
# Target Label: when
# Predicted Label: <find>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW36_M7.wav
# Target Label: when
# Predicted Label: <lan>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW36_M8.wav
# Target Label: when
# Predicted Label: <on>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW37_M2.wav
# Target Label: your
# Predicted Label: <your>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW37_M3.wav
# Target Label: your
# Predicted Label: <your>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW37_M4.wav
# Target Label: your
# Predicted Label: <your>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW37_M5.wav
# Target Label: your
# Predicted Label: <your>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW37_M6.wav
# Target Label: your
# Predicted Label: <your>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW37_M7.wav
# Target Label: your
# Predicted Label: <your>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW37_M8.wav
# Target Label: your
# Predicted Label: <your>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW38_M2.wav
# Target Label: can
# Predicted Label: <chan>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW38_M3.wav
# Target Label: can
# Predicted Label: <can>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW38_M4.wav
# Target Label: can
# Predicted Label: <tan>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW38_M5.wav
# Target Label: can
# Predicted Label: <can>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW38_M6.wav
# Target Label: can
# Predicted Label: <can>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW38_M7.wav
# Target Label: can
# Predicted Label: <tango>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW38_M8.wav
# Target Label: can
# Predicted Label: <can>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW39_M2.wav
# Target Label: said
# Predicted Label: <their>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW39_M3.wav
# Target Label: said
# Predicted Label: <theid>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW39_M4.wav
# Target Label: said
# Predicted Label: <then>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW39_M5.wav
# Target Label: said
# Predicted Label: <good>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW39_M6.wav
# Target Label: said
# Predicted Label: <then>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW39_M7.wav
# Target Label: said
# Predicted Label: <then>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW39_M8.wav
# Target Label: said
# Predicted Label: <theid>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW3_M2.wav
# Target Label: and
# Predicted Label: <hin>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW3_M3.wav
# Target Label: and
# Predicted Label: <hin>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW3_M4.wav
# Target Label: and
# Predicted Label: <and>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW3_M5.wav
# Target Label: and
# Predicted Label: <can>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW3_M6.wav
# Target Label: and
# Predicted Label: <and>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW3_M7.wav
# Target Label: and
# Predicted Label: <hin>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW3_M8.wav
# Target Label: and
# Predicted Label: <hin>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW40_M2.wav
# Target Label: there
# Predicted Label: <there>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW40_M3.wav
# Target Label: there
# Predicted Label: <their>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW40_M4.wav
# Target Label: there
# Predicted Label: <there>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW40_M5.wav
# Target Label: there
# Predicted Label: <there>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW40_M6.wav
# Target Label: there
# Predicted Label: <their>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW40_M7.wav
# Target Label: there
# Predicted Label: <their>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW40_M8.wav
# Target Label: there
# Predicted Label: <their>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW41_M2.wav
# Target Label: use
# Predicted Label: <use>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW41_M3.wav
# Target Label: use
# Predicted Label: <use>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW41_M4.wav
# Target Label: use
# Predicted Label: <use>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW41_M5.wav
# Target Label: use
# Predicted Label: <use>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW41_M6.wav
# Target Label: use
# Predicted Label: <use>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW41_M7.wav
# Target Label: use
# Predicted Label: <use>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW41_M8.wav
# Target Label: use
# Predicted Label: <use>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW42_M2.wav
# Target Label: an
# Predicted Label: <an>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW42_M3.wav
# Target Label: an
# Predicted Label: <and>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW42_M4.wav
# Target Label: an
# Predicted Label: <and>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW42_M5.wav
# Target Label: an
# Predicted Label: <an>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW42_M6.wav
# Target Label: an
# Predicted Label: <and>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW42_M7.wav
# Target Label: an
# Predicted Label: <and>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW42_M8.wav
# Target Label: an
# Predicted Label: <an>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW43_M2.wav
# Target Label: each
# Predicted Label: <each>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW43_M3.wav
# Target Label: each
# Predicted Label: <each>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW43_M4.wav
# Target Label: each
# Predicted Label: <pach>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW43_M5.wav
# Target Label: each
# Predicted Label: <each>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW43_M6.wav
# Target Label: each
# Predicted Label: <each>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW43_M7.wav
# Target Label: each
# Predicted Label: <each>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW43_M8.wav
# Target Label: each
# Predicted Label: <each>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW44_M2.wav
# Target Label: which
# Predicted Label: <which>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW44_M3.wav
# Target Label: which
# Predicted Label: <with>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW44_M4.wav
# Target Label: which
# Predicted Label: <with>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW44_M5.wav
# Target Label: which
# Predicted Label: <mike>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW44_M6.wav
# Target Label: which
# Predicted Label: <lemp>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW44_M7.wav
# Target Label: which
# Predicted Label: <which>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW44_M8.wav
# Target Label: which
# Predicted Label: <which>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW45_M2.wav
# Target Label: she
# Predicted Label: <she>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW45_M3.wav
# Target Label: she
# Predicted Label: <she>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW45_M4.wav
# Target Label: she
# Predicted Label: <she>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW45_M5.wav
# Target Label: she
# Predicted Label: <she>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW45_M6.wav
# Target Label: she
# Predicted Label: <she>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW45_M7.wav
# Target Label: she
# Predicted Label: <she>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW45_M8.wav
# Target Label: she
# Predicted Label: <she>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW46_M2.wav
# Target Label: do
# Predicted Label: <ablut>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW46_M3.wav
# Target Label: do
# Predicted Label: <do>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW46_M4.wav
# Target Label: do
# Predicted Label: <do>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW46_M5.wav
# Target Label: do
# Predicted Label: <do>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW46_M6.wav
# Target Label: do
# Predicted Label: <do>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW46_M7.wav
# Target Label: do
# Predicted Label: <do>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW46_M8.wav
# Target Label: do
# Predicted Label: <do>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW47_M2.wav
# Target Label: how
# Predicted Label: <how>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW47_M3.wav
# Target Label: how
# Predicted Label: <ow>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW47_M4.wav
# Target Label: how
# Predicted Label: <how>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW47_M5.wav
# Target Label: how
# Predicted Label: <how>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW47_M6.wav
# Target Label: how
# Predicted Label: <alpha>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW47_M7.wav
# Target Label: how
# Predicted Label: <how>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW47_M8.wav
# Target Label: how
# Predicted Label: <how>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW48_M2.wav
# Target Label: their
# Predicted Label: <there>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW48_M3.wav
# Target Label: their
# Predicted Label: <there>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW48_M4.wav
# Target Label: their
# Predicted Label: <there>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW48_M5.wav
# Target Label: their
# Predicted Label: <there>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW48_M6.wav
# Target Label: their
# Predicted Label: <there>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW48_M7.wav
# Target Label: their
# Predicted Label: <there>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW48_M8.wav
# Target Label: their
# Predicted Label: <there>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW49_M2.wav
# Target Label: if
# Predicted Label: <it>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW49_M3.wav
# Target Label: if
# Predicted Label: <its>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW49_M4.wav
# Target Label: if
# Predicted Label: <its>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW49_M5.wav
# Target Label: if
# Predicted Label: <it>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW49_M6.wav
# Target Label: if
# Predicted Label: <its>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW49_M7.wav
# Target Label: if
# Predicted Label: <it>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW49_M8.wav
# Target Label: if
# Predicted Label: <its>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW4_M2.wav
# Target Label: a
# Predicted Label: <a>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW4_M3.wav
# Target Label: a
# Predicted Label: <a>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW4_M4.wav
# Target Label: a
# Predicted Label: <a>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW4_M5.wav
# Target Label: a
# Predicted Label: <a>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW4_M6.wav
# Target Label: a
# Predicted Label: <a>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW4_M7.wav
# Target Label: a
# Predicted Label: <a>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW4_M8.wav
# Target Label: a
# Predicted Label: <a>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW50_M2.wav
# Target Label: will
# Predicted Label: <will>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW50_M3.wav
# Target Label: will
# Predicted Label: <will>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW50_M4.wav
# Target Label: will
# Predicted Label: <will>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW50_M5.wav
# Target Label: will
# Predicted Label: <will>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW50_M6.wav
# Target Label: will
# Predicted Label: <will>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW50_M7.wav
# Target Label: will
# Predicted Label: <will>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW50_M8.wav
# Target Label: will
# Predicted Label: <will>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW51_M2.wav
# Target Label: up
# Predicted Label: <up>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW51_M3.wav
# Target Label: up
# Predicted Label: <up>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW51_M4.wav
# Target Label: up
# Predicted Label: <up>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW51_M5.wav
# Target Label: up
# Predicted Label: <up>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW51_M6.wav
# Target Label: up
# Predicted Label: <up>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW51_M7.wav
# Target Label: up
# Predicted Label: <up>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW51_M8.wav
# Target Label: up
# Predicted Label: <up>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW52_M2.wav
# Target Label: other
# Predicted Label: <left>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW52_M3.wav
# Target Label: other
# Predicted Label: <lelephone>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW52_M4.wav
# Target Label: other
# Predicted Label: <ather>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW52_M5.wav
# Target Label: other
# Predicted Label: <lethargy>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW52_M6.wav
# Target Label: other
# Predicted Label: <lethargy>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW52_M7.wav
# Target Label: other
# Predicted Label: <massage>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW52_M8.wav
# Target Label: other
# Predicted Label: <lathargy>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW53_M2.wav
# Target Label: about
# Predicted Label: <about>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW53_M3.wav
# Target Label: about
# Predicted Label: <about>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW53_M4.wav
# Target Label: about
# Predicted Label: <the>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW53_M5.wav
# Target Label: about
# Predicted Label: <thou>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW53_M6.wav
# Target Label: about
# Predicted Label: <about>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW53_M7.wav
# Target Label: about
# Predicted Label: <about>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW53_M8.wav
# Target Label: about
# Predicted Label: <both>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW54_M2.wav
# Target Label: out
# Predicted Label: <out>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW54_M3.wav
# Target Label: out
# Predicted Label: <out>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW54_M4.wav
# Target Label: out
# Predicted Label: <out>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW54_M5.wav
# Target Label: out
# Predicted Label: <out>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW54_M6.wav
# Target Label: out
# Predicted Label: <out>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW54_M7.wav
# Target Label: out
# Predicted Label: <out>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW54_M8.wav
# Target Label: out
# Predicted Label: <cup>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW55_M2.wav
# Target Label: many
# Predicted Label: <minte>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW55_M3.wav
# Target Label: many
# Predicted Label: <mintence>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW55_M4.wav
# Target Label: many
# Predicted Label: <mintence>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW55_M5.wav
# Target Label: many
# Predicted Label: <mintence>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW55_M6.wav
# Target Label: many
# Predicted Label: <monkence>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW55_M7.wav
# Target Label: many
# Predicted Label: <many>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW55_M8.wav
# Target Label: many
# Predicted Label: <monkence>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW56_M2.wav
# Target Label: then
# Predicted Label: <then>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW56_M3.wav
# Target Label: then
# Predicted Label: <then>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW56_M4.wav
# Target Label: then
# Predicted Label: <sentence>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW56_M5.wav
# Target Label: then
# Predicted Label: <one>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW56_M6.wav
# Target Label: then
# Predicted Label: <one>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW56_M7.wav
# Target Label: then
# Predicted Label: <seen>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW56_M8.wav
# Target Label: then
# Predicted Label: <sentence>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW57_M2.wav
# Target Label: them
# Predicted Label: <them>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW57_M3.wav
# Target Label: them
# Predicted Label: <some>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW57_M4.wav
# Target Label: them
# Predicted Label: <one>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW57_M5.wav
# Target Label: them
# Predicted Label: <lone>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW57_M6.wav
# Target Label: them
# Predicted Label: <one>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW57_M7.wav
# Target Label: them
# Predicted Label: <one>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW57_M8.wav
# Target Label: them
# Predicted Label: <one>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW58_M2.wav
# Target Label: these
# Predicted Label: <these>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW58_M3.wav
# Target Label: these
# Predicted Label: <these>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW58_M4.wav
# Target Label: these
# Predicted Label: <these>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW58_M5.wav
# Target Label: these
# Predicted Label: <you>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW58_M6.wav
# Target Label: these
# Predicted Label: <escape>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW58_M7.wav
# Target Label: these
# Predicted Label: <these>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW58_M8.wav
# Target Label: these
# Predicted Label: <these>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW59_M2.wav
# Target Label: so
# Predicted Label: <so>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW59_M3.wav
# Target Label: so
# Predicted Label: <co>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW59_M4.wav
# Target Label: so
# Predicted Label: <co>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW59_M5.wav
# Target Label: so
# Predicted Label: <co>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW59_M6.wav
# Target Label: so
# Predicted Label: <so>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW59_M7.wav
# Target Label: so
# Predicted Label: <taltphone>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW59_M8.wav
# Target Label: so
# Predicted Label: <to>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW5_M2.wav
# Target Label: to
# Predicted Label: <tree>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW5_M3.wav
# Target Label: to
# Predicted Label: <tree>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW5_M4.wav
# Target Label: to
# Predicted Label: <two>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW5_M5.wav
# Target Label: to
# Predicted Label: <tree>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW5_M6.wav
# Target Label: to
# Predicted Label: <tree>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW5_M7.wav
# Target Label: to
# Predicted Label: <tree>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW5_M8.wav
# Target Label: to
# Predicted Label: <tree>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW60_M2.wav
# Target Label: some
# Predicted Label: <some>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW60_M3.wav
# Target Label: some
# Predicted Label: <some>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW60_M4.wav
# Target Label: some
# Predicted Label: <some>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW60_M5.wav
# Target Label: some
# Predicted Label: <some>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW60_M6.wav
# Target Label: some
# Predicted Label: <some>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW60_M7.wav
# Target Label: some
# Predicted Label: <some>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW60_M8.wav
# Target Label: some
# Predicted Label: <some>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW61_M2.wav
# Target Label: her
# Predicted Label: <her>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW61_M3.wav
# Target Label: her
# Predicted Label: <her>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW61_M4.wav
# Target Label: her
# Predicted Label: <her>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW61_M5.wav
# Target Label: her
# Predicted Label: <her>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW61_M6.wav
# Target Label: her
# Predicted Label: <her>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW61_M7.wav
# Target Label: her
# Predicted Label: <are>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW61_M8.wav
# Target Label: her
# Predicted Label: <har>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW62_M2.wav
# Target Label: would
# Predicted Label: <would>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW62_M3.wav
# Target Label: would
# Predicted Label: <would>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW62_M4.wav
# Target Label: would
# Predicted Label: <would>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW62_M5.wav
# Target Label: would
# Predicted Label: <would>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW62_M6.wav
# Target Label: would
# Predicted Label: <would>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW62_M7.wav
# Target Label: would
# Predicted Label: <would>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW62_M8.wav
# Target Label: would
# Predicted Label: <would>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW63_M2.wav
# Target Label: make
# Predicted Label: <make>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW63_M3.wav
# Target Label: make
# Predicted Label: <made>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW63_M4.wav
# Target Label: make
# Predicted Label: <make>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW63_M5.wav
# Target Label: make
# Predicted Label: <made>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW63_M6.wav
# Target Label: make
# Predicted Label: <mad>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW63_M7.wav
# Target Label: make
# Predicted Label: <made>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW63_M8.wav
# Target Label: make
# Predicted Label: <made>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW64_M2.wav
# Target Label: like
# Predicted Label: <six>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW64_M3.wav
# Target Label: like
# Predicted Label: <seven>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW64_M4.wav
# Target Label: like
# Predicted Label: <seven>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW64_M5.wav
# Target Label: like
# Predicted Label: <shat>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW64_M6.wav
# Target Label: like
# Predicted Label: <sentence>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW64_M7.wav
# Target Label: like
# Predicted Label: <sentence>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW64_M8.wav
# Target Label: like
# Predicted Label: <seven>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW65_M2.wav
# Target Label: him
# Predicted Label: <hin>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW65_M3.wav
# Target Label: him
# Predicted Label: <hin>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW65_M4.wav
# Target Label: him
# Predicted Label: <in>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW65_M5.wav
# Target Label: him
# Predicted Label: <senten>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW65_M6.wav
# Target Label: him
# Predicted Label: <in>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW65_M7.wav
# Target Label: him
# Predicted Label: <hin>
#
# C:\Users\abdul\Downloads\Test\F04_B3_CW65_M8.wav
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-6ffada70cdcf> in <module>
#      18
#      19     # Generate predictions
# ---> 20     predicted_label = predict_label(rmodel, audio_path)
#      21
#      22     # Print target and predicted labels
#
# <ipython-input-40-cf8bbcff3c38> in predict_label(model, audio_path)
#       8     # Generate predictions
#       9     start_token_idx = 2  # Adjust this based on your vocabulary
# ---> 10     preds = model.generate(audio, start_token_idx).numpy()
#      11
#      12     # Convert predicted indices to label
#
# <ipython-input-22-78405de86cef> in generate(self, source, target_start_token_idx)
#      96         dec_logits = []
#      97         for i in range(self.target_maxlen - 1):
# ---> 98             dec_out = self.decode(enc, dec_input)
#      99             logits = self.classifier(dec_out)
#     100             logits = tf.argmax(logits, axis=-1, output_type=tf.int32)
#
# <ipython-input-22-78405de86cef> in decode(self, enc_out, target)
#      45         y = self.dec_input(target)
#      46         for i in range(self.num_layers_dec):
# ---> 47             y = getattr(self, f"dec_layer_{i}")(enc_out, y)
#      48         return y
#      49
#
# ~\anaconda3\envs\myenv\lib\site-packages\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#    1035         with autocast_variable.enable_auto_cast_variables(
#    1036             self._compute_dtype_object):
# -> 1037           outputs = call_fn(inputs, *args, **kwargs)
#    1038
#    1039         if self._activity_regularizer:
#
# <ipython-input-21-58710a506532> in call(self, enc_out, target)
#      42         target_att = self.self_att(target, target, attention_mask=causal_mask)
#      43         target_norm = self.layernorm1(target + self.self_dropout(target_att))
# ---> 44         enc_out = self.enc_att(target_norm, enc_out)
#      45         enc_out_norm = self.layernorm2(self.enc_dropout(enc_out) + target_norm)
#      46         ffn_out = self.ffn(enc_out_norm)
#
# ~\anaconda3\envs\myenv\lib\site-packages\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#    1035         with autocast_variable.enable_auto_cast_variables(
#    1036             self._compute_dtype_object):
# -> 1037           outputs = call_fn(inputs, *args, **kwargs)
#    1038
#    1039         if self._activity_regularizer:
#
# ~\anaconda3\envs\myenv\lib\site-packages\keras\layers\multi_head_attention.py in call(self, query, value, key, attention_mask, return_attention_scores, training)
#     496
#     497     # `key` = [B, S, N, H]
# --> 498     key = self._key_dense(key)
#     499
#     500     # `value` = [B, S, N, H]
#
# ~\anaconda3\envs\myenv\lib\site-packages\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#    1035         with autocast_variable.enable_auto_cast_variables(
#    1036             self._compute_dtype_object):
# -> 1037           outputs = call_fn(inputs, *args, **kwargs)
#    1038
#    1039         if self._activity_regularizer:
#
# ~\anaconda3\envs\myenv\lib\site-packages\keras\layers\einsum_dense.py in call(self, inputs)
#     195
#     196   def call(self, inputs):
# --> 197     ret = tf.einsum(self.equation, inputs, self.kernel)
#     198     if self.bias is not None:
#     199       ret += self.bias
#
# ~\anaconda3\envs\myenv\lib\site-packages\tensorflow\python\util\dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~\anaconda3\envs\myenv\lib\site-packages\tensorflow\python\ops\special_math_ops.py in einsum(equation, *inputs, **kwargs)
#     749       - number of inputs or their shapes are inconsistent with `equation`.
#     750   """
# --> 751   return _einsum_v2(equation, *inputs, **kwargs)
#     752
#     753
#
# ~\anaconda3\envs\myenv\lib\site-packages\tensorflow\python\ops\special_math_ops.py in _einsum_v2(equation, *inputs, **kwargs)
#    1178       if ellipsis_label:
#    1179         resolved_equation = resolved_equation.replace(ellipsis_label, '...')
# -> 1180       return gen_linalg_ops.einsum(inputs, resolved_equation)
#    1181
#    1182     # Send fully specified shapes to opt_einsum, since it cannot handle unknown
#
# ~\anaconda3\envs\myenv\lib\site-packages\tensorflow\python\ops\gen_linalg_ops.py in einsum(inputs, equation, name)
#    1070     try:
#    1071       _result = pywrap_tfe.TFE_Py_FastPathExecute(
# -> 1072         _ctx, "Einsum", name, inputs, "equation", equation)
#    1073       return _result
#    1074     except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
accuracy = calculate_accuracy(predicted_labels, target_labels)
print(f"Overall Accuracy: {accuracy * 100:.2f}%")
# Out:
# Overall Accuracy: 51.24%
